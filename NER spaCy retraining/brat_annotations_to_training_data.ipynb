# %% [markdown]
# ### Import spaCy, load annotation files

# %%
import spacy

nlp = spacy.load("nl_core_news_lg")

# %%
from tqdm import tqdm

import gzip
import os

import random

import pandas

corpus = "../Corpus/"
anns = "../Annotations/"

def load(file, corpus, lines=False):
    with open(os.path.join(corpus, file), "r") as handle:
        if lines:
            return list(handle) # handle.readlines()
        else:
            return handle.read()

# %% [markdown]
# ### Reading BRAT annotations (for select entities)

# %%
def read_csv(file, corpus=anns):
    file = load(file, corpus, lines=True)
    for line in file:
        tab_cols = line.split("\t")
        
        if tab_cols[0].startswith("T"):
            last = tab_cols[-1].strip()
            first = tab_cols[0]
            
            middle = tab_cols[1].split()
#             print(middle, middle[0], middle[-1])
            middle = [middle[0], middle[1], middle[-1]]
            
            yield (first, *middle, last)
            
def filter_rows(rows):
    for r in rows:
        if r[1].upper() in ["PERSON", "ORG", "GPE"]:
            yield r
            
def change_rows(rows):
    for r in rows:
        entity_nr, entity_type, start, end, label = r
        yield int(start), int(end), entity_type.upper()

# %% [markdown]
# ### output of textfile, text and annotations - both manual and those output by spaCy

# %%
data = {}
for ann_f in os.listdir(anns):
    if not ann_f.endswith('.ann'): continue
    if len(load(ann_f, anns)) > 0:
        cur_name = ann_f.strip(".ann")
    
        txt_f = cur_name + ".txt"
        if os.path.isfile(os.path.join(corpus, txt_f)):
        
            raw_text = load(txt_f, corpus)
            brat_entity_list = list(change_rows(filter_rows(read_csv(ann_f, anns))))
            spacy_entity_list = [(e.start_char, e.end_char, e.label_) for e in nlp(raw_text).ents]

            data[cur_name] = (raw_text.replace("\n", " "), brat_entity_list, spacy_entity_list)
        else:
            print("no file", txt_f)
    #else:
        #print("annotation file empty")

# %%
import random

def range_in(ent, ent_ls):
    for ent2 in ent_ls:
        x = ent[:-1]
        y = ent2[:-1]
        if len(range(max(x[0], y[0]), min(x[-1], y[-1])+1)) > 0:
            return True
    return False
        
def merge(b_ls, s_ls):
    l = len(b_ls)
    
    l = len(s_ls)//1
    k = 0
    for s_ent in random.sample(s_ls, len(s_ls)):
        if k == l:
            break
        if not range_in(s_ent, b_ls):
            yield s_ent
            k += 1
            
    yield from b_ls
            
    
    
    
    
data_merged = {}

for f, (txt, b_ls, s_ls) in data.items():    
    ents = sorted(merge(b_ls, s_ls), key=lambda tup: tup[0])
    
    data_merged[f] = (txt, ents)

# %%
data_merged
# Out:
# {'NL-HaNA_1.04.02_6847_0758': ("Gods dienst gedaan hebben, zal mogen verkoopen, alles ingevolge de heer gerespecteerde ordres voor de E: hooge Regeening diezertlanden ten dien opzigten g'emaneert Al het gunt voorschreeven staat de testateuren drijdelijk voorgeleesen en bi hun zoozij reiden wel verstand szijnde begeereten zij dat sent instrument het h: als testament of cod„ El, of zodanig als het best na regten sal konnen bestaan DitAleus passeerde ten huijzen ande tesluteuren Staande ter plaatse als in den Hoofde deeses gemelde in tegenswoordigheijd van Abraham Salbindusz en Pieter Iuspphoz Clercquen als getuigen De minute deeses is behoorlijk geteekend en gesch op een Legul van een rijxd:s / onderstond /quve allestar ( was geteekend) C: Blomhert nolafis Op Heeden den 15. 9br A:o 1774 Toormidagsee Ctokeuuren Gotfried hebbe ik Christiaan Baumgarten eerst gesworen Klerk van Politie deeses gouvernements, ende na te noemene getuigen als waar toe gerequireerd zijnde mij vervoegt Pasqual de aan het woon huijs van den eerwaarde Heer Pasqual De Siva proponent van de gereformeerde Religie, tans in Coco sihra en staande op zijn vertrekt naar Batavia, alwaar voor mij in eigenen persoon Compureerde gemelde Heer Desilva en des Alfs huifsvrouw mejuf Martia Jansz egtelieden en mij bekend, sijnde beidengezond van Lighaam gaande en staande hebbende eerzelver verslanstreden en memu die tot hinnerb volkomen gebruik na allen uitwendtge Schein, Dewelke verklaarden uit een Christen betaamde overdenking zijnen sterflijkheijd te vaaren geworden te zijn net uit, deese weevels te willn scheiden zonder benoovens, over de tijvelijke goederen aan hun voor god almagtig verleend gedis „poneerd te hebben; doende zulke bij deesen zoo als zij verder verklaarden uit hunner eigen en vrijen willen en gemoed zonder iemande opmaking of misleiding Revoceerende en Casseerende vermeliegende bij deesen al de testamenten Co„ „dicillen en andere actens van uitterste willen die EE Comparanten stuijkeedens t samen of een ieder van hun in ’t bijzondert van wel met iemagTanders voor datu deeser eenigzints gemaakt gepasseerd of verleden mogten hebben Dewijl zil verklaarden niet te willen nog begeeven dat alle dekelve of een van alle in geheel often deese agter volge zal worden in geenerleijk manieren Voorls van nieuw en ter dispositie treevende zoo verkchaarden de testateuren tot hunnen E: eenigen en universeele eerfgenaam of erfgenaame over en weder te slellen en institueeren gelijk coen bij deesen Te eerststerwende de langstleevende van hun beiden en dat in alle de goederen zoo roerende als onroerende tegenswoordige, en toekomende utien en  Crediten waar die gelegen of van wat natuur de zelve zouden mogen zijn geene ter veren uitgezondert, de welke de eerst stervende met zijn of haar overlijden ontruijmen en agter laaten zal en wel om hetzelve te possideerten en daar meede te handelen als met vrij eige goedt nogtans met deese verstande en op voorwaarde sal de langstlevenden of de langst, ",
#   [(153, 163, 'PERSON'),
#    (211, 234, 'PERSON'),
#    (238, 240, 'NORP'),
#    (339, 342, 'ORG'),
#    (401, 409, 'PERSON'),
#    (476, 493, 'PERSON'),
#    (505, 527, 'PERSON'),
#    (528, 546, 'PERSON'),
#    (550, 565, 'PERSON'),
#    (633, 638, 'NORP'),
#    (681, 695, 'PRODUCT'),
#    (713, 724, 'PERSON'),
#    (733, 742, 'PERSON'),
#    (747, 749, 'CARDINAL'),
#    (751, 754, 'PERSON'),
#    (759, 763, 'DATE'),
#    (764, 776, 'GPE'),
#    (806, 827, 'PERSON'),
#    (861, 881, 'PERSON'),
#    (957, 964, 'PERSON'),
#    (1010, 1025, 'PERSON'),
#    (1043, 1056, 'NORP'),
#    (1074, 1079, 'PERSON'),
#    (1118, 1125, 'GPE'),
#    (1162, 1173, 'GPE'),
#    (1187, 1194, 'PERSON'),
#    (1202, 1206, 'LOC'),
#    (1207, 1217, 'LOC'),
#    (1224, 1236, 'PERSON'),
#    (1287, 1294, 'GPE'),
#    (1444, 1452, 'NORP'),
#    (1532, 1545, 'PERSON'),
#    (1549, 1580, 'PERSON'),
#    (1623, 1635, 'PERSON'),
#    (1688, 1698, 'PERSON'),
#    (1777, 1793, 'ORG'),
#    (1808, 1820, 'WORK_OF_ART'),
#    (1824, 1835, 'NORP'),
#    (1854, 1860, 'PERSON'),
#    (1879, 1881, 'WORK_OF_ART'),
#    (1914, 1923, 'GPE'),
#    (1935, 1962, 'ORG'),
#    (2039, 2050, 'PERSON'),
#    (2107, 2117, 'PERSON'),
#    (2207, 2218, 'PERSON'),
#    (2260, 2266, 'ORG'),
#    (2416, 2423, 'FAC'),
#    (2427, 2440, 'DATE'),
#    (2447, 2462, 'PERSON'),
#    (2484, 2499, 'DATE'),
#    (2599, 2604, 'PERSON'),
#    (2609, 2617, 'PERSON'),
#    (2696, 2708, 'PERSON'),
#    (2766, 2776, 'GPE'),
#    (2934, 2948, 'LOC')]),
#  'NL-HaNA_1.04.02_6847_0764': ('mogte weesen te legateeren aan voornoemde Frans Willen waltig, een goude stukrigg met Seeven diamanten soo meede prelegateerd de testatrice aan haar degterlje Christina Elisabeth een Snoerpaarlen van een honden vijf en dertig stuks mitsg:s een kruijs met vier en twintig hiamanten en het slatje met negen diamanten twee strik „ringen, hier met seeven ciamanten een paar verletten met diamanten in Europa gezet, een hartring met vier diamanten Ses spelien ieder met een diamant, een goude beuyeltas, twee goude doosses een paar Sardonir Steene hembds knoopen en vijff hondert tagentig pees losse paar„ „len Gaande de beide teslateuren ter finale dispositie over hes verklaarde de eerststervende de langstleevende van haar te nomineeren en institueeren tot zijn ofte haar E: eenige algeheele en universeele erfgenaam of erfgenaame den dat in alle ’t geen de eerststervende verder niet er door zal komen te ontruijmen naar te laten zoo roerende als on„ „reerende goederen, actien en Crediten niets uitgezonderd mits en onder dien verstande nogtans dat de langst „leerende gehouden en verpligt sal zijn aan haar E: bij den andere reets, verwekte dogtertje genaamd Christina Elisubeth, cud ruijm drie Jaaken hier vooren genoemd mitsg:s ter veriere kind off de kinderen waar van de Juffrouw teslatrice thans Swanger gaat item nog soodani „ge kinderen als sij testateuren bij den andere al verde mogte komen le prrccreeren uit te keeren de legitine portie, haar na regten Competeerende inititueerende alle dezelve, in zoo verre tot meede erfgenaamen met regt en titul van iuslitutie stellende Eligeerende en Conslitueerende de eerstster„ „rende der testateur en de Langstleevende van hun bewe tot executeur off executrice van deesen testament en van haar E: nalatenschap mitsg:s begraavenisse bezorger off bezog „ „ster ietem voogd off voogdesse over haar E natelatene onmondige Kinderen demandeerende elkanderren daar toe zoodanige last, magt en authoriteit als na regten kan werden vergunt Speciaal die van assumtie Substi„ „tutie en Surrogatie Sectudeerende dier halven st eerwaarde Collegie van Heeren Weesmesteren deser Steede en ten opzigt van den testateur de Heer Curalor ad Lites zoo als hier als elders niet ',
#   [(16, 26, 'GPE'),
#    (42, 61, 'PERSON'),
#    (86, 92, 'PERSON'),
#    (159, 178, 'PERSON'),
#    (183, 195, 'GPE'),
#    (211, 215, 'CARDINAL'),
#    (219, 225, 'CARDINAL'),
#    (255, 259, 'CARDINAL'),
#    (263, 270, 'CARDINAL'),
#    (299, 304, 'CARDINAL'),
#    (315, 319, 'CARDINAL'),
#    (397, 403, 'GPE'),
#    (428, 432, 'CARDINAL'),
#    (499, 503, 'CARDINAL'),
#    (527, 542, 'ORG'),
#    (561, 566, 'CARDINAL'),
#    (724, 734, 'GPE'),
#    (738, 750, 'GPE'),
#    (793, 804, 'GPE'),
#    (818, 832, 'PERSON'),
#    (904, 914, 'GPE'),
#    (970, 976, 'PERSON'),
#    (980, 988, 'PERSON'),
#    (1142, 1151, 'PERSON'),
#    (1160, 1179, 'PERSON'),
#    (1181, 1190, 'ORG'),
#    (1191, 1195, 'CARDINAL'),
#    (1276, 1295, 'PERSON'),
#    (1302, 1309, 'PERSON'),
#    (1465, 1478, 'NORP'),
#    (1531, 1542, 'GPE'),
#    (1555, 1575, 'PERSON'),
#    (1586, 1597, 'ORG'),
#    (1658, 1672, 'LAW'),
#    (1704, 1725, 'ORG'),
#    (1795, 1798, 'PERSON'),
#    (1813, 1818, 'PERSON'),
#    (1849, 1880, 'ORG'),
#    (1881, 1906, 'PERSON'),
#    (2011, 2017, 'ORG'),
#    (2118, 2124, 'GPE'),
#    (2160, 2172, 'PERSON')]),
#  'NL-HaNA_1.04.02_6847_0016': ('Zij dat dit instrument na een hunner verder overlijden van volk„ „men krogt en Effect wesen zal ¶ zij als testament Codicell of zodanige t zelve best na regten zal konnen bestaan schoon Eenige Solemnityten ten desen gerequireerd werden alle met na behooren mogten wesen g’obserteerd, Aldus gedaan ende gepasseerd ten huijze van de Testateuren van staande of de tijgersgragt binnen dese stad ter presentie Clercq: Abraham Salomons en Hendrik Abrahamsz als getriggen De minute deses is behoorlijk getekend en gesz: op een Zegul van Een Ed: /onderstond/ gnodaterston was getek:d Eggbert Blomhert /mots: naar gedaane Collatie is dese met dies origineel bevonden te accordeeren by my bovengenoemde nots alhier resideerende Natavo den 13: 8bert 1768: Marten Albregt Heynagtez N„o 3 op Heeden den 15: November 1768, Compareerde voor mij m:r Egbert Blomhert nots: pnbl: by de Edele hooge regeringe van nederlands Jordia G’admitteerd binnen de stad batera resideerende inde voor de naargenoemde getuggen mont Martin Albregt Heijnagtsz opsiender vande steen en beeldhomsers winkel in SE: Comp:s ambagts quartier alhier en woonagtig aldaar mij bek:d zijnde ziekelik van lichaam dog hebbende alle en Eijallens passeeren van een uywerste wille benodigt die mij notaris mek volkomen verstand en onverwaarde uytspraetie te kennen gaff uijt eijge vrije en onbedwongen wille sonder in duicke aff Bermatie van iemand genegen te zijn om over sijne natelatene goederen Testamentair te disponeeren invoegen doet bij deesen na voorgaan„ de revicatie van alle testamenten, soaicillein en andere makingen van uijterste wille door hem alleen, dan wel niet iemaent anders bevoorens gemaakt ofte gepasseerd, En op nieuws ter dispositie komende zoo verklaarde den testateur te prelegateeren aan de hier onderte noemene Erfgename Harmelina Calharina de slaaff September en Slavinneolinda aelse bij de van de mallebaar met Expresselijk begeerte dat twee slaeven bij haar zullen moeten blijven dienen en haar gs passen, vervolgens nu ter generale Ersstelling over gaande 2„ ver„ klaarde aen testateur / alsoo betuijgde geene onders in leeven te hebben, en ook geene kinderen als noet getrouwt geweest zijnde tot zijn Eenige algeheele en umireele Erfgename Goccoaama 555 ',
#   [(116, 124, 'GPE'),
#    (361, 373, 'NORP'),
#    (381, 385, 'NORP'),
#    (413, 429, 'PERSON'),
#    (433, 450, 'PERSON'),
#    (551, 563, 'PERSON'),
#    (576, 592, 'PERSON'),
#    (593, 598, 'PERSON'),
#    (613, 621, 'GPE'),
#    (698, 717, 'PERSON'),
#    (729, 731, 'CARDINAL'),
#    (733, 738, 'PERSON'),
#    (739, 743, 'DATE'),
#    (745, 769, 'PERSON'),
#    (774, 776, 'DATE'),
#    (790, 792, 'CARDINAL'),
#    (794, 807, 'DATE'),
#    (834, 848, 'PERSON'),
#    (856, 860, 'PERSON'),
#    (862, 873, 'WORK_OF_ART'),
#    (874, 889, 'GPE'),
#    (894, 911, 'GPE'),
#    (940, 946, 'GPE'),
#    (986, 999, 'PERSON'),
#    (1000, 1025, 'PERSON'),
#    (1074, 1076, 'PERCENT'),
#    (1078, 1082, 'EVENT'),
#    (1085, 1108, 'PERSON'),
#    (1146, 1166, 'PERSON'),
#    (1256, 1260, 'ORG'),
#    (1281, 1304, 'PERSON'),
#    (1340, 1351, 'NORP'),
#    (1368, 1374, 'PERSON'),
#    (1423, 1439, 'PERSON'),
#    (1465, 1476, 'GPE'),
#    (1495, 1501, 'PERSON'),
#    (1749, 1762, 'GPE'),
#    (1775, 1782, 'PERSON'),
#    (1801, 1820, 'PERSON'),
#    (1831, 1840, 'PERSON'),
#    (1852, 1858, 'PERSON'),
#    (1893, 1914, 'PRODUCT'),
#    (1919, 1923, 'CARDINAL'),
#    (1978, 1987, 'ORG'),
#    (2040, 2041, 'CARDINAL'),
#    (2148, 2152, 'PERSON'),
#    (2215, 2224, 'GPE')]),
#  'NL-HaNA_1.04.02_6847_0770': ("„ overlijven bij D'E: Comp zal te vooren staan, versoekt eligeert en Consti„ „lueert bij zier eerbiedig, de wel Edele Groot Agtb: Heeren BewinP. „hebberen der g'octroijeerde coptimischhe Comp:e tter Kamer Amstersan waar voor Thij affirmeerd uijt gevaaren te zijn ten einde de actribuliet daar van te doen aan de daartoe geregtigde Betuigende den tedtateur zijn boeiel geen twee Duijsend vijrd: te bedraegen Vorts heb ik Notaris gehucideert de seer gevenereerde  ordonnantje van de Edele Hooge Indjasche Regeering nopen de Lijl Eijgenen, die den Christelijke godsdienst Camplesteekt hebbe Alleste gunt voorsz: staat den Teblateur wel en Duijvelijk voor gehouden en bij hem zoo hij zeide wel verstaan, zijnde zk begeerde hij, dat dit instrument na zijn overlijden van volkomen kragt en effect wesen sal, t zij als, testament of Codicil van wel zoodanig alst best na regten sal konnen bestaan Schoon eenige Sylem„ niteiten ten desen, gerequireerd werdende alle niet na behooren mogte weezen g'ebserveert. DatBias passeerde ingt voorsz: quartier ten bijweesen van Freierih Balthazar Haaksz en de Johannes Lambertus Surriaande derequen als getuigen Ed: minute deses is behoorlijk geteekend en geschreeven op een zegul van een Ryxd: /onerfstond/ quor attestor / was geteekend/ L=l Rolff not=ar Jurriaan Martwyk Op Heeden den 2:e Junij 1778 Compareerde voor mij M:r Herman, Schelfus nota, publicq bijf de E: Hlaege Regeeringe van Nederlangs Indiag admitteer 91 binnen de stad Batavia resideerende present de natenoemene getuigen den E: Iurriaan Hartwijk voorleeser van de Casteele Capgelle ken dienst der Ed: Comp: woonende binnen de stad mi bekend Eijnse een E: Comparant zickelijk van Lighaam hebbende nna gezien zijn volkomen verstand en onverwaarde uit spraeke, te — kennen gevende genegen te weesen om uit eige vwijl en onloed wa „gen: Wille sonder meuctie by persuagie van heman Vourr zijne tijdelijke natelatene goederent testamentieire te dispo„ „neerten kevocatie mitsdren alle zijne voorige testamenten en Cadheillen Enve op nieuws disponeerende verklaerde den testateur iarankelijk geene schuld hoe genaamd aan wie het mogte zijn te hebben aan op zijn huijs ter somma van Negen hondert Rijxd=s verklaarende zijn E: verders geene ouders nog kinde „ven in ’t leven te hebben en bij omtreentenisse van dien tot zijn eenige algeheele en universeele erfgenaam te nomig „neerens en iublitueeren D' EJote aehem Plaat Boekhouder te dienst voorsz en dat in alle zijne natelatene goeveren soo roerende als onvoerende tem actien Creehten niets uitgesom Vat executeur van desen testamenten benorger van zyne begravenisse item Redderaar zijner Nalatenschap verklaar den teslateur te nomineeren en te stellen de boven genoeme E: Joan Jochem Klaat fleense aan den selven zodanige wijdlopige Last magt en authoriteit als na regten kan werden fgunt ",
#   [(17, 21, 'ORG'),
#    (22, 26, 'ORG'),
#    (57, 65, 'PERSON'),
#    (69, 75, 'GPE'),
#    (78, 84, 'PERSON'),
#    (118, 128, 'WORK_OF_ART'),
#    (130, 144, 'FAC'),
#    (146, 173, 'ORG'),
#    (187, 191, 'ORG'),
#    (205, 214, 'GPE'),
#    (225, 240, 'PERSON'),
#    (331, 355, 'ORG'),
#    (373, 377, 'CARDINAL'),
#    (378, 392, 'WORK_OF_ART'),
#    (420, 439, 'PERSON'),
#    (462, 486, 'PERSON'),
#    (487, 512, 'GPE'),
#    (522, 535, 'ORG'),
#    (545, 557, 'NORP'),
#    (636, 646, 'GPE'),
#    (707, 709, 'ORG'),
#    (791, 800, 'PERSON'),
#    (826, 833, 'ORG'),
#    (1020, 1031, 'PERSON'),
#    (1060, 1085, 'PERSON'),
#    (1092, 1119, 'PERSON'),
#    (1221, 1225, 'FAC'),
#    (1260, 1270, 'GPE'),
#    (1273, 1280, 'PERSON'),
#    (1288, 1304, 'PERSON'),
#    (1359, 1375, 'PERSON'),
#    (1401, 1407, 'GPE'),
#    (1408, 1433, 'PERSON'),
#    (1434, 1440, 'PERSON'),
#    (1451, 1454, 'DATE'),
#    (1469, 1476, 'GPE'),
#    (1529, 1546, 'PERSON'),
#    (1565, 1573, 'LOC'),
#    (1627, 1634, 'GPE'),
#    (1642, 1648, 'NORP'),
#    (1656, 1665, 'WORK_OF_ART'),
#    (1666, 1687, 'FAC'),
#    (1750, 1757, 'PERSON'),
#    (1804, 1814, 'PERSON'),
#    (1834, 1854, 'WORK_OF_ART'),
#    (1872, 1877, 'PERSON'),
#    (1878, 1883, 'PERSON'),
#    (1940, 1945, 'GPE'),
#    (1966, 1974, 'GPE'),
#    (2009, 2019, 'NORP'),
#    (2035, 2063, 'ORG'),
#    (2074, 2091, 'PERSON'),
#    (2176, 2181, 'NORP'),
#    (2190, 2195, 'GPE'),
#    (2198, 2210, 'GPE'),
#    (2337, 2348, 'GPE'),
#    (2362, 2368, 'PERSON'),
#    (2380, 2392, 'NORP'),
#    (2397, 2413, 'PERSON'),
#    (2457, 2482, 'PERSON'),
#    (2500, 2510, 'NORP'),
#    (2564, 2569, 'PERSON'),
#    (2618, 2627, 'NORP'),
#    (2628, 2647, 'PERSON'),
#    (2674, 2684, 'GPE'),
#    (2719, 2736, 'PERSON'),
#    (2737, 2759, 'PERSON'),
#    (2780, 2789, 'PERSON')]),
#  'NL-HaNA_1.04.02_6847_0017': ("„ 6  6  daerop vort gesteld EDet dhinden de testateur en op afvrage van mijn nots: te nomineeren en institueeren de Jonge dogter harmelina catarina on d oontren=k vier Jaaren en dat malle de verdere goederen zoo roerende als onroerende vemackien en crediten die hij testateur zal komen natelaten niets uijtgezondert met deese last nogthans dat al t am ven beengen Erfgen: my vhoogte deses zal komen te cuffenen Camen zoo zy voor haker mondige Jaaren off trouwdagen mogte komen te overlijden, in zijn geheel met de volle titl van Eijgendom zal moeten gaan en devolveeren op Jnsf=m Anna magdalena dors Laost wed: van Pan Jonas ofte derselver kinderen bij rappresentihe die de Testavenr verklaarde in zodanig geval tot zennen van zyn nala tenschap te Lobsschiteren wel verstaande nogthans detvoornoemde Harmelina Catharina tot mondege Jaaren oft huwelijken staat gekomen, en dus aan eene der voorsz: twee Conditien door haar voldaan zijnde van die last ten Eenemaalen ontheft ende vrije dispositie over deete Erffenisse hebben zal: Sallen de Regeerende en Consfatueerende den testateur met Eerbie dige Eeclusie van het berw: Collegie van heeren weem: en H:s Curakir adlites zoo hier als Elders met Jegenstaande mijne gedaane preadvertentie, tot Executeurs deser testamente begravenis besoo„ gerzen redderaars zijner boedel en nalatensz: milsg: eogden op de persoone ende uijtkrogte deses te Ervene Goederen en penn van de onmondige Erfgename de mons: Cornelis de keijder op„ permandadoor en peeter Eelders boekh: beijde in sE: Comp:s am„ bagts Quartier alhier, gevende hun zoo te samen als ieder afson„ derlik zodanige last magt en anprriteijt, als na regten kan wer„ den vergunt onder des die van assunntie subssitutie en surrogatie verklaarende wijders den testateur seer ootmoedig te Eligeeren en Ver Comsitneeren tot Executeur over zijne bij dE: somp: te goed hebbende maandgelaen de Ed:e groot agtb: heeren bewindhebberen der g'ochog„ eerde dost indische Comp:e ter kamer amst: waar voor den testateur afsiermeerde vijtgevaeren te zijn ten eijnde door haar Ed:s groot agtb: uytgekeerd te werden aan de geene die daar toe geregtigde zullen zijn, Laastelijk betuijgde aen testateur op mijne gedaane vraage in gevolge de ordonn: van 1 kl: zegul dat sijn boedel geen twee duijsend 20. is bedragende zullende de Executeur en zorge moeten dragen om van alle de gaste goederen die door den zessateur nagelaten mogten werden binnen drie maanden na zij afsterven acte van overschrijving op de naam van de Erfganant tedoen ter voldoening aan de ordre van haar hoog Raelens d’ Edele hooge regering deser landen daar op vast gesteld; alle t gunt voorsz stoot aen teslateur duijdelijk voorgehouden en bij ",
#   [(2, 3, 'CARDINAL'),
#    (5, 6, 'CARDINAL'),
#    (28, 32, 'CARDINAL'),
#    (86, 96, 'GPE'),
#    (100, 112, 'GPE'),
#    (129, 147, 'PERSON'),
#    (249, 257, 'PERSON'),
#    (302, 315, 'PERSON'),
#    (331, 339, 'PERSON'),
#    (347, 349, 'ORG'),
#    (349, 363, 'WORK_OF_ART'),
#    (372, 382, 'PERSON'),
#    (529, 538, 'ORG'),
#    (558, 569, 'GPE'),
#    (573, 577, 'LANGUAGE'),
#    (580, 594, 'PERSON'),
#    (600, 605, 'ORG'),
#    (615, 624, 'PERSON'),
#    (653, 667, 'PERSON'),
#    (674, 683, 'PERSON'),
#    (716, 722, 'NORP'),
#    (748, 761, 'GPE'),
#    (766, 799, 'ORG'),
#    (800, 819, 'PERSON'),
#    (880, 895, 'PERSON'),
#    (897, 901, 'CARDINAL'),
#    (902, 911, 'WORK_OF_ART'),
#    (954, 964, 'NORP'),
#    (1039, 1049, 'EVENT'),
#    (1099, 1107, 'PERSON'),
#    (1195, 1213, 'WORK_OF_ART'),
#    (1323, 1332, 'NORP'),
#    (1334, 1339, 'GPE'),
#    (1341, 1348, 'DATE'),
#    (1368, 1384, 'ORG'),
#    (1388, 1394, 'GPE'),
#    (1429, 1438, 'GPE'),
#    (1448, 1467, 'PERSON'),
#    (1488, 1502, 'PERSON'),
#    (1503, 1508, 'PERSON'),
#    (1520, 1522, 'PERSON'),
#    (1524, 1528, 'EVENT'),
#    (1535, 1556, 'PERSON'),
#    (1629, 1640, 'PERSON'),
#    (1766, 1780, 'PERSON'),
#    (1784, 1793, 'GPE'),
#    (1843, 1845, 'GPE'),
#    (1882, 1887, 'PERSON'),
#    (1888, 1889, 'ORDINAL'),
#    (1902, 1935, 'PERSON'),
#    (1943, 1947, 'PERSON'),
#    (1948, 1961, 'ORG'),
#    (1974, 1978, 'ORG'),
#    (2059, 2061, 'PERSON'),
#    (2232, 2233, 'CARDINAL'),
#    (2265, 2269, 'CARDINAL'),
#    (2279, 2281, 'CARDINAL'),
#    (2309, 2318, 'GPE'),
#    (2426, 2438, 'DATE'),
#    (2498, 2507, 'ORG')]),
#  'NL-HaNA_1.04.02_6847_0771': ("6 ergunt Speciaal die van assumtie sulestitutie en byrdogde  Begeerende den Testateur op het binnen portugeer kershoff begraaven te werden en vat zijnelijk op de allerso= beste wijse onder aanspreekers ter aasde besteld sal werden  Als meere gat aan zijne slaven inder een htel gouve knopen in hunne kuttjes zal gegeven worden en dat zij al het geene in haare kisten gevonden vor sullen behoue — Leeludeerende den ETestateur met de Vereijschte eerbied uijt zijn Nalatenschap het Eerw Collegie van 't Heeren weesmesteren nevens de Heeren Curatiren ad Lites zo hier als ter plaatse daar zijn testateurs sterfhuijs verstaan mogte werden gevallen te zijn haar Eerw: en E: voorder zelver andersints daar omtrent te nemene moeijten, en sorge reverentelijk bevankende onaangezien mijne dien aangaande aan Een E: testateur gevaene pread„ „vertantie Maar tot executeurs op zijne testateurs lergeer behoudene gage versoekt Eligeeren en Constitueeren zijn E: zeer eerbe „diglijk de hoog Edele groot Agtb: Heeren Berind hebberen der g'eetregeerde d tindinhe Comp:e ter Kamer Amsterdam waar voor den teslateur afirmeerd in Dienst aangenomen en uijtgevaren te zijn ten einde door haar EE: groot Agtb: uijtgekeert te werden aan de geene die uijtkragt deesen tot dies ontvangst zal wesen gequalificeert Betuigende den E: testateur op mijne gedaane vrage dat zijn boedel beneeven de twee duijsent rijze: was beddaagende Vorts heb ik Notaris den testateur gepreaiverteert dat zijn E: voornoemde execuleur en enlgenaame voor al Sorge 2 sal moeten dragen dat de vaste goederen door zijn E: nate alen binnen de drie maande na zijn overlijsen op de naam 2 w hemexecuteur en Erfgenaam werden overgeschreeven in gening aan de gevenereerde ordres door haar hoog reeden de hooge Erigheijd deser Landen in Cassubijeer esteld orts Feb ik Notaris Een E: testateur behoorlijk lasmeerd van de Jongste besluijten door haar hoog Edelh: elmeli ten opsigte van de lijfeigenen die gedoopt en in de Cchristelijks leere onderweezen zijn Successive aangenomen M guntt Viersz: Staat den Etectateur wel en Drijvelijk voorgehouden en door zijn E: zoo hij betuigde wel verstand  sijnde begeerde hij dat dit instrument na zijn oferlijven van volkomen Effect ",
#   [(0, 2, 'DATE'),
#    (61, 85, 'ORG'),
#    (162, 182, 'ORG'),
#    (278, 284, 'PERSON'),
#    (410, 424, 'GPE'),
#    (432, 443, 'NORP'),
#    (479, 499, 'ORG'),
#    (530, 546, 'LOC'),
#    (710, 725, 'PERSON'),
#    (730, 749, 'PERSON'),
#    (815, 828, 'PERSON'),
#    (913, 922, 'LANGUAGE'),
#    (960, 975, 'PERSON'),
#    (1035, 1050, 'ORG'),
#    (1063, 1072, 'GPE'),
#    (1131, 1142, 'ORG'),
#    (1171, 1173, 'EVENT'),
#    (1187, 1198, 'PERSON'),
#    (1226, 1235, 'NORP'),
#    (1266, 1286, 'PERSON'),
#    (1354, 1362, 'FAC'),
#    (1366, 1370, 'CARDINAL'),
#    (1371, 1379, 'NORP'),
#    (1380, 1385, 'ORG'),
#    (1416, 1427, 'PERSON'),
#    (1438, 1453, 'PERSON'),
#    (1509, 1514, 'PERSON'),
#    (1590, 1601, 'DATE'),
#    (1632, 1633, 'CARDINAL'),
#    (1652, 1661, 'PERSON'),
#    (1753, 1775, 'PERSON'),
#    (1779, 1790, 'GPE'),
#    (1803, 1809, 'PERSON'),
#    (1862, 1869, 'ORDINAL'),
#    (1896, 1901, 'PERSON'),
#    (1962, 1975, 'LANGUAGE'),
#    (1999, 2009, 'FAC'),
#    (2065, 2076, 'ORG')]),
#  'NL-HaNA_1.04.02_6847_0765': ("niet tegenstaande de preadvertantie dien aangaande gedaan Maar tot Executeurs over de maand gelden die hij testuteur op zijn afsterven by de E: Comp sulle goed behouden versoekt en Conslitueerd zijn E: eerlliediglijk de wel E: aroot Agtbaare heeren bezin hebberen der g'Ectroijeerde oostjndische Comp: ter Kamer Amsterdam waar voor den selven affirmeerd uit tevaaren te zijn, om de distributie van dien te doen aan de geene welke daar toe geregtig sullen zijn En Sal de testatrice de langst leevende blijvende zorge gelieven te draagen dat alle de vaste goeveren van haar gemeenen boedel, binnen drie maanden na de dood van den teslateur op haar E: naam werden overschreeven ter volioe„ ^Indiasche ning aan de door de Edele Hooge, regeeringe in Cus subject Vast gestelde ordre Laastelijk verklaarde de testateuren aan hun te behouden de magt en faculteit om dese haar E: testamentuire dispositie ten allen tijden, bij onderhandsche door haar E: te zaamen off ieder afzondellijk geteekende memorien off geschriften te konnen en mogen veranderen vermeerderen en vermin„ „deren namentlijk legaaten en prelegaaten bij en af te doen, lijff eigenen te Emancipeeren, dit gedaan zijnde weder te revoceeren en voorts daar omtrent alle andere voorsie„ „ninge te maaken soo als de testateuren te raden veerden sullen willende en begeerende dat al ’t selve van Even= gelijk kragt en waarde sal werden gehouden als off te hier inne woordelijk stonde ginfereert van wel voor notaris en geluigen waren gepasseert alle het gunt voorschreeven staat re testateuren wel en Duijdelijk voorgelesen en bij haur E: zoo de zelve betuigden wel verstaan zijnde soobegeerde haar E: dat het zelve na een harer beide overlijden van volkomen kragt en effect weesen zal st zij als testament, Codicil of te zoodanige als het best na regten sal kunnen bestaan schoon eenige Solemniteiten, ten desen gerequireerd werdende alle niet na behooren mogten weesen g'observeert Aldus gedaan ende getesleerd Een huisen van de testa„ teuren in ’t bijwijsen van Zavie Iansz en frederitius Conslantijn Gerrit, Clercquen als getuigen De minut deses is behoorlijk geteekend en geschreeven op een zeghel van thien sijrd:s /onder stond / quad attestors was geteekend/ L: Rolff notaris Uit kragte van de Clausule reservaloire vervat in onse testament ",
#   [(144, 168, 'WORK_OF_ART'),
#    (181, 193, 'ORG'),
#    (249, 254, 'GPE'),
#    (255, 282, 'ORG'),
#    (296, 300, 'ORG'),
#    (312, 321, 'GPE'),
#    (596, 608, 'DATE'),
#    (661, 685, 'PERSON'),
#    (687, 702, 'ORG'),
#    (724, 729, 'GPE'),
#    (745, 748, 'GPE'),
#    (989, 1001, 'PERSON'),
#    (1069, 1085, 'PERSON'),
#    (1129, 1134, 'GPE'),
#    (1146, 1158, 'GPE'),
#    (1187, 1197, 'GPE'),
#    (1243, 1248, 'GPE'),
#    (1336, 1348, 'WORK_OF_ART'),
#    (1437, 1447, 'PERSON'),
#    (1584, 1590, 'PRODUCT'),
#    (1728, 1734, 'PERSON'),
#    (1739, 1741, 'ORG'),
#    (1761, 1768, 'ORG'),
#    (2001, 2013, 'WORK_OF_ART'),
#    (2018, 2029, 'PERSON'),
#    (2033, 2063, 'PERSON'),
#    (2065, 2074, 'PERSON'),
#    (2160, 2171, 'PERSON'),
#    (2174, 2180, 'GPE'),
#    (2208, 2218, 'GPE'),
#    (2219, 2227, 'PERSON'),
#    (2254, 2275, 'WORK_OF_ART')]),
#  'NL-HaNA_1.04.02_6847_0759': ("„ langstleevende gehoudenen verpligt zal zijn het kind of de kinderen die het den Eerwel behagen mogt aan hun E: te schenken, en het welke dezelve in hun ruwelijk verzekt zullen komen nalaten eerlijk te alimenteeren en op te roeden och te oefenen en onderwijsen in sodanige Stijl, oeffening, en hangteering als de langstleevende tot niet van zoodanige kind of kinderien zal bevinden te behoo„ ren En dat den langstlezenden boven dien gehouden en verpligt zal zijn aan zoodanige kind of kinderen wanneer tot meerder Jaarighp dan wel bij eerder huwelijk, of tot een ander g'approbeerde staat gekomen is of zullen zijn uit te keeren, en te laten volgen zoda nige Sommel van penningen als den Langstleevenge na den Staar En geleegendheijd des boedels in Conscrentje oordeelen en bevinden zal, te behooren en dat alles in plaatse van desselfs en der zilver legitime portie die hun of kinderen uit hunner ouders agter gelaaten boedel na regten Competeerde daar inne en in meer„ „der of anders met nomneerd en institueerd de eerststervende hit zelf of dezelve tot zijn teslateurs of haar testatrices meede erfgenaam of erfgenaamen Dog of het zaae waaren dat zij testatrice Eerst en zulke voor haure man testateur, kwam te overlijven, zonder kind of kinderen tijd elkanderen, versiekt in hett leven natelaten en dat als dan har testatrices ouders of een van dezelven nog in het leven is in dit geval maar anders niet verklaarde zij testatrice haar begeerte en uisterste wille te zijn dat den langst levenden testateur beiden 't semen of aan den geene die van Run in ’t leven is uitkeeren laten, volgen zodanige Somme penningen als hun af dezelve voor de legitime portie bevonden zal worden te Competeeren Dewijl zij dezelve daar in en gog in meerder of anders niet in Cas hier voor en gemeld als meede erfgenaamen of erfgenaam nomineerd en institueerd bij deesen Tot executeur of executiuees van Wit hun testament en begrave„ „nisse bezorger of besorgeresse van den eerststervende mitsg:s hooge, of boogeefse overt hun mindere Jaarig nate laten Nind of hinderen verklaarden de testateuren Pecipreque over en weder over en zulks de uiststervende de langstleevende te nomineeren, en te institueeren de eerststervende de langstleeven „de van hun beiden geevende aan zijn of haar E: alle zodanige magt last en aulhariteit als na regten kan of mag gegeeven worden als meede magt van assumtie en susnogatie tot het einde van het executeur of vocgvijschap toe ook om vaste en andere goederen te mogen verhoopen en transporteeren, en dat alles buijten eenige gezag magtt en authoriteit van vrienden Heeren magistraalen, geregten weesmeesteren, Curatier adliles of alle e zodanige die daar over eenig gezag magten authoriteit zouden mogen of behooren te hebben, terwwijl alle de zelven of een ieder van hun in t bijzonder voor De andezints te neemene moeijten eerbiedig bedankende en daar van excuseeren mitsg:s uits hun teslateurs respective agter te laten boddel secludeeren by deesen niet tegenstaande de testateuren van inhoud Kragt ende gevolge deeser seclusie door mij behoorlijk waar en ondervigt Dog ten reguard van des teslateurs te goed hebbende maar gelden verzoekt en eligeert hij lot executeuren over dezelve de wel Edele groot Agtbaare Heeren bewinehebberen tr Kamer Amsterdam waar voor den testateur in den Iaar een duijsend Zeven hondert een en Seventig voor proponent van de Gerefor„ „meerde „ ",
#   [(154, 170, 'PERSON'),
#    (250, 261, 'GPE'),
#    (314, 329, 'DATE'),
#    (386, 391, 'GPE'),
#    (515, 523, 'GPE'),
#    (685, 703, 'PERSON'),
#    (750, 761, 'GPE'),
#    (938, 949, 'GPE'),
#    (955, 959, 'GPE'),
#    (1268, 1276, 'PERSON'),
#    (1280, 1284, 'PERSON'),
#    (1316, 1331, 'PERSON'),
#    (1452, 1461, 'PERSON'),
#    (1551, 1566, 'EVENT'),
#    (1570, 1580, 'EVENT'),
#    (1603, 1608, 'GPE'),
#    (1727, 1730, 'ORG'),
#    (1794, 1805, 'GPE'),
#    (1848, 1855, 'PERSON'),
#    (1872, 1891, 'ORG'),
#    (1919, 1924, 'GPE'),
#    (1937, 1949, 'GPE'),
#    (1973, 1978, 'PERSON'),
#    (1991, 2000, 'ORG'),
#    (2019, 2030, 'ORG'),
#    (2037, 2042, 'ORG'),
#    (2069, 2091, 'GPE'),
#    (2123, 2154, 'GPE'),
#    (2176, 2188, 'FAC'),
#    (2298, 2309, 'LOC'),
#    (2370, 2378, 'GPE'),
#    (2486, 2495, 'GPE'),
#    (2499, 2513, 'PERSON'),
#    (2549, 2554, 'GPE'),
#    (2613, 2626, 'GPE'),
#    (2628, 2636, 'GPE'),
#    (2813, 2822, 'PERSON'),
#    (2876, 2886, 'NORP'),
#    (2887, 2892, 'PERSON'),
#    (2941, 2959, 'PERSON'),
#    (3014, 3048, 'PERSON'),
#    (3087, 3110, 'WORK_OF_ART'),
#    (3163, 3171, 'ORG'),
#    (3180, 3191, 'NORP'),
#    (3224, 3232, 'LOC'),
#    (3264, 3273, 'GPE'),
#    (3301, 3309, 'PERSON'),
#    (3323, 3336, 'EVENT'),
#    (3344, 3352, 'NORP'),
#    (3375, 3382, 'ORG')]),
#  'NL-HaNA_1.04.02_6847_0029': ("als zij testateuren staande huwelyk zullen komen te verwecken uijt tekeeren de legiti„ me portie de wettige kinderen na regten Competeerende institueerende den zelven of deselve daar in tot hunne Erfgenaam of Erfgenamen bij desen en dit alles zonder aftrek van eenige tribelliamqne of falndie portie hoe gen: of in Regten bekend; Edogh vn dier het geleiren mogte dat de Jnt=r tes tadrice keteerst en sulx voor den peer sestateur dit sterffelyke mogte verlaten, zonder kind of kinderen natelaten zo verklaarde zij de voorsz: begiteme portie met regt en tihe als vooren te bespreken aan haar moeden Juff=mo sersanna van Maccasser wed:e van den overt baas der loodgieters dE: Bensamen Grebel verklaarende den heer testatent geen onder en leeven tehebben stallende eligeerende en Constitueerende de Eerst stervende de testa„ teuren de Langstleevende van huw beyde ook tot Executeur of Executrice dezer testamente begrafenis bezorger of besorgster item voogd fvoog„ derse over hunne natelatene onmondige kind of kinderen, den teshtenr daar onder zijn voorsz: natuurlijke dogter meede begrijpende en dat met zodanige ample last magt en anmhoriseijt als daar toe na regten kan werden vergunts speciaal die van aisnintie Subssihihe en surrogake Secludeerende dien volgende 2 berw: Collegie van heeren weesm: deser Rede den b„e snoatsr aalites en alle andere magistraats benoonen zoo heep als baers niet tegenstaande de prea arrntenlie dienaangaande gedaan maar tot Executeurs over des testateurs te goed te hondene gagie ver„ zoekt Eligeerden Constitreerd hij zeer eerbiedig d Edele groozagst: heeren bewind hebberen de geoctroijeerde orst indische Compagnie ter kimer Amstver: waar voor hij testateur aftiermeerd uijtgevaeren te zijn ten eijnde door haar Ed: Groot agtb: uijtgekeerd te werden aan de geene die tot denont„ fangst zal wesen gequalificeerd Laastelyk verklaarden de beyde testateuren hiet inne te intereeren 6 de Clausile Reservatoir en uijt krogte van dien aan haar te behouden 6 de mogt en Facultijt omme dese hare Testamentaire dis posike bij onderhandsche door haar te zamen of eeder afzonderlijk gebekende pnemorien off geschriften zodanig te kunnen en mogen veranderen ver„ meerderen of verminderen als zijse rade werden mogten, wellende en begeerende dat al het zelve van zodanige krogt en waarde zal werden gehouden als of het hier inne woordelijk ware ginsereerd Alle 2 gunt voorsz vtaat de testateuren duijdelijk voorgelesen ee bij haar zoo zij betuijgden wel verstaan zijnde zoo begeerden zij dat dit indhriment na een horer beijde overlijden van volkomen kragt en EWert wesen zal het zij als testament sodicil of zodanig het zelve fest zal konnen bestaan schoon eenige solanmitieen ten desen gerequireerd werdende met ten vollen noren g'insereerd Dat aldus passeerde ten huijse van de testateuren ten bijwesen van Darr 8 arons Bilsoork en Joseph Plache mijne cbercq: als getuigen, ",
#   [(67, 75, 'GPE'),
#    (127, 140, 'NORP'),
#    (196, 205, 'PERSON'),
#    (209, 219, 'GPE'),
#    (285, 292, 'NORP'),
#    (330, 338, 'NORP'),
#    (370, 373, 'ORG'),
#    (419, 444, 'PERSON'),
#    (485, 494, 'PERSON'),
#    (552, 556, 'PERSON'),
#    (597, 601, 'ORG'),
#    (605, 627, 'PERSON'),
#    (632, 641, 'EVENT'),
#    (669, 671, 'GPE'),
#    (673, 688, 'PERSON'),
#    (711, 720, 'PERSON'),
#    (831, 877, 'ORG'),
#    (881, 891, 'ORG'),
#    (954, 959, 'PERSON'),
#    (978, 988, 'PERSON'),
#    (1130, 1142, 'PERSON'),
#    (1177, 1185, 'PERSON'),
#    (1213, 1223, 'PERSON'),
#    (1265, 1266, 'CARDINAL'),
#    (1267, 1271, 'NORP'),
#    (1273, 1292, 'ORG'),
#    (1300, 1310, 'PERCENT'),
#    (1319, 1334, 'PERSON'),
#    (1350, 1361, 'NORP'),
#    (1362, 1370, 'NORP'),
#    (1371, 1379, 'PERSON'),
#    (1411, 1415, 'PERSON'),
#    (1457, 1467, 'GPE'),
#    (1499, 1506, 'GPE'),
#    (1524, 1534, 'PERSON'),
#    (1575, 1584, 'GPE'),
#    (1612, 1626, 'GPE'),
#    (1632, 1650, 'ORG'),
#    (1661, 1669, 'GPE'),
#    (1807, 1813, 'GPE'),
#    (1826, 1831, 'PERSON'),
#    (1872, 1899, 'EVENT'),
#    (1903, 1913, 'GPE'),
#    (1914, 1916, 'DATE'),
#    (1919, 1939, 'PERSON'),
#    (1998, 2017, 'PERSON'),
#    (2215, 2220, 'GPE'),
#    (2221, 2225, 'ORG'),
#    (2294, 2299, 'PERSON'),
#    (2346, 2350, 'PERSON'),
#    (2383, 2384, 'CARDINAL'),
#    (2397, 2402, 'GPE'),
#    (2418, 2428, 'GPE'),
#    (2536, 2541, 'NORP'),
#    (2582, 2593, 'EVENT'),
#    (2837, 2838, 'CARDINAL'),
#    (2839, 2853, 'PERSON'),
#    (2857, 2870, 'PERSON')]),
#  'NL-HaNA_1.04.02_6847_0015': ('daerop vost gesteld Ne1oden de testateur en op afvrage van mijn nots:  woonagtig te voldoen al legitime portie de welke zijn gemelte groot moeder bij representatie van zijne overleedene onders uijtdes hesbteni nala„ benschap na regten is Competeerende, Zoo meede verklaarde de testatrice ingevalle zij voor naar manden Testateur moesen mogte komen te overlijden dat als dan den Tessateur verobligeerd zal welsen aan haar moeder mesust=r Hester IacobaLe grand wed:e wijlen dE: Guillianr Gerard Franchimont pn l/ nots: te deser steede uijt te keeren de legitime portie al onder na regten Competeerende Instilneerende de restpsenren in zodanige gevlle haar E:s in zoo verre tot zijn ofte haare meede Erfgename bij desen en dat meede met volle regt en titul van institutie, Stellende Eligeerende en Constitueerende de Eerststervende den testa„ „temren tot E recutemen of Executrice deser testamente redderaer ofredderaarster zijner off haarer boedel en nalatenschap besor ger o besoroster zijner off harer begraffenisse item zoo tot vesiende regeerende als administreerende voogd off voogdesse over hunne natelatene kend gf kinderen en der selver uyt krgte deses te bhamne goederen en pem: de langs seevende hunne beiden en dat met toeereginge van zodanige ample last magt en gezag als daar toe na regten kan werden Vergunt onver des die van assumtie Substitutie en Lirrogatie, serludeerende mitsaeen met alle Eerbied t Eerw: Collegie van peeren weesm: en dE Curatoren adlites zoo te deser als alle andere Plaatsen alwaar aer Testateuren zergeval mogte komen tevallen mer eew en Ed: voor des zelvs anders aan te wendene moelte re„ verentelijk bedankende bij deesen. Jnhaar tot Executeirs op als restakenrd te goed behondene gogie ver„ Laeks en Constitueerd hij zeer Eerbiedig de wel Ed:e groot agt: heeren bewind hebberen der geoctroijeerde oost indische Comp:e ter kamer am„ Herdan waar voor hij afjermeerd uitgevaaren te Zijn met beede dien aangaande te willen handelen zoo als hun Edele groet agtb: zullen bevinden te behooren En betuyg den de testateuren op mijne gedaane vraege ingevolge De ordonn: vant klein Zegal dot hunne gemeenen boedel geen twee duysend rd: is bedragende en zal de Testatrice wanneer zij de langs„ leevende zij voor al moeten zorge drogen dat alle de vastegoe„ deren mit hmme gemeenen boedel zoo als ze door den testateur met en dood werden nagelaten behoorl: op haer naem werden opgeschreeven binnen drie maanden na zijn asterven ter voldoening aan de ordre harer hoog Edelens in Cas subject, Alle t gint voorsz: staat de testateuren dugdelijk voor ge„ houden en bij pun zoo zij betuijgden wel verstaan zynde zoo begeerde ',
#   [(0, 11, 'PERSON'),
#    (20, 27, 'PERSON'),
#    (95, 103, 'PERSON'),
#    (168, 185, 'PERSON'),
#    (210, 214, 'PERSON'),
#    (238, 251, 'ORG'),
#    (428, 434, 'PERSON'),
#    (437, 452, 'PERSON'),
#    (453, 462, 'PERSON'),
#    (463, 464, 'ORDINAL'),
#    (476, 504, 'PERSON'),
#    (505, 510, 'ORG'),
#    (520, 525, 'GPE'),
#    (551, 559, 'PERSON'),
#    (586, 600, 'ORG'),
#    (615, 629, 'PERSON'),
#    (697, 706, 'GPE'),
#    (711, 716, 'PERSON'),
#    (748, 768, 'PERSON'),
#    (770, 838, 'ORG'),
#    (852, 863, 'WORK_OF_ART'),
#    (867, 877, 'ORG'),
#    (921, 945, 'PERSON'),
#    (962, 968, 'PERSON'),
#    (1029, 1048, 'ORG'),
#    (1053, 1069, 'NORP'),
#    (1101, 1112, 'PERSON'),
#    (1117, 1128, 'PERSON'),
#    (1143, 1158, 'PERSON'),
#    (1181, 1184, 'ORG'),
#    (1388, 1396, 'PERSON'),
#    (1406, 1413, 'NORP'),
#    (1414, 1420, 'PERSON'),
#    (1452, 1464, 'ORG'),
#    (1465, 1476, 'PERSON'),
#    (1480, 1485, 'GPE'),
#    (1518, 1533, 'PERSON'),
#    (1534, 1542, 'EVENT'),
#    (1575, 1577, 'PERSON'),
#    (1608, 1615, 'GPE'),
#    (1616, 1622, 'PERSON'),
#    (1673, 1683, 'GPE'),
#    (1691, 1701, 'GPE'),
#    (1710, 1719, 'GPE'),
#    (1779, 1781, 'PERSON'),
#    (1809, 1836, 'PERSON'),
#    (1842, 1855, 'ORG'),
#    (1868, 1878, 'GPE'),
#    (1928, 1933, 'GPE'),
#    (2029, 2039, 'ORG'),
#    (2072, 2078, 'ORG'),
#    (2100, 2110, 'WORK_OF_ART'),
#    (2111, 2116, 'LANGUAGE'),
#    (2117, 2142, 'PERSON'),
#    (2148, 2153, 'DATE'),
#    (2189, 2199, 'ORG'),
#    (2375, 2382, 'ORG'),
#    (2387, 2396, 'PERSON'),
#    (2425, 2437, 'DATE'),
#    (2505, 2508, 'PERSON'),
#    (2559, 2576, 'PERSON'),
#    (2592, 2599, 'ORG'),
#    (2628, 2637, 'PERSON')]),
#  'NL-HaNA_1.04.02_6847_0767': ("Ernst Bren verstlaan zijnde en begeerde hy dit dit instrument van volktmen kragt en Effect weesen sal ’t zij als testament of Codicit dan wel zodanige valst lest na Regten sal konnen bestaan, Schoon eenige Solemniteiten ten desen gerequireerd weesende alle niet na behooren mogten weesen g’blesertveerde Dat aldus passeerde ten huijse van den testaleur ten bijweesen van Frredericus Censlantijn Gerritszende Fredetik Balthajare Isaaksz, Clercquen als getuigen„ De minute deeses is behoorlijk geteekend en gesz: op een zegel van een Rijxd.s sonder stondt qudd attestor /was geteekend/ Rol notaris ster zeijde storu / dit testament is alhier ter weesk geleeen en geregistreert ingevolge Heere weesmeesteren Resolutie van dalo deeses Batavia Vin weerk: den 22: April 1778: /was geteekend, H: N: Laelé secretaris Op Huyden Den 23: Maart A:o 1778: mpareerde voor mij M:r Anthonij Cornelis Verspijk notaris Epulblicq bij de Edele Hooge Regeeringe van Nederlakds India g’admilleert, binnen de slaet Batavia Resiveerende present de na te noemene getuigen DE: Ernst Brein Boekhouder in Dienst der E: Comp: woonende alhier wij bekend Dewelke verklaarde te Constitueeren ende magtig te maken de Heeren Jan Andries Duur Koop d Majoor dit der Jnsanler al hier Abraham Walkard oud onverkoopman ten dienst voorschreeven en binnen Regent van het Chineese korpitaal alhier te zamen of ieder in ’t bijonder genegdelijk omme zijn persoon alhier en alomme Jaar t noodige soude mogen weesen te representeerd en uijt dien hoofd alle zne zaaken en affwas met dies af en depensentie te verrigtenen uijt te voeren, alle uijtstaende schelden Erffenis sen en bestervenissen soo er mogte zijn te vorderen en onder't behoorlyke quittantien ontvangen vaste als andere goederen en 4 lijf eigenen te mogen kopen en verkopen daar, van behoorlijk opdragten en transportenr na de retten en Custumen van den Lande voor de geen die daar toe gautporiseert zijn te passeeren als meede te aanvaarden en onder hunne E: te staan alle sodanige goederen, penningen ende missives als aan den Cnstituae of aan de geconslitueerdens, van wegens den Conslituant af aan de geconstitueerdens van wegen den Conslituant uit eenige quartie, „ren alhier gezonden of ove gemaekt soude mogen werden en daar smeede te oent en handelen ten meeste nutte en profijte van den Conslituant Tit alles in der minne is het doenlijk afte zo niet de onwillige weder strevige, quade Betaale ersch partije voegende per soonen door middelen tot betaaling en Situsfactie te Constringeeren, Voorts alle regte saeken Liie den  mparant heeft of te nog souve mogent opkomen so pro als Comtia waar te neemen en in dat geval alle Soo Substantielie als pccidentelle als gecidentelle ter mijnen van regten te observeeren en tot sententien te besollicileeren, de voordeelig na haar forma en inhoude ter Executie te stellen, of zo en stellen en van de nadeelig te proipceeren appelleeren of reformeeren mitsg:s des geraden vindende te mogen accordeeren, Com„ „promillegen ",
#   [(0, 10, 'PERSON'),
#    (126, 137, 'PERSON'),
#    (328, 342, 'PERSON'),
#    (371, 403, 'PERSON'),
#    (408, 435, 'PERSON'),
#    (437, 446, 'PERSON'),
#    (584, 587, 'PERSON'),
#    (644, 649, 'GPE'),
#    (650, 658, 'PERSON'),
#    (685, 704, 'PERSON'),
#    (731, 738, 'GPE'),
#    (739, 748, 'FAC'),
#    (754, 756, 'CARDINAL'),
#    (758, 763, 'EVENT'),
#    (764, 768, 'DATE'),
#    (770, 784, 'WORK_OF_ART'),
#    (789, 790, 'LANGUAGE'),
#    (792, 797, 'LANGUAGE'),
#    (809, 818, 'ORG'),
#    (823, 825, 'CARDINAL'),
#    (827, 832, 'DATE'),
#    (837, 841, 'DATE'),
#    (866, 892, 'PERSON'),
#    (901, 910, 'WORK_OF_ART'),
#    (945, 955, 'NORP'),
#    (956, 961, 'GPE'),
#    (992, 999, 'GPE'),
#    (1047, 1049, 'PERSON'),
#    (1051, 1062, 'PERSON'),
#    (1091, 1095, 'WORK_OF_ART'),
#    (1146, 1171, 'PERSON'),
#    (1191, 1212, 'PERSON'),
#    (1247, 1262, 'PERSON'),
#    (1315, 1329, 'PERSON'),
#    (1330, 1338, 'LANGUAGE'),
#    (1339, 1355, 'PERSON'),
#    (1377, 1405, 'FAC'),
#    (1441, 1456, 'WORK_OF_ART'),
#    (1525, 1531, 'GPE'),
#    (1750, 1751, 'CARDINAL'),
#    (1826, 1838, 'GPE'),
#    (1855, 1863, 'GPE'),
#    (1904, 1917, 'PERSON'),
#    (2047, 2057, 'ORG'),
#    (2211, 2228, 'PERSON'),
#    (2250, 2256, 'PERSON'),
#    (2314, 2325, 'ORG'),
#    (2397, 2405, 'GPE'),
#    (2407, 2412, 'GPE'),
#    (2421, 2427, 'PERSON'),
#    (2501, 2515, 'FAC'),
#    (2552, 2559, 'GPE'),
#    (2576, 2588, 'PERSON'),
#    (2608, 2614, 'ORG'),
#    (2651, 2654, 'NORP'),
#    (2655, 2668, 'ORG'),
#    (2761, 2776, 'PERSON'),
#    (2809, 2829, 'PERSON'),
#    (2881, 2892, 'NORP'),
#    (2958, 2969, 'FAC')]),
#  'NL-HaNA_1.04.02_6847_0766': ("Jora Hen „ testament den 19: mei 1773: voor den notaris LieuEert Rolff en geluigen gepasseert verklaarde de eerststervende van oi„ beide tot meede execuleur van voorsz: uilterste willen en onser nalatenschap mitsg:s begravenis bezorger en meede voegd over onze natelatene onmondige kinderen met en benevens de Langstlevende van ons beide eerbiediglijk te versoeken en aan te stellen den wel Edelen gestrehgen Heer Hendrik van Stokum, raad extraordrt van Nederland india te zaamen of ieder in ’t bijzouder en dat met zoodanig en breed veerigen last magt en authoriteit als na regtent kun werden vergunt speciaal die van assumtie Sulestitutie en Surrogatie, Dit begeeren wy dat Sal stane grijpen als Coduil /onderstond/ Batavia den 15: x:be 1771: was geteeken: PN: Hare Huijden 28. december A:o 1771. vanamiddag om haffig Compareerde voor mij Leendert Rolf notaris publicq bij de Edde EHooge Regeeringe van Nederlands India gadmilter Auijlen de stad Batavia rresideerende ter presentie van de naar te noemene getuigen sE: Holua Hen boekhouder in dienst der E: Comp wo„ pende aan de wystzijne van de Grootte Rivier binnen destaet mij beken De welke onaangezien zijnen zieken toestand mij Notaris Egter met volkomen verstand em onverwaarde uitspraake te kennen gafuit Eige vrij en onbeewingen willen souder inductie ef persua „gie van iemine geneegen te zijn om te disponeeren over de sijn nate „latene goederen invoegen doet bij deesen na voorgaande revocatie van Mle Testamenten, Ceduillen en andere makinden van uitterste wille, die hij bevoorens mogte hebben gemaakt tofte gepasseert Dus of nieuws disponeerende zoo verklaarde den Teslateur door onstentenisse van ouders en Pescendenten tot zijn eenige algeheele ende univer seele erfgenaam te nomineeren en Enslitueeren Dalmoesniers wdeshuijs tot Amsteriam waar hij Testateur is opgevoed, en dat in al ’t geen den Testuteur met er Dood sal komen te ontruijmen en naer te laeten soo roerende als cureerende goeveren actien en Crediten geene uitgezonden ’'t gune hij bethilge geen Twee Duijsend rijrd. te bedraagen Tot execuleur deser Testament en sijnen Nalatenschup mitsg:s begravenis bezorgers verseekt en Constitueere hij testateur Seer eerwaarden eerbierigd de wel Edele Heeren Weesmeksteren Deeser steede Voorts heb ik notaris den Testateur g’Elucideert te seergeve nereerde ordonnantje van de Edele Hooge Indiasche Regeering nopens de lijfEigenen de Een schristelijken gods Dienst gamplee„ leerd hebben Versoekenee den Testateur alhier te noteeren dat den slaaf Portuijn van Malbaar op Soudratta is egekogt door de lei hem woonende vrije Onchriste vrouwe Rosetta van Ben„ „galen endezelve over Sulx haar in Eigendom is toebehoorende Dog dat ’t bewijs is te zoek geraakt AAltgint voorsz. Slakat een Tesluteur wel en Duijvelijk voorgehouden en bij hem zoo hij zeide wel verstaan zijnde so begeerde hij, dal dit instrument na zijn overlijven wer verstaan van ",
#   [(0, 8, 'PERSON'),
#    (25, 27, 'CARDINAL'),
#    (29, 37, 'DATE'),
#    (56, 70, 'PERSON'),
#    (261, 290, 'PERSON'),
#    (310, 323, 'GPE'),
#    (414, 433, 'PERSON'),
#    (454, 469, 'GPE'),
#    (644, 654, 'GPE'),
#    (676, 685, 'WORK_OF_ART'),
#    (718, 725, 'GPE'),
#    (730, 732, 'CARDINAL'),
#    (739, 743, 'DATE'),
#    (759, 761, 'EVENT'),
#    (763, 775, 'PERSON'),
#    (776, 778, 'CARDINAL'),
#    (780, 788, 'DATE'),
#    (793, 797, 'DATE'),
#    (841, 854, 'PERSON'),
#    (878, 904, 'ORG'),
#    (905, 921, 'GPE'),
#    (932, 939, 'NORP'),
#    (948, 955, 'GPE'),
#    (1016, 1018, 'PERSON'),
#    (1020, 1029, 'PERSON'),
#    (1080, 1126, 'GPE'),
#    (1185, 1192, 'PERSON'),
#    (1236, 1246, 'PERSON'),
#    (1257, 1263, 'NORP'),
#    (1296, 1302, 'PERSON'),
#    (1312, 1321, 'ORG'),
#    (1323, 1337, 'ORG'),
#    (1361, 1372, 'GPE'),
# ...
#   [(4, 17, 'PERSON'),
#    (28, 36, 'PERSON'),
#    (78, 85, 'GPE'),
#    (90, 92, 'CARDINAL'),
#    (94, 107, 'DATE'),
#    (123, 127, 'PERSON'),
#    (128, 132, 'LOC'),
#    (133, 139, 'LOC'),
#    (140, 146, 'GPE'),
#    (162, 169, 'GPE'),
#    (184, 189, 'GPE'),
#    (191, 199, 'GPE'),
#    (214, 218, 'GPE'),
#    (229, 236, 'PERSON'),
#    (286, 291, 'LOC'),
#    (297, 299, 'CARDINAL'),
#    (307, 311, 'DATE'),
#    (332, 340, 'PERSON'),
#    (448, 456, 'DATE'),
#    (461, 462, 'CARDINAL'),
#    (464, 469, 'DATE'),
#    (474, 478, 'DATE'),
#    (480, 500, 'PERSON'),
#    (504, 519, 'PERSON'),
#    (590, 600, 'PERSON'),
#    (655, 666, 'PERSON'),
#    (674, 681, 'ORG'),
#    (759, 773, 'PERSON'),
#    (781, 791, 'ORG'),
#    (796, 798, 'CARDINAL'),
#    (800, 805, 'EVENT'),
#    (806, 810, 'DATE'),
#    (812, 823, 'PERSON'),
#    (827, 831, 'CARDINAL'),
#    (859, 874, 'PERSON'),
#    (968, 975, 'GPE'),
#    (1033, 1037, 'GPE'),
#    (1038, 1049, 'PERSON'),
#    (1096, 1112, 'PERSON'),
#    (1165, 1173, 'GPE'),
#    (1230, 1240, 'PERSON'),
#    (1272, 1283, 'NORP'),
#    (1371, 1396, 'PERSON'),
#    (1470, 1477, 'NORP'),
#    (1488, 1489, 'CARDINAL'),
#    (1503, 1513, 'EVENT'),
#    (1529, 1538, 'PERSON'),
#    (1565, 1576, 'PERSON'),
#    (1590, 1603, 'LAW'),
#    (1605, 1623, 'PERSON'),
#    (1666, 1675, 'WORK_OF_ART'),
#    (1708, 1752, 'WORK_OF_ART'),
#    (1756, 1764, 'PERSON'),
#    (1765, 1768, 'ORG'),
#    (1772, 1784, 'GPE'),
#    (1790, 1794, 'CARDINAL'),
#    (1811, 1842, 'PERSON'),
#    (1846, 1866, 'PERSON'),
#    (1880, 1886, 'LANGUAGE'),
#    (1967, 1976, 'PERSON'),
#    (2077, 2085, 'PERSON'),
#    (2118, 2137, 'PERSON'),
#    (2203, 2208, 'PERSON'),
#    (2230, 2233, 'ORG'),
#    (2235, 2260, 'PERSON'),
#    (2261, 2275, 'PERSON'),
#    (2437, 2450, 'NORP'),
#    (2451, 2464, 'PERSON'),
#    (2504, 2513, 'ORG'),
#    (2576, 2582, 'PERSON'),
#    (2712, 2714, 'CARDINAL'),
#    (2717, 2719, 'DATE')]),
#  'NL-HaNA_1.04.02_6847_0755': ("„ essen testamente en bezorger zijner begravenisse verderaars zijner nalatenschap mitsg:s voogden over de onmondige legotarissen en hunne uit kragte deeses te ervene penningen en middelen te versoeken Eligeeren en Constitueeren De meskeurs Samuel Godri Manke Cernoral en Barend Carlelijn adsistent beide ten dien meermelt geevende aan hun zol 't samen als ieder a zonderlijk de breed voorigen last magt en authoriteit als eenigsints na regten aan eenige execuleur en testamentaire kun en magwer„ ten vergunt en wel speciaal die van assumtie Surrggatie en Sulstituutie Secludeerende der halvens behoudens haar eerwaardigheijd on„ aangezien de gedaane precivertantie, het eerwaarde Collegie van heeren weesmeesteren en den E: Heer Curater ad litest alhier ter steede mitsgds alle andere amptenaaren off pligts halven waar ook zijn testateurs sterffgeval mogte kunnen te exteeren Vol pereculeurs over zijn reslateurs vaes verdreme en negte versienen maand gelien verklaarde den teslateur zeer eerbiedig„ „lijk te versoeken ten Conslitueeren de wel Edele groot Agtb Heeren bewind hebberen den g'egtroijeerde aastjndische Compagnie te kamer Amsterdam voor de welke bij belutigite in dienst aangenoomen en hijt gevaaren te zijn /met beide daar toe aan hun wel Ed: groot agtbaare gelieven te betaalen aan de geene die haar toe geregtigde sal of zullen zijn Voorts verklaarde ien testateur aan zig te behouden de magt en russepiteit om deese zijne testamentaire dispositie met alsulke leqaalen prelegaaten Emcncipatien van lijf Eigenen en benoeming van meede off nadere executeuren te amptieeren en gedaan zijnde tzelve zoowel als het bereeds daar omtrent gedisponeerde te rerrie „pen iff altereeren dan wel in ’t generaalbuijten de erfstelling in desen zoodanige rexancering tet maaken als rijstzis in margine op de vrugge deeses of te bij aparte memorien onder des selff gevoone hangbckenin K men met bireyingg van maand dag en Haar zal konnen goed te rinden verklakrende al ’t geen zodanig sal komen te blijken te houden van Even gelijke kragt en waarde als of het zelve in deese woordelijk g'insereert dan wel voor notaris en getuigen gepasseert waaren. En zal de voorschreeven Erfgenaame verpligt weesen, om alles de vaste goederen die hij uit kragt deeses mogte komen te erven binnen drie maanden gerekent van zyn testateurs Sterffdag af behoorlijk op haare naame te laten doen overschreeven ingevolge de g'eevde ordres van de Edele hooge Indiaeche Regeering ik muteries Julejeel Al het gunt verschreeven Claal aan den teslateur duijdelijk voorgeleesen en by hem zoo hij betuigde wel verstaan zijnde hij Dat ie instrument zijn volkomen Effect mogten genieten 't hij als testament Codicil gift ter zaake des doods ofte eenige andere, makinge van uitlerste wille zulx het zelve best naregter Irl: konnen bestaan schoon de noodige Colemniteiten in deesen gerequireere niet volkomen waaren, gobserveert Versoekende ten dien sins het wobile beniquum officium van sHeeren regt ende regteren te mogen genielen, Compareerde meede de voornoemde executeuren de welke verklaarden den voorsz: Last met hunne meede onderleckenin te hebben g'accepteerde Aldus gestaan ende getesteert ten vroonhuijs van den testa „teur ",
#   [(8, 18, 'GPE'),
#    (31, 50, 'PERSON'),
#    (82, 87, 'PERSON'),
#    (159, 165, 'GPE'),
#    (201, 210, 'LANGUAGE'),
#    (240, 251, 'PERSON'),
#    (271, 287, 'PERSON'),
#    (339, 345, 'ORG'),
#    (422, 432, 'PERSON'),
#    (488, 494, 'PERSON'),
#    (541, 551, 'PERSON'),
#    (582, 593, 'PERSON'),
#    (717, 720, 'NORP'),
#    (724, 746, 'PERSON'),
#    (785, 796, 'NORP'),
#    (797, 807, 'PERSON'),
#    (914, 927, 'PERSON'),
#    (953, 984, 'PERSON'),
#    (1010, 1037, 'PERSON'),
#    (1057, 1061, 'WORK_OF_ART'),
#    (1117, 1126, 'ORG'),
#    (1136, 1145, 'GPE'),
#    (1254, 1256, 'PERSON'),
#    (1368, 1381, 'PERSON'),
#    (1498, 1519, 'PERSON'),
#    (1562, 1573, 'NORP'),
#    (1648, 1661, 'GPE'),
#    (1677, 1680, 'ORG'),
#    (1795, 1802, 'GPE'),
#    (1840, 1848, 'PERSON'),
#    (1865, 1884, 'PERSON'),
#    (1895, 1904, 'ORG'),
#    (2086, 2097, 'PERSON'),
#    (2174, 2184, 'PERSON'),
#    (2241, 2253, 'PERSON'),
#    (2282, 2294, 'DATE'),
#    (2403, 2410, 'ORG'),
#    (2527, 2550, 'PERSON'),
#    (2678, 2685, 'PERSON'),
#    (2759, 2773, 'PERSON'),
#    (2826, 2839, 'NORP'),
#    (2934, 2951, 'PERSON'),
#    (2992, 3000, 'GPE'),
#    (3034, 3045, 'NORP'),
#    (3067, 3077, 'PERSON'),
#    (3100, 3114, 'PERSON')]),
#  'NL-HaNA_1.04.02_6847_0033': ("„ „ „  op Heeden den 27: Iunij A:o 1767. snamiddags om vyff uuren Compareerde voor mij M:r Pieter Willem lam, wen nots ppbl: bij de Edele hooge regeringe van nederlands Indio g'admitseerd buijten de stad Batavia resideerende ende voor de naar genoemde getijgen den wel Edelen gestr: Heer van Schrennder raad ordinair van nederlands india en president van heeren welsmeesteren deser stede en mevrouwe Kara goertrugda De Lahaije Egtelieden woonende op Jaccaha buijten des stad mi bekend, Zijnde de wel Edele gestrengen heer en vrouwe Comp=s gesond van lerhaane huwr verstand, en memorie wel hebbende De welke aan mij nots: Exhbeerde en ter hand selde dijs wellen Popier gevouwen dngwante waaren zijn Ed:s Eehoggde voor Eanderde hand gesz: en door huw wel Ed: Eijgenhandig on derbekend te zijn hun wel Ed: Testament laastenngverste wille begeerende dat ’t selve alsoo mogte stand grijpen dan wel als Codicil zoo als 't best zal kunnen bestaan voorts heb ik nots 't selve papier hierinne geslooten mitsg:s dit omslag met drie mijner cachetten en vier van de wel Ed:e Gestr: hier en vrouwe Comparanten alle in roode lacque gedrukt Aldus gedaan ende gesuperscribeerd in de Rhiyn van de wel Ed:e gestr heer en vrouwe Comparanten in tegenwoordig„ Jacob Pieterszen Fredricus constanlijn ƒ heid van Clercquen als getuigen /was getekend/ I:n Schrenden Gerritsz geextroijda Schrender gebooren de Lahaije en Clam tond /getekend/ I:b Pieterszen Fr: C:gerritsz ferzyde lager/ P: W: lammens nots en heb ik na dat de Zeguls door ons g’Examineerd gaaff en ongecanselleerd gevonden waaren gegrend en daar in bevonden haar wel Edeles mate„ eele Testament die het selve men beeswoordelij kalden kennelijk zij aan een ieder dient behoord dat wij onder„ gebekende Jan Schrender raad ord van nederlands india en Clara geertruyda De lahaije Egtelieden, uyt overdenken ge vande swak en broosheid onses levensende onsekerheid wanneer het zelve staat te Eijndigen te raade zijn geworden nopens de tijdelijke goederen ons door god verleend onsen wille te verklaaren en dat wij zulks doen bij deesen zonder dnang manche off persnagie van iemand mitsg:s met revoca„ te en annillatie van alle voorgaande testamenten codicillen huwelijkse voorwaarden en andere acten van uij Eerste wille hoe ook genaamd die voor dato deses door ons beijden off een ",
#   [(10, 16, 'PERSON'),
#    (21, 23, 'CARDINAL'),
#    (25, 30, 'WORK_OF_ART'),
#    (35, 39, 'DATE'),
#    (91, 108, 'PERSON'),
#    (158, 174, 'GPE'),
#    (204, 211, 'GPE'),
#    (212, 225, 'DATE'),
#    (288, 302, 'PERSON'),
#    (321, 337, 'GPE'),
#    (355, 375, 'PERSON'),
#    (376, 381, 'GPE'),
#    (400, 426, 'PERSON'),
#    (427, 437, 'PERSON'),
#    (450, 457, 'GPE'),
#    (621, 630, 'GPE'),
#    (703, 725, 'PERSON'),
#    (731, 735, 'GPE'),
#    (753, 755, 'PERSON'),
#    (757, 769, 'PERSON'),
#    (799, 801, 'PERSON'),
#    (803, 812, 'PERSON'),
#    (897, 915, 'PERSON'),
#    (1017, 1021, 'CARDINAL'),
#    (1042, 1046, 'CARDINAL'),
#    (1105, 1111, 'ORG'),
#    (1167, 1172, 'LAW'),
#    (1184, 1186, 'PERSON'),
#    (1189, 1194, 'PERSON'),
#    (1239, 1277, 'PERSON'),
#    (1317, 1328, 'WORK_OF_ART'),
#    (1331, 1349, 'PERSON'),
#    (1350, 1371, 'PERSON'),
#    (1384, 1391, 'LOC'),
#    (1395, 1404, 'ORG'),
#    (1405, 1417, 'PERSON'),
#    (1420, 1445, 'PERSON'),
#    (1461, 1474, 'PERSON'),
#    (1500, 1506, 'LOC'),
#    (1529, 1534, 'GPE'),
#    (1620, 1634, 'PERSON'),
#    (1741, 1754, 'PERSON'),
#    (1768, 1784, 'GPE'),
#    (1788, 1815, 'PERSON'),
#    (1816, 1826, 'PERSON'),
#    (1926, 1935, 'PERSON')]),
#  'NL-HaNA_1.04.02_6847_0027': ("„ „ daer op voos gesteld Eijndelijk betrijgden de testateuren op afvrage van mijn nots: ingevolge de ordonn: van te klein zigul dat hinne gemeene boedel beneden de twee duysend Ed: is bedragende, Al het gunt voorsz staat de testateuren wel en drijdelijk voor„ gehouden en te verstaan gegeven zijnde en soo zij betuigden 'tselve wel begreepen te hebben begeerden zij dit instinment volkomen Effect sal mogen genieten ’t zij als testament of Codiciel zoo en indiervoegen 't selve best naregten sal konnen bestaan, — Aldus gepasseerd ten hise van de Testateuren staande ter plaatse als enden hoofde deses gemeld it bij wesen van Abraham Salomons en Bernardus Aronsz myne klerken als getuygen De minute dezes is behoorlijk getekend en gesz: op een segel van Een rd: /onderstond/ guod attestor /was getekend w E: Blomhert nots: ter zijde stond dit Testament ialhier ter weesk gelesen en geregistreerd ingevolge heeren weesm: resol: van dato deses Batavia in de weesk: den 25: Jann 1769 /was getekend/ meijer secretaris! Pruymer Gerind Gerhard Henderk N:o 8 op heeden den 18: Iunij 1763. Compareerde voor mij M:r Pieter Iacob Bert not=s publ: bij de Edele hooge regering van nederland onder g’admisseerd brijten destad batavia redideerende present de naargenoemde getuigen De Heer geerhardt Hendrik Prui„ mers Fabrijcq en Iuff=m Susanna Maria Grebel Egtelieden mij bekend dog hebbende zijn den Eersten ziekelijk ende tweede gesond van lachaame beijde naar volkomen verstand en onverwaarde uijtspraak, Te kennen gevende uyt eijgen vrye en onbedwongen wille genegen te zijn om te risponeeren over hunne natelatene goederen Casseerende over zulx reroceerende rood en te niet doende alle testamenten Codicillen of andere actens van uijsterste wille bij hun Ed:s te zamen of bij ijeder van hem in 't bij„ zonder gemaakt of gepasseerd niet willende dat een der zelver effect zal sorteeren maar hondende de zelve voor mil korgteloos en van onwaarde Dus op nieuw disponeerende zo verklaarde den heer testateur te lega„ teeren aan zijn Ed:s natuurlijke dogter Anna Lamentia pruij„ mers bij zijn Ed: pro dato van zijn huwelijk verwekt een somma van agt Duisen d 20:e van agt en veertig sw: stver: ieder nevens twee slaven gen: Fortuijn van boegies en Cananga van batavia mitsg:s alle kleede ren linne goed Jnweelen goud en silver werken tot haar lijf behoorende die paar successivelijk van den heer testateur gegeven zijn, met desen verstaande nogthans dat ingevalle gem: legatrice onmondig ",
#   [(25, 46, 'ORG'),
#    (132, 145, 'GPE'),
#    (164, 168, 'CARDINAL'),
#    (177, 179, 'PERSON'),
#    (243, 253, 'PERSON'),
#    (440, 452, 'PERSON'),
#    (547, 558, 'ORG'),
#    (626, 642, 'PERSON'),
#    (646, 662, 'PERSON'),
#    (663, 675, 'PERSON'),
#    (775, 788, 'PERSON'),
#    (808, 816, 'PERSON'),
#    (843, 852, 'PERSON'),
#    (906, 918, 'PERSON'),
#    (920, 925, 'GPE'),
#    (942, 949, 'GPE'),
#    (956, 961, 'LOC'),
#    (963, 966, 'LANGUAGE'),
#    (967, 969, 'CARDINAL'),
#    (971, 976, 'PERSON'),
#    (976, 980, 'DATE'),
#    (986, 1002, 'ORG'),
#    (1015, 1022, 'PERSON'),
#    (1023, 1045, 'PERSON'),
#    (1050, 1051, 'CARDINAL'),
#    (1066, 1068, 'CARDINAL'),
#    (1070, 1075, 'ORG'),
#    (1076, 1080, 'DATE'),
#    (1107, 1124, 'PERSON'),
#    (1213, 1220, 'GPE'),
#    (1245, 1257, 'GPE'),
#    (1275, 1303, 'PERSON'),
#    (1304, 1312, 'GPE'),
#    (1323, 1343, 'PERSON'),
#    (1344, 1354, 'PERSON'),
#    (1384, 1395, 'PERSON'),
#    (1411, 1417, 'ORDINAL'),
#    (1429, 1437, 'GPE'),
#    (1471, 1493, 'PERSON'),
#    (1532, 1543, 'NORP'),
#    (1572, 1583, 'GPE'),
#    (1589, 1605, 'PERSON'),
#    (1615, 1626, 'NORP'),
#    (1747, 1749, 'PERSON'),
#    (1882, 1899, 'PERSON'),
#    (1905, 1919, 'PERSON'),
#    (1949, 1962, 'LAW'),
#    (2045, 2070, 'PERSON'),
#    (2146, 2150, 'DATE'),
#    (2162, 2169, 'CARDINAL'),
#    (2170, 2172, 'ORG'),
#    (2194, 2198, 'CARDINAL'),
#    (2211, 2231, 'PERSON'),
#    (2235, 2254, 'PERSON'),
#    (2255, 2260, 'PERSON'),
#    (2290, 2298, 'NORP'),
#    (2355, 2377, 'PERSON'),
#    (2411, 2436, 'PERSON'),
#    (2456, 2465, 'GPE')])}

# %% [markdown]
# In order to circumvent the catastrophic forgetting problem, we train the model on both manual annotations as well as what spaCy itself predicts.
