# %%
import spacy
from spacy import displacy
nlp = spacy.load("nl_core_news_lg")

# %%
text = "Premier Rutte heeft Koning Willem-Alexander het ontslag aangeboden van zijn kabinet. Daarmee is zijn derde kabinet twee maanden voor de Kamerverkiezingen van maart gevallen. Dat deze stap eraan zat te komen, tekende zich de afgelopen dagen al af in allerlei overleggen binnen de coalitie van VVD, CDA, D66 en ChristenUnie. Vandaag hakte het kabinet de knoop door.Het kabinet zal nu demissionair doorregeren, met uitzondering van minister Wiebes van Economische Zaken. Die vertrekt helemaal vanwege zijn rol als staatssecretaris van Financiën in het vorige kabinet. Minister Van Nieuwenhuizen van Infrastructuur neemt zijn portefeuille de komende tijd over.Het opstappen van het kabinet hangt samen met de toeslagenaffaire, waarbij duizenden mensen ten onrechte als fraudeur werden bestempeld en de toeslag voor de kinderopvang moesten terugbetalen."

# %%
doc = nlp(text)
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Premier
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rutte
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  heeft
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Koning Willem-Alexander
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  het ontslag aangeboden van zijn kabinet. Daarmee is zijn derde kabinet
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     twee maanden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  voor de Kamerverkiezingen van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  gevallen. Dat deze stap eraan zat te komen, tekende zich de afgelopen dagen al af in allerlei overleggen binnen de coalitie van
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VVD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CDA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     D66
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  en
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ChristenUnie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Vandaag hakte het kabinet de knoop door.Het kabinet zal nu demissionair doorregeren, met uitzondering van minister Wiebes van
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Economische Zaken
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Die vertrekt helemaal vanwege zijn rol als staatssecretaris van Financiën in het vorige kabinet. Minister Van Nieuwenhuizen van Infrastructuur neemt zijn portefeuille de komende tijd over.Het opstappen van het kabinet hangt samen met de toeslagenaffaire, waarbij duizenden mensen ten onrechte als fraudeur werden bestempeld en de toeslag voor de kinderopvang moesten terugbetalen.</div></span>

# %%
lines = []

with open("NL-HaNA_1.04.02_6847_0237.txt", "r") as handle:
    lines = [l.strip() for l in handle.readlines() if len(l.strip()) > 0]
    
    
text1 = " ".join(lines)
print(text1)
# Out:
# Ende op nieuws ter dispositie komende, verk=de den testat=e na ontfangene clucidatie van mij nots: nopens den in houd van het placcaat door d’ Ed: hooge req: deeser Landen op het Clapitre van de manumissie der Leijf feijgenen beraamd, de Vrijdom teschenken aan zijn slaaff Ontong van Nias en slavinne klarinda, van balij, met begeerle dat de kosten daar toe staande, uit zijn boedel betaald zullen moeten werden en Legateerd aan ieder derselven Een somma van 50. rd„s van 48. sw: stver=s ider voorts Legat=d hij testat=r aan d’ diaconij armen der Christelijke gereform: gem=te alhier Een somma van 50. — rd„s munte voorsz: Waar mede den testat=r ter gener=le Erfstelling advan„ ceerende, verklaarde tot zijn Eenige ende universeele Erffgen: te nomineeren en institueeren d’E: Hermanus zijn Wiese, boekh: in dienst der E: Comp: en dat in alle als testat=rs verdere natelatene goederen, zoo roerende ouroerende item actien ende Crediten niets uijtgezond=t, betuijgende geene Ouders in’t Levente hebben Tot Execut=e van dezen testam =en van zijne begrafe„ „nisse verklaarde hij te stellen den voorn=de E herman= wiese met de magt daar toe vereijscht, en wel speciaal die van assumntie substitutie en surrogatie selludeerende hij testat=r met de verEischte Eerbied uit zijne nalatenschap het Eerw=de Collegie van heeren Weesm: en den heer Curat=r adlites, zoo hier als Elders, haar eerw=s en Edelens voor derselver anderzints te mene moeijte reverentelijk bedankende Tot Executren over zijne maand gelden verklaarde hij zeer Eerbiediglijk te versoeken, eligeeren en qualificeeren de hoog Ed: gr: agtb: heeren bewind hebb: der g’octroijeerde oost indische Comp: ter kamer Amsterdam, voor dewelke hij betuijgde alhier in dienst aangenomen te zijn, met bede dezelve tewillen doen uijtkeeren aan die uijtkragte deses tot ontfangst zal off zullen wesen gequalificeerd, dies Betuijgende den testat=r dat zijn boedel 2900. — rd=s was surpasseerende zullende 28 1

# %%
doc = nlp(text1)

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ende op nieuws ter dispositie komende, verk=de den testat=e na ontfangene clucidatie van mij nots: nopens den in houd van het placcaat door d’
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hooge req
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     deeser Landen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  op het
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clapitre van de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     manumissie der Leijf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     feijgenen beraamd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , de
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vrijdom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  teschenken aan zijn slaaff
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ontong van Nias
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  en
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     slavinne klarinda
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , van
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     balij
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , met begeerle dat de kosten daar toe staande, uit zijn boedel betaald zullen moeten werden en
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Legateerd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  aan ieder derselven Een somma van
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# „s van
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     48
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sw
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : stver=s ider voorts
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Legat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
# =d hij testat=r aan d’
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diaconij
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  armen der
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christelijke gereform
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gem
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# =te alhier Een somma van
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . —
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# „s
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     munte
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  voorsz: Waar mede den testat=r ter gener=le Erfstelling
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     advan

# %%
file_name = 'Manualcorrections.xlsx'
import pandas as pd
df = pd.read_excel(io=file_name)
print(df.head())


print(df.columns)
text1.replace(df.columns[0], df.columns[1])
# Out:
#        verk=de verklarende
# 0     testat=e   testateur
# 1  clucidatie   elucidatie
# 2        nots:     notaris
# 3           d’          de
# 4          Ed:       edele
# Index(['verk=de', 'verklarende'], dtype='object')
# '_:winklaande hie tot Executeurs van zijn Testamente en begrafenis door Elk voor Elk voor Een Equale portie genooten, en bezeten te werden, met versoek en qualificatie aan de Erfgenaame, en Executrice in deesen gemelde penningen, op de bequaamste manier te Remitteeren, en over te maeken, aan des Testateurs gemagtigden de Heer Bernardus Jonffermans, oud scheepen deeser steede, thans woonagtig in Holland, buijten den Haag op de Haagse weg, om deselve te besorgen, aan de Legatarissen desselvs susters voormeld waar deselve woonagtig sullen zijn Wijders is des Testateurs begeerte, dat de drie duijsend duijt„ sche daelders, waar voor Een stuk Land gekogt is; weder te rug sullen keeren, aan bovengem: Agt susters, of zoo veel als in ’t leeven sullen zijn, onder deese mits nogthans, dat de Jnkomsten van dat land sullen genooten, en getrocken werden haar leeven lang geduu„ rende, door deselfs Jongste Suster Juff:r Dorothea Elisabeth Senff huijsv: van den heer Andries Zabel, burger te Pangermunde in ’t brandenburgse. Aan desselfs Neeff DE: Andries Zabel Jumor, Adsistent in dienst der E: Comp:e en somma van Een duijsend vijfhondert aijxdi Aan de heer Reijnier van Aarn koopman, mitsgs fiscaal en va Cassier van Mallabaar, Een Somma wee duysend vijf hondert uijxd: Aan DE: Jan Iacob Hes Boekhouder in dicust voorsz: Een Somma van Vijff Hondert rijxd: Aan desselfs gemagtigden den heer Bernardus Ionffermans hier voren gemeld Een somma van Twee Duijsend rijxd:s Aan sijn aangenomen kind Lodewijk Cornelis Senff, oud vijf Jaeren, Een Somma van Drie Duijsend rijx:s, met versoek aan de Erfgenaame in veesen, dat gemelde Lodewyk mag bij haar blijven woonen om hem tot een bequaam ambagt, of behoorlijke kostwinning op te voeden, onder deese mits almeede, ingevalle gerepte Lodewijk onmondig, of ongetrouwt kwam te overlijden, als dan ’t voorsz: legaet zonder aftrek van Eenige Trebellianique portie, zal komen, en de volveeren, aan de hier ondertenoemene Erfgenaeme Aan de vrije Christen vrouw Jamila van Nias, bij den H: doop genaamd Johanna Lourens, Een Somma van Twee duij„ send rijxd:, met begeerte van den Testateur, dat aan haar sullen moeten afgegeven worden, alle de Juweelen, Goud, en Silver werken dat den testateur haer gegeven heeft, volgens Een getekende Lijst, in'

# %%
doc = nlp(text1)
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ende op nieuws ter dispositie komende, verk=de den testat=e na ontfangene clucidatie van mij nots: nopens den in houd van het placcaat door d’
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hooge req
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     deeser Landen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  op het
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clapitre van de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     manumissie der Leijf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     feijgenen beraamd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , de
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vrijdom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  teschenken aan zijn slaaff
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ontong van Nias
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  en
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     slavinne klarinda
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , van
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     balij
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , met begeerle dat de kosten daar toe staande, uit zijn boedel betaald zullen moeten werden en
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Legateerd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  aan ieder derselven Een somma van
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# „s van
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     48
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sw
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : stver=s ider voorts
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Legat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
# =d hij testat=r aan d’
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diaconij
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  armen der
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christelijke gereform
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gem
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# =te alhier Een somma van
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . —
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# „s
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     munte
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  voorsz: Waar mede den testat=r ter gener=le Erfstelling
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     advan

# %%
file_name = "Manualcorrections.xlsx"
import pandas as pd
df = pd.read_excel(io=file_name)

df.shape
# Out:
# (111, 2)

# %%
text2="mijn testat=e is verk=de"

for i, row in df.iterrows():
    print(row.Mistake, row.Correction)
    text2.replace(row.Mistake, row.Correction)
# Out:
# verk=de verklarende
# testat=e testateur
# clucidatie  elucidatie
# nots: notaris
# d’ de
# Ed: edele
# req: regering
# Leijf feijgenen Leijffeijgenen
# balij Balij
# Vrijdom vrijdom
# begeerle begeerte
# werden worden
# Legateerd legateerd
# 50. 50,-
# rd„s rds.
# stver=s stuijvers
# Legat=d legateerd
# testat=r testateur
# gereform: gereformeerde
# gem=te gemeente
# 50. — 50,-
# advan„ ceerende advanceerende
# gener=le generale
# Eenige eenige
# Erffgen: erffgenamen
# d’E: de edele
# boekh: boekhouder
# E: edele
# Comp: companion
# testat=rs testateurs
# Crediten crediten
# uijtgezond=t uijtgezondert
# Ouders ouders
# Execut=e executeur
# testam =en testamenten
# begrafe„ „nisse begrafenisse
# herman= Hermanus
# wiese Wiese
# verEischte vereijschte
# Eerbied eerbied
# Eerw=de eerwaarde
# Curat=r curator
# Elders elders
# eerw=s eerwaardes
# Executren executeuren
# Eerbiediglijk eerbiediglijk
# gr: grote
# agtb: agtbare
# hebb: hebbende
# g’octroijeerde geoctroijeerde
# Oost indische Comp: Oost Indische Compagnie
# 2900. - 2900,-
# rd=s rds
# in’t in het
# Op Heeden Op heeden
# Den den
# : october oktober
# wiggert wargaren Wiggert Wargaren
# Edelen edelen
# eegeringe regering
# derdele de edele
# nederlands Jonra Nederlands Indië
# bunnen binnen
# destad de stad
# Eerw: eerw:
# bentamin Benjamin
# des Goddelijken des goddelijken
# nederdug Nederduits
# Compareerde voor men Compareerde voor mij
# batmera Batmera
# m:r meester
# geschieden gescheiden
# mijner mijne
# sekerheit zekerheid
# teffens tevens
# geteekend getekend
# decemb,,r december
# deses deze
# Eenelijk eenelijk
# versogt verzocht
# Commissi commissie
# M,,r Mr
# selivelden Selievelden
# verspijck Verspijck
# secret secretaris
# G'Extraheert Gertraheert
# agtb: agtbare
# raede raad
# Iustitie Justitie
# batavia Batavia
# onselieve onze lieve
# Verspijcksaluit Verspijck ?
# Veertruida Geertruida
# huijvrouw huisvrouw
# Comman,,deur commandeur
# Equipagiemeester equipage meester
# heeden heden
# rij/ en vijf en
# Iaaren jaren
# desernee,,,,ren defenseeren
# schijding scheiding
# verdra,,gen verdragen
# Een  een
# bi bij
# is't is het
# soo zo
# geextruida geertruida
# secret''s secretaris
# schudingendeeling scheiding en deeling
# de vessolutie de dissolutie
# dedissolutie de dissolutie
