# %%
import spacy
nlp = spacy.load("nl_core_news_lg")

# %% [markdown]
# ### Importing spaCy and loading texts and annotations

# %%
from tqdm import tqdm

import gzip
import os

import random

import re
import matplotlib.pyplot as plt
import seaborn as sns
import pandas

corpus = "./Corpus/"
anns = "./Annotations/"

def load(file, corpus, lines=False):
    with open(os.path.join(corpus, file), "r") as handle:
        if lines:
            return list(handle) # handle.readlines()
        else:
            return handle.read()

# %% [markdown]
# ### Using csv to read BRAT annotations

# %%
def read_csv(file, corpus=anns):
    file = load(file, corpus, lines=True)

    for i, line in enumerate(file):
        if i == 0: print("first line:", line) #to see brat format
        tab_cols = line.split("\t")
        
        if tab_cols[0].startswith("T"):
            last = tab_cols[-1].strip()
            first = tab_cols[0]
            
            middle = tab_cols[1].split()
#             print(middle, middle[0], middle[-1])
            middle = [middle[0], middle[1], middle[-1]]
            
            yield (first, *middle, last)
            
def filter_rows(rows):
    for r in rows:
        if r[1].upper() in ["WOMEN", "INDIGENOUS", "MEN", "GPE", "ORGANIZATION"]:
        #if r[1].upper() in ["PERSON", "ORG", "GPE", "WOMEN", "INDIGENOUS", "MEN"]:
            yield r
        
def change_rows(rows):
    for r in rows:
        entity_nr, entity_type, start, end, label = r
        yield int(start), int(end), entity_type.upper(), label

# %%
data = {}

for ann_f in os.listdir(anns):
    if not ann_f.endswith('.ann'): continue
        
    if len(load(ann_f, anns)) > 0:
        cur_name = ann_f.strip(".ann")
    
        txt_f = cur_name + ".txt"
        if os.path.isfile(os.path.join(corpus, txt_f)):
        
            #raw_text = load(txt_f, corpus)
            brat_entity_list = list(change_rows(filter_rows(read_csv(ann_f, anns))))
            
            data[txt_f] = (brat_entity_list)
        else:
            print("no file", txt_f)
    else:
        print("annotation file empty")
# Out:
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 528 546	Abraham Salbindusz
#
# annotation file empty
# first line: T1	Person 42 54;55 61	Frans Willen waltig
#
# annotation file empty
# first line: T1	Group 59 63	volk
#
# first line: T1	Organization 137 144;145 191	BewinP. „hebberen der g'octroijeerde coptimischhe Comp
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Women 122 128	dogter
#
# first line: T1	Indigenous 256 262	slaven
#
# first line: T1	Organization 268 300	g'Ectroijeerde oostjndische Comp
#
# annotation file empty
# annotation file empty
# first line: T1	Organization 2613 2626	weesmeesteren
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Women 590 596	moeden
#
# annotation file empty
# annotation file empty
# first line: T2	Group 186 192	onders
#
# annotation file empty
# first line: T1	Person 371 403	Frredericus Censlantijn Gerritsz
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 0 8	Jora Hen
#
# annotation file empty
# first line: T1	GPE 142 149	Batavia
#
# annotation file empty
# annotation file empty
# first line: T1	Number 202 206	twee
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 0 16;17 29	Hendert Chustien Meyenslhagen
#
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	GPE 757 764	batavia
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Indigenous 2034 2049	huis inboorling
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Organization 200 222	gereformeerde diaconie
#
# annotation file empty
# first line: T1	Men 196 200	Heer
#
# annotation file empty
# first line: T1	Person 83 98	Benjamin Heynen
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 1 36	Susanna Elisabeth Willilmina Pinket
#
# annotation file empty
# first line: T1	Person 90 105	Benjamin Heynen
#
# annotation file empty
# annotation file empty
# first line: T1	Women 169 178	Meuffrouw
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 0 16	Cornelis Griafel
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	GPE 1591 1598	Malacca
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 268 275;276 284	Abraham Salomons
#
# first line: T1	Person 631 655;656 668	Ian Carelszen Zaelitbra„ „ham Simanoz
#
# annotation file empty
# annotation file empty
# first line: T1	Person 74 101	Christiaan Perdinant Cramer
#
# annotation file empty
# first line: T1	Organization 427 436	Weeskamer
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 88 106	M: Egbert Blomhert
#
# first line: T1	Person 131 145	Leendert Rolff
#
# annotation file empty
# first line: T1	Person 2 26	George Daniel
#
# first line: T1	Person 0 11	Jan Molleer
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T2	Person 310 326	Henricus van Lis
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Organization 1902 1937;1938 1989;1990 2005	WelEdele Groot Agtb: Heeren Bewind. hebberen der Geostroijeerde oost Jndische Comp: ter kamer Amsterdam
#
# annotation file empty
# first line: T1	Person 117 130	Hendrik Stuwe
#
# first line: T1	Person 1171 1187	Abraham Jalomous
#
# first line: T1	Person 200 221	Jnno Keint Sichterman
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 917 929	A=m Salomous
#
# annotation file empty
# annotation file empty
# first line: T1	Men 342 348	sijnen
#
# first line: T1	Person 81 105	Pieter Hendrik Popijwoud
#
# annotation file empty
# first line: T1	Women 252 263	haar moeder
#
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 512 536	Johannes Ezechiel Felist
#
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Indigenous 242 254	lijf eigenen
#
# annotation file empty
# annotation file empty
# first line: T1	Person 76 100	Pieter Hendrik Popijwoud
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	GPE 165 174	Amsterdam
#
# first line: T1	Organization 245 272;273 325;326 351	de welEdele Groot Agtb: Hee rend Bewindhebberen der Geoctroijeerde oost indische Comp: ter kamer Amsterdam
#
# first line: T1	Person 263 296	Adlites Thopas Fredrik Wannemaker
#
# first line: T1	Person 26 53	Hendrik Jan van den Berghen
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 293 318	Cavel Slegaro, van Bergen
#
# first line: T1	Person 615 629	A: v: d: Bergs
#
# first line: T1	Person 0 7;8 16	Abraham Abeleven
#
# first line: T1	Person 0 14	Jan Nederbosch
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 633 644	Ian Carelsz
#
# first line: T1	Person 76 103	Christiaan Ferdinant Cramer
#
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Men 148 152	Heer
#
# annotation file empty
# annotation file empty
# first line: T1	Person 1 11	duijneveld
# annotation file empty
# annotation file empty
# first line: T1	Person 74 101	Christiaan Perdinant Cramer
#
# first line: T1	Person 17 34	Iacobus mooijaard
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 265 273;274 280	Anthonia van Os
#
# first line: T1	Person 0 18	Pieter Adriaan Pla
#
# first line: T3	GPE 71 77	Europa
#
# first line: T1	Group 253 313;314 334	de LeijtEijgenen, die belijdenis van den Christelijken Gods„ dienst gedaan hebben
#
# annotation file empty
# annotation file empty
# first line: T2	Person 36 69	Johan Gerad Risschir van Gaerbeek
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 341 349	P: Evers
#
# annotation file empty
# annotation file empty
# first line: T1	Person 119 147	Barend van den Berghingergee
#
# first line: T1	Person 139 161;162 180	Iohannes Theodorus Vis scher van Paasbeek
#
# first line: T1	Person 2 17	Cornelis van Os
#
# first line: T1	Person 0 16	M Ryk van Echten
#
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 22 30	Saroenie
#
# annotation file empty
# annotation file empty
# first line: T1	Indigenous 247 259	lijf eigenen
#
# first line: T1	Person 537 555	Abraham Salomonsen
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 75 96	Pieter Hendrik Popijn
#
# first line: T1	Women 62 67	JnW=m
#
# annotation file empty
# first line: T1	Person 72 96	Pieter Hendrik Popijwoud
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 2 21	Jacob Christoffelsz
#
# annotation file empty
# first line: T2	Person 11 26	Cupiao van Bwoo
#
# first line: T1	Organization 422 443;444 496;497 532	DE wel Edele Groot tg „baaren Heeren Bewind hebberan der geoctaateerde oog Jndesche Comp: ter kamier Amsterdam
#
# annotation file empty
# first line: T1	Person 912 936	Commandeur van den bergh
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 223 253	Johanna Gertritijda De Pahaije
#
# annotation file empty
# annotation file empty
# first line: T1	Person 454 470	Adriaan Abeleven
#
# first line: T1	Person 6 35	Henderik Gerardus Tmommelsmet
#
# first line: T1	Person 211 229	Johannes Timmerman
#
# annotation file empty
# first line: T1	Person 16 37	Gerrit van den bezigh
#
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 624 648;649 653	Ian Carelszen Zaelitbra„ „ham
#
# first line: T1	Person 21 43	Johannes Stierna Boekh
#
# annotation file empty
# annotation file empty
# first line: T1	Person 629 640	Ian Carelsz
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 87 106	Christina Elizabeth
#
# annotation file empty
# first line: T1	Indigenous 83 89	slaven
#
# first line: T1	Person 279 295	Abraham Salomons
#
# first line: T1	Men 79 84	mons:
#
# annotation file empty
# annotation file empty
# first line: T1	Person 96 119	Pieter Cornelis Beekman
#
# first line: T1	GPE 137 144	Batavia
#
# first line: T1	Person 742 755	A=re Salomans
#
# first line: T2	Person 2044 2058	Cornelis Proms
#
# annotation file empty
# annotation file empty
# first line: T1	GPE 126 144	Eijland Groot Iava
#
# annotation file empty
# annotation file empty
# first line: T1	Person 422 438	Jan Barend Felix
#
# first line: T2	Person 11 34	Commandeur van den Berg
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 134 150	P: van Lelijveld
#
# annotation file empty
# first line: T1	Person 4 19	Matthem Welborn
#
# first line: T1	Person 51 73	Iohannes van den Bergh
#
# annotation file empty
# annotation file empty
# first line: T1	GPE 1 8	Batavia
#
# annotation file empty
# first line: T1	Person 1687 1699	Alida Elders
#
# first line: T1	Person 142 154	Darid Jansz:
#
# annotation file empty
# first line: T1	Person 1145 1156	David Jansz
#
# first line: T1	Person 297 308	p: Blomherk
#
# annotation file empty
# first line: T1	Person 68 86	Abraham van Zenden
#
# annotation file empty
# first line: T1	Number 105 110	vijff
#
# first line: T1	Person 488 505;506 511	Johannes Exechiel felix
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Indigenous 800 806	slaven
#
# first line: T1	Men 79 86	zoontje
#
# annotation file empty
# first line: T1	GPE 714 723	amsterdam
#
# annotation file empty
# annotation file empty
# first line: T1	Person 174 179	Jonas
#
# annotation file empty
# annotation file empty
# first line: T1	Organization 327 378;379 426	d’Edele Agtb: Heeren Bewindhebberen der Nederlandse oost Jndische (maatschappij ter Kamer Amsterdam
#
# annotation file empty
# first line: T1	Person 1543 1548;1549 1560	Johan Friemeijer,
#
# annotation file empty
# first line: T1	Person 0 29	Julius August Henderik Rowolt
#
# first line: T1	Person 572 579	Brouwer
#
# annotation file empty
# first line: T1	Person 177 207	Johanna Geertruijdd De Lahaije
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T2	GPE 132 139	Batavia
#
# first line: T1	Organization 575 593	oost Indische Comp
#
# first line: T1	Person 107 115;116 123	Casparus Hartman
#
# annotation file empty
# first line: T1	Person 6 28	Johan Henderk Driemeye
#
# annotation file empty
# first line: T1	Person 74 99	Fredrik Willem Hooghcamer
#
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Women 366 372	moeder
#
# first line: T1	Women 1999 2005	moeder
#
# annotation file empty
# annotation file empty
# first line: T1	Men 363 368	zoons
#
# first line: T1	Women 366 374	Slavinne
#
# annotation file empty
# annotation file empty
# first line: T1	Men 524 531	broeder
#
# first line: T1	Indigenous 1398 1404	slaven
#
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	GPE 128 135	Batavia
#
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 644 654	P= Lispens
#
# first line: T1	Person 248 266	Elisabeth Naalhout
#
# annotation file empty
# first line: T1	Person 735 762	Susanna Margaretha Leeuwerk
#
# first line: T1	Person 0 16	Hermanus Fredrik
#
# first line: T1	Organization 191 234	staaten Generaal der vereenigde nederlanden
#
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 1373 1389	Louise Verdelhan
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Indigenous 358 375	huysen boorlingen
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Organization 210 238	de Eerw: Heeren Weesmeeteren
#
# annotation file empty
# annotation file empty
# first line: T1	Person 200 216	I: G: De Cahaije
#
# annotation file empty
# first line: T1	Person 0 33	Johan Gerad Viescher van Gaarheek
#
# annotation file empty
# annotation file empty
# first line: T1	Group 4 28	formeerde Piaconie Armen
#
# first line: T1	Person 108 130	Franciscus Gertoel Sma
#
# annotation file empty
# first line: T1	Person 80 94	Ian van veeren
#
# annotation file empty
# annotation file empty
# first line: T1	Person 1575 1594	Johannes Laurenzzen
#
# annotation file empty
# annotation file empty
# first line: T1	Person 12 29	Willem Otto Reitz
#
# first line: T1	Person 77 92	Sijbrand Braaks
#
# annotation file empty
# first line: T1	GPE 80 87	Batavia
#
# first line: T1	Person 1422 1434	David Jansz:
#
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 17 36	Dompanicus Dolphijn
#
# first line: T1	Indigenous 706 712	slaven
#
# annotation file empty
# first line: T1	Person 75 102	Christiaan Perdinant Cramer
#
# first line: T1	Person 497 515;516 521	Johannes Welhelmus Close
#
# first line: T1	Group 156 182	Diaconij Armen deser stede
#
# annotation file empty
# annotation file empty
# first line: T1	Men 79 86	de heer
#
# first line: T1	Person 154 163	Nieuwveld
#
# first line: T1	Person 39 72	Johan Gerad Vietoher van Gaerheik
#
# annotation file empty
# first line: T1	Person 530 548	Dominicus Bernard,
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 58 78	George zodewijk Pfei
#
# annotation file empty
# annotation file empty
# first line: T1	Men 168 175	zoontje
#
# first line: T1	GPE 525 532	Batavia
#
# annotation file empty
# first line: T1	Indigenous 495 513	huijsin boorlingen
#
# first line: T1	Person 0 16	A: van den Bergh
#
# first line: T1	Organization 398 414;415 463	Hoog Edele Groot Agtb: Heeren Bewind hebberen ter kamer Amsterdam
#
# first line: T1	Person 240 256	Cornelis Potmans
#
# first line: T1	Indigenous 239 251	lijf eigenen
#
# first line: T1	Women 166 171	moede
#
# annotation file empty
# annotation file empty
# first line: T1	Men 122 126	Heer
#
# annotation file empty
# annotation file empty
# first line: T1	Person 524 530;531 543	Pieter an Ponningen
#
# annotation file empty
# first line: T1	Indigenous 526 534	slavinne
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 2798 2824	Anthonij Cornelis verspijk
#
# first line: T1	Person 1061 1073	Pieter Arons
#
# first line: T1	Indigenous 420 426	slaven
#
# annotation file empty
# first line: T1	GPE 15 22	Batavia
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Indigenous 364 380	hueys inboorling
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Indigenous 531 547	huijs inboorling
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Unclear_entity 205 238	Seven tien hondert Zes en twintig
#
# first line: T1	Person 2384 2400	Herman, Scheltus
#
# annotation file empty
# annotation file empty
# first line: T1	Men 88 92	heer
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T3	Person 1403 1428	ohannas Batthazar Davidsz
#
# first line: T1	Person 265 275;276 283	Jan phreu„ der Ool
#
# first line: T1	Person 124 141	Andries Jan Zalle
#
# first line: T1	GPE 23 30	Batavia
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Men 266 272	slaaff
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 85 106	Reynier Stapel Junior
#
# first line: T1	Men 118 122	Heer
#
# first line: T1	Person 372 377;378 393	Maria Anthonia Sweers
#
# first line: T1	Person 15 32	Cornelis valentyn
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Men 362 368;369 373	schoon Zoon
#
# first line: T1	Women 1198 1203	Juff„
#
# annotation file empty
# first line: T2	Women 1312 1318	Sister
#
# first line: T1	Women 96 102	moeder
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T2	Person 331 346	Abraham Alomons
#
# annotation file empty
# first line: T1	Men 158 162	Heer
#
# first line: T1	Men 117 120	m:r
#
# first line: T1	Person 117 132	Albraham Simogs
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	GPE 307 313	amstv:
#
# annotation file empty
# annotation file empty
# first line: T1	Person 500 517	Lanke van Coegies
#
# first line: T1	Person 942 958	Sirardus de Welo
#
# first line: T1	Organization 1318 1338	Heeren weesmeesteren
#
# annotation file empty
# annotation file empty
# first line: T1	Indigenous 1287 1303	huijs inboorling
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Women 1026 1030	nigt
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# first line: T1	Person 28 36	Breukels
#
# first line: T1	Person 271 287	Barend Carlelijn
#
# first line: T2	Person 91 108	Pieter Willem lam
#
# first line: T1	Person 626 633;634 642	Abraham Salomons
#
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty
# annotation file empty

# %%
data
# Out:
# {'NL-HaNA_1.04.02_6847_0758.txt': [(853, 860, 'ORGANIZATION', 'Politie'),
#   (1005, 1009, 'MEN', 'Heer'),
#   (1118, 1125, 'GPE', 'Batavia'),
#   (1207, 1217, 'WOMEN', 'huifsvrouw'),
#   (1218, 1223, 'WOMEN', 'mejuf'),
#   (1182, 1186, 'MEN', 'Heer')],
#  'NL-HaNA_1.04.02_6847_0764.txt': [(149, 158, 'WOMEN', 'degterlje'),
#   (397, 403, 'GPE', 'Europa'),
#   (1142, 1151, 'WOMEN', 'dogtertje'),
#   (1276, 1284, 'WOMEN', 'Juffrouw'),
#   (2092, 2111, 'ORGANIZATION', 'Heeren Weesmesteren')],
#  'NL-HaNA_1.04.02_6847_0016.txt': [(894, 911, 'GPE', 'nederlands Jordia'),
#   (940, 946, 'GPE', 'batera'),
#   (1791, 1800, 'WOMEN', 'Erfgename'),
#   (1824, 1830, 'INDIGENOUS', 'slaaff'),
#   (1844, 1852, 'INDIGENOUS', 'Slavinne'),
#   (1844, 1852, 'WOMEN', 'Slavinne'),
#   (1924, 1931, 'INDIGENOUS', 'slaeven')],
#  'NL-HaNA_1.04.02_6847_0770.txt': [(137,
#    191,
#    'ORGANIZATION',
#    "BewinP. „hebberen der g'octroijeerde coptimischhe Comp"),
#   (199, 214, 'ORGANIZATION', 'Kamer Amstersan'),
#   (205, 214, 'GPE', 'Amstersan'),
#   (487, 512, 'ORGANIZATION', 'Hooge Indjasche Regeering'),
#   (1401, 1439, 'ORGANIZATION', 'Hlaege Regeeringe van Nederlangs India'),
#   (1469, 1476, 'GPE', 'Batavia')],
#  'NL-HaNA_1.04.02_6847_0017.txt': [(122, 128, 'WOMEN', 'dogter'),
#   (429, 434, 'WOMEN', 'haker'),
#   (573, 579, 'WOMEN', 'Jnsf=m'),
#   (606, 610, 'WOMEN', 'wed:'),
#   (1442, 1447, 'MEN', 'mons:')],
#  'NL-HaNA_1.04.02_6847_0771.txt': [(256, 262, 'INDIGENOUS', 'slaven'),
#   (994,
#    1052,
#    'ORGANIZATION',
#    "Heeren Berind hebberen der g'eetregeerde d tindinhe Comp:e"),
#   (1057, 1072, 'ORGANIZATION', 'Kamer Amsterdam'),
#   (1063, 1072, 'GPE', 'Amsterdam'),
#   (1929, 1940, 'INDIGENOUS', 'lijfeigenen')],
#  'NL-HaNA_1.04.02_6847_0765.txt': [(268,
#    300,
#    'ORGANIZATION',
#    "g'Ectroijeerde oostjndische Comp"),
#   (306, 321, 'ORGANIZATION', 'Kamer Amsterdam'),
#   (312, 321, 'GPE', 'Amsterdam'),
#   (1129, 1142, 'INDIGENOUS', 'lijff eigenen'),
#   (718, 741, 'ORGANIZATION', 'Edele Hooge, regeeringe')],
#  'NL-HaNA_1.04.02_6847_0759.txt': [(2613,
#    2626,
#    'ORGANIZATION',
#    'weesmeesteren'),
#   (3264, 3273, 'GPE', 'Amsterdam')],
#  'NL-HaNA_1.04.02_6847_0029.txt': [(590, 596, 'WOMEN', 'moeden'),
#   (597, 604, 'WOMEN', 'Juff=mo'),
#   (628, 633, 'WOMEN', 'wed:e'),
#   (1054, 1072, 'WOMEN', 'natuurlijke dogter'),
#   (1661, 1669, 'GPE', 'Amstver:'),
#   (669, 672, 'MEN', 'dE:')],
#  'NL-HaNA_1.04.02_6847_0015.txt': [(421, 427, 'WOMEN', 'moeder'),
#   (428, 436, 'WOMEN', 'mesust=r'),
#   (459, 464, 'WOMEN', 'wed:e'),
#   (1070, 1075, 'MEN', 'voogd'),
#   (1080, 1089, 'WOMEN', 'voogdesse'),
#   (1790, 1801, 'MEN', 'agt: heeren'),
#   (2189, 2199, 'WOMEN', 'Testatrice'),
#   (133, 145, 'WOMEN', 'groot moeder'),
#   (277, 287, 'WOMEN', 'testatrice'),
#   (1868, 1878, 'GPE', 'am„ Herdan'),
#   (31, 40, 'MEN', 'testateur'),
#   (472, 474, 'MEN', 'dE')],
#  'NL-HaNA_1.04.02_6847_0767.txt': [(685,
#    704,
#    'ORGANIZATION',
#    'Heere weesmeesteren'),
#   (731, 738, 'GPE', 'Batavia'),
#   (924, 961, 'ORGANIZATION', 'Hooge Regeeringe van Nederlakds India'),
#   (992, 999, 'GPE', 'Batavia'),
#   (1088, 1096, 'ORGANIZATION', 'E: Comp:'),
#   (1184, 1190, 'MEN', 'Heeren'),
#   (1330, 1348, 'ORGANIZATION', 'Chineese korpitaal'),
#   (1330, 1348, 'INDIGENOUS', 'Chineese korpitaal')],
#  'NL-HaNA_1.04.02_6847_0766.txt': [(409, 413, 'MEN', 'Heer'),
#   (454, 469, 'GPE', 'Nederland india'),
#   (718, 725, 'GPE', 'Batavia'),
#   (883, 921, 'ORGANIZATION', 'EHooge Regeeringe van Nederlands India'),
#   (905, 921, 'GPE', 'Nederlands India'),
#   (948, 955, 'GPE', 'Batavia'),
#   (1080, 1126, 'GPE', 'wystzijne van de Grootte Rivier binnen destaet'),
#   (1055, 1062, 'ORGANIZATION', 'E: Comp'),
#   (1772, 1807, 'ORGANIZATION', 'almoesniers wdeshuijs tot Amsteriam'),
#   (2225, 2245, 'ORGANIZATION', 'Heeren Weesmeksteren'),
#   (2349, 2380, 'ORGANIZATION', 'Edele Hooge Indiasche Regeering'),
#   (2391, 2402, 'INDIGENOUS', 'lijfEigenen'),
#   (2512, 2517, 'INDIGENOUS', 'slaaf'),
#   (2512, 2517, 'MEN', 'slaaf'),
#   (2542, 2551, 'GPE', 'Soudratta'),
#   (2531, 2538, 'GPE', 'Malbaar'),
#   (2588, 2610, 'INDIGENOUS', 'vrije Onchriste vrouwe'),
#   (2604, 2610, 'WOMEN', 'vrouwe'),
#   (2623, 2634, 'GPE', 'Ben„ „galen')],
#  'NL-HaNA_1.04.02_6847_0014.txt': [(142, 149, 'GPE', 'Batavia'),
#   (357, 373, 'GPE', 'nederlands India'),
#   (402, 409, 'GPE', 'Batavia'),
#   (527, 535, 'WOMEN', 'mejnst=m'),
#   (2180, 2186, 'WOMEN', 'moeder'),
#   (2187, 2195, 'WOMEN', 'mesust=m'),
#   (2214, 2219, 'WOMEN', 'wed=e'),
#   (2230, 2234, 'MEN', 'heer'),
#   (2278, 2290, 'GPE', 'bellingwolde'),
#   (459, 461, 'MEN', 'dE')],
#  'NL-HaNA_1.04.02_6847_0028.txt': [(207, 213, 'MEN', 'neeven'),
#   (221, 224, 'WOMEN', 'ngt'),
#   (324, 330, 'GPE', 'schale'),
#   (497, 503, 'MEN', 'Heeren'),
#   (571, 582, 'GPE', 'amstveromme'),
#   (2474, 2481, 'GPE', 'batavia'),
#   (527, 530, 'MEN', 'M:r')],
#  'NL-HaNA_1.04.02_6847_0762.txt': [(80,
#    100,
#    'ORGANIZATION',
#    'Heeren weesmeesteren'),
#   (306, 313, 'GPE', 'Holland'),
#   (329, 341, 'GPE', 'Amster „dam,'),
#   (418, 434, 'GPE', "'tGaaven Ergedag"),
#   (538, 555, 'ORGANIZATION', 'oostjndische Comp'),
#   (611, 619, 'GPE', 'Bestavia'),
#   (696, 703, 'GPE', 'Batavia'),
#   (1044, 1051, 'GPE', 'Batavia'),
#   (1017, 1033, 'ORGANIZATION', 'Kleede Pakthuijs'),
#   (1186, 1193, 'GPE', 'Batavia'),
#   (1369, 1375, 'MEN', 'Heeren'),
#   (1478, 1482, 'MEN', 'Heer'),
#   (2005, 2016, 'GPE', 'Ooslijndien')],
#  'NL-HaNA_1.04.02_6847_0038.txt': [(757, 764, 'GPE', 'batavia'),
#   (854, 864, 'GPE', 'De Lahaije'),
#   (985, 991, 'WOMEN', 'vrouwe'),
#   (1463, 1471, 'WOMEN', 'mevrouwe'),
#   (1512, 1519, 'GPE', 'Batavia'),
#   (1721, 1737, 'GPE', 'nederlands india'),
#   (1765, 1772, 'GPE', 'batavia'),
#   (1822, 1825, 'MEN', 'dE:')],
#  'NL-HaNA_1.04.02_6847_0830.txt': [(2034,
#    2049,
#    'INDIGENOUS',
#    'huis inboorling'),
#   (2050, 2058, 'INDIGENOUS', 'slavinne')],
#  'NL-HaNA_1.04.02_6847_0039.txt': [(200,
#    222,
#    'ORGANIZATION',
#    'gereformeerde diaconie'),
#   (285, 307, 'ORGANIZATION', 'gereformeerde diaconie'),
#   (312, 323, 'GPE', 'nogo patnam'),
#   (366, 373, 'MEN', 'broeder'),
#   (426, 436, 'GPE', 'nagapatnam'),
#   (449, 454, 'WOMEN', 'Ins=m'),
#   (483, 486, 'MEN', 'man'),
#   (532, 543, 'GPE', 'pack poeram'),
#   (869, 876, 'MEN', 'broeder'),
#   (911, 914, 'MEN', 'man'),
#   (892, 897, 'WOMEN', 'Iup=m'),
#   (1147, 1167, 'INDIGENOUS', 'vrije Cristene vrouw'),
#   (1147, 1167, 'WOMEN', 'vrije Cristene vrouw'),
#   (1289, 1297, 'INDIGENOUS', 'slavinne'),
#   (1289, 1297, 'WOMEN', 'slavinne'),
#   (1330, 1358, 'WOMEN', 'Enlandsche Crietene persoone'),
#   (1330, 1358, 'INDIGENOUS', 'Enlandsche Crietene persoone'),
#   (1389, 1398, 'GPE', 'nagapatn:'),
#   (1680, 1687, 'MEN', 'broeder'),
#   (1712, 1716, 'WOMEN', 'nigt'),
#   (2138, 2141, 'MEN', 'VE:'),
#   (374, 377, 'MEN', 'dE:'),
#   (487, 490, 'MEN', 'dE:')],
#  'NL-HaNA_1.04.02_6847_0763.txt': [(196, 200, 'MEN', 'Heer'),
#   (246, 258, 'ORGANIZATION', 'water geregt'),
#   (335, 339, 'MEN', 'Heer'),
#   (386, 406, 'ORGANIZATION', 'Heeren Weermeesteren'),
#   (644, 653, 'GPE', 'Amsterdam'),
#   (936, 973, 'ORGANIZATION', 'hooge regeeringe van Nederlands India'),
#   (1001, 1008, 'GPE', 'Batavia'),
#   (957, 973, 'GPE', 'Nederlands India'),
#   (1151, 1159, 'WOMEN', 'Iuffrouw'),
#   (1855, 1859, 'MEN', 'Heer'),
#   (1846, 1851, 'MEN', 'vader'),
#   (1909, 1918, 'GPE', 'amersfort'),
#   (2078, 2086, 'MEN', 'doopzoon'),
#   (2108, 2112, 'MEN', 'zoon'),
#   (2153, 2161, 'GPE', 'Samarang')],
#  'NL-HaNA_1.04.02_6847_0011.txt': [(357, 361, 'MEN', 'heer'),
#   (292, 299, 'GPE', 'batnera'),
#   (791, 795, 'MEN', 'heer'),
#   (1350, 1357, 'MEN', 'opperm:'),
#   (1398, 1404, 'WOMEN', 'Zuster'),
#   (1405, 1411, 'WOMEN', 'Jnst=m'),
#   (1652, 1658, 'MEN', 'heeren'),
#   (1669, 1672, 'MEN', 'dE:'),
#   (1914, 1919, 'GPE', 'amstv'),
#   (2312, 2315, 'MEN', 'dE:'),
#   (248, 264, 'GPE', 'nederlands Jndia'),
#   (1781, 1785, 'MEN', 'heer'),
#   (1786, 1796, 'MEN', 'testateurs'),
#   (796, 805, 'MEN', 'Testateur'),
#   (417, 439, 'GPE', 'nederdui Vshegemeen te'),
#   (1317, 1325, 'GPE', 'maleydse')],
#  'NL-HaNA_1.04.02_6847_0761.txt': [(384, 390, 'MEN', 'Swager'),
#   (695, 705, 'ORGANIZATION', 'Edele Comp'),
#   (981, 1015, 'ORGANIZATION', 'Collegief van Heeten weermeesteren'),
#   (1336, 1369, 'ORGANIZATION', 'dergoetroyeerde costjueische Comp'),
#   (1374, 1389, 'ORGANIZATION', 'Kamer Amsterdam'),
#   (1380, 1389, 'GPE', 'Amsterdam'),
#   (2709, 2717, 'ORGANIZATION', 'E: Comp:')],
#  'NL-HaNA_1.04.02_6847_0013.txt': [(250, 266, 'GPE', 'nederlands Jonra'),
#   (294, 301, 'GPE', 'batmera'),
#   (360, 364, 'MEN', 'heer'),
#   (1405, 1411, 'WOMEN', 'Zuster'),
#   (1412, 1417, 'WOMEN', 'Jns=m'),
#   (1786, 1790, 'MEN', 'heer'),
#   (1274, 1276, 'MEN', 'dE'),
#   (2320, 2323, 'MEN', 'dE:')],
#  'NL-HaNA_1.04.02_6847_0749.txt': [(169, 178, 'WOMEN', 'Meuffrouw'),
#   (162, 168, 'WOMEN', 'do ter'),
#   (200, 210, 'WOMEN', 'Huijsvrouw'),
#   (278, 283, 'INDIGENOUS', 'slaaf'),
#   (334, 342, 'INDIGENOUS', 'slavinne'),
#   (334, 342, 'WOMEN', 'slavinne'),
#   (542, 546, 'MEN', 'zoon'),
#   (621, 638, 'ORGANIZATION', 'Comploir generaal'),
#   (642, 645, 'INDIGENOUS', 'slf'),
#   (661, 665, 'WOMEN', 'wijf'),
#   (720, 725, 'INDIGENOUS', 'Slaaf'),
#   (1074, 1082, 'GPE', 'Sumatras'),
#   (1058, 1070, 'GPE', 'Goelo Chincu'),
#   (1242, 1252, 'WOMEN', 'Mejuffrouw'),
#   (1508, 1512, 'MEN', 'Heer'),
#   (1576, 1582, 'WOMEN', 'Suster'),
#   (1583, 1593, 'WOMEN', 'Mejuffrouw'),
#   (2192, 2200, 'INDIGENOUS', 'Inlander'),
#   (2489, 2495, 'MEN', 'Heeren'),
#   (2496, 2509, 'ORGANIZATION', 'wegsmeesteren'),
#   (218, 223, 'MEN', 'E: mH')],
#  'NL-HaNA_1.04.02_6847_0748.txt': [(877, 887, 'WOMEN', 'Huijevrouw'),
#   (911, 918, 'GPE', 'Batavia'),
#   (935, 945, 'WOMEN', 'erfgenaame'),
#   (1129, 1135, 'WOMEN', 'weduwe'),
#   (1116, 1125, 'WOMEN', 'Mejufrouw'),
#   (1058, 1062, 'MEN', 'Heer'),
#   (436, 466, 'MEN', 'alleu Heere'),
#   (983, 989, 'WOMEN', 'hogter'),
#   (1202, 1209, 'GPE', 'Batavia'),
#   (1363, 1393, 'ORGANIZATION', 'Regeering van Nederlands Jndia'),
#   (1422, 1429, 'GPE', 'Batavia'),
#   (1477, 1495, 'MEN', 'den Eerwaarde Heer'),
#   (1551, 1573, 'ORGANIZATION', 'nedertuijsche gemeente'),
#   (1632, 1638, 'GPE', 'Padang'),
#   (1653, 1661, 'GPE', 'Surmatra'),
#   (1996, 2000, 'MEN', 'Heer'),
#   (2195, 2205, 'INDIGENOUS', 'inboorling'),
#   (2124, 2136, 'INDIGENOUS', 'lijf ergenen'),
#   (1315, 1317, 'MEN', 'm:'),
#   (2189, 2205, 'INDIGENOUS', 'huijs inboorling')],
#  'NL-HaNA_1.04.02_6847_0760.txt': [(1591, 1598, 'GPE', 'Malacca'),
#   (2187, 2202, 'GPE', 'Nedetland India'),
#   (2368, 2375, 'MEN', 'Iongman'),
#   (2929, 2934, 'MEN', 'wager'),
#   (2938, 2944, 'WOMEN', 'Hluste'),
#   (3085, 3096, 'WOMEN', 'huijs vrouw'),
#   (3097, 3104, 'WOMEN', 'Iufrouw')],
#  'NL-HaNA_1.04.02_6847_0049.txt': [(657, 674, 'GPE', 'nederlands in dea'),
#   (704, 711, 'GPE', 'batavia'),
#   (765, 769, 'MEN', 'Heer'),
#   (875, 882, 'WOMEN', 'mepst=m'),
#   (1000, 1006, 'WOMEN', 'Jnst=r'),
#   (595, 598, 'MEN', 'm:r')],
#  'NL-HaNA_1.04.02_6847_0061.txt': [(1210, 1215, 'GPE', 'Javra'),
#   (1343, 1350, 'GPE', 'malacca'),
#   (1827, 1839, 'INDIGENOUS', 'sla„ verrije'),
#   (1879, 1892, 'INDIGENOUS', 'lijf eijgenen'),
#   (1930, 1933, 'WOMEN', 'wij'),
#   (2019, 2024, 'WOMEN', 'wijff'),
#   (1111, 1114, 'MEN', 'm:r')],
#  'NL-HaNA_1.04.02_6847_0075.txt': [(156, 159, 'MEN', 'M:r'),
#   (225, 241, 'GPE', 'nederlands India'),
#   (271, 278, 'GPE', 'Batavia'),
#   (1124, 1138, 'ORGANIZATION', 'Lutersche kork'),
#   (1241, 1261, 'INDIGENOUS', 'vrije Christen vrouw'),
#   (1241, 1261, 'WOMEN', 'vrije Christen vrouw'),
#   (1642, 1649, 'GPE', 'Alkmaar'),
#   (2037, 2044, 'MEN', 'zoontje'),
#   (1609, 1613, 'MEN', 'heer')],
#  'NL-HaNA_1.04.02_6847_0288.txt': [(427, 436, 'ORGANIZATION', 'Weeskamer'),
#   (1446, 1479, 'ORGANIZATION', 'Collegie van Heeren weesmeesteren'),
#   (1711,
#    1818,
#    'ORGANIZATION',
#    'De welEdele Groot Agtb: Heeren bewindhebberen der geocrraijeerde oost Jndisch Compagnie ter kamer Amsterdam'),
#   (1809, 1818, 'GPE', 'Amsterdam')],
#  'NL-HaNA_1.04.02_6847_0505.txt': [(1984, 1994, 'GPE', 'maastreiht'),
#   (1941, 1948, 'MEN', 'de heer'),
#   (1142, 1150, 'INDIGENOUS', 'slafsche'),
#   (1213, 1223, 'INDIGENOUS', 'lyfeigenen'),
#   (1397, 1404, 'GPE', 'batavia'),
#   (1263, 1267, 'WOMEN', 'wijf'),
#   (1673, 1679, 'INDIGENOUS', 'slaeff'),
#   (1673, 1679, 'MEN', 'slaeff'),
#   (1700, 1704, 'GPE', 'Nias'),
#   (1567, 1596, 'INDIGENOUS', 'bereeds vrijgegevene slavinne'),
#   (1588, 1596, 'WOMEN', 'slavinne'),
#   (1616, 1623, 'GPE', 'Amboina'),
#   (1627, 1641, 'INDIGENOUS', 'haere kinderen'),
#   (2291, 2295, 'GPE', 'zwol')],
#  'NL-HaNA_1.04.02_6847_0263.txt': [(241, 248, 'GPE', 'Batavia'),
#   (943, 951, 'MEN', 'den Heer'),
#   (1485, 1490, 'WOMEN', 'vrouw'),
#   (1467, 1490, 'INDIGENOUS', 'vrije onchristene vrouw')],
#  'NL-HaNA_1.04.02_6847_0277.txt': [(369,
#    440,
#    'INDIGENOUS',
#    'slaven die beleijdenisse van den Christelijken Podsdienst gedaan hebben'),
#   (1145, 1152, 'GPE', 'Batavia'),
#   (1365, 1377, 'GPE', 'stad Batavia'),
#   (1517, 1523, 'WOMEN', 'Memttw')],
#  'NL-HaNA_1.04.02_6847_0511.txt': [(113,
#    158,
#    'ORGANIZATION',
#    'de Edele hooge regeering van nederlands India'),
#   (172, 194, 'GPE', 'binnen de stad Batavia'),
#   (240, 245, 'MEN', 'Den E'),
#   (824, 829, 'MEN', 'den E'),
#   (945, 952, 'MEN', 'de Heer'),
#   (1002, 1009, 'ORGANIZATION', 'E: Comp'),
#   (1273, 1280, 'MEN', 'broeder'),
#   (1281, 1283, 'MEN', 'DE'),
#   (1312, 1321, 'GPE', 'Amsterdam'),
#   (1483, 1492, 'MEN', 'testateur')],
#  'NL-HaNA_1.04.02_6847_0100.txt': [(1352, 1358, 'INDIGENOUS', 'slaven'),
#   (1363, 1372, 'WOMEN', 'slavinnen'),
#   (1363, 1372, 'INDIGENOUS', 'slavinnen'),
#   (302, 309, 'MEN', 'dE: M:r')],
#  'NL-HaNA_1.04.02_6847_0276.txt': [(1902,
#    2005,
#    'ORGANIZATION',
#    'WelEdele Groot Agtb: Heeren Bewind. hebberen der Geostroijeerde oost Jndische Comp: ter kamer Amsterdam'),
#   (43, 53, 'WOMEN', 'testatrice'),
#   (29, 39, 'WOMEN', 'huijsvrouw'),
#   (1034, 1043, 'WOMEN', 'Excutrice')],
#  'NL-HaNA_1.04.02_6847_0510.txt': [(185, 203, 'GPE', 'de Theewaterstraat'),
#   (297, 313, 'GPE', 'de kaijmansgragt'),
#   (344, 359, 'GPE', 'de tijgersgragt'),
#   (367, 401, 'GPE', 'op de hoek van de Amsterdam graagt'),
#   (524, 556, 'GPE', 'de angiolse vaart buijten destad'),
#   (667, 679, 'INDIGENOUS', 'LijfEijgenen'),
#   (1084, 1096, 'INDIGENOUS', 'LijfEijgenen'),
#   (2717, 2724, 'GPE', 'Batavia'),
#   (24, 70, 'GPE', 'de westzijde van de heere straet binnen destad'),
#   (848, 857, 'MEN', 'testateur'),
#   (220, 233, 'ORGANIZATION', 'Lutherse kerk')],
#  'NL-HaNA_1.04.02_6847_0504.txt': [(775, 781, 'INDIGENOUS', 'slaven'),
#   (1428, 1430, 'MEN', 'M:'),
#   (1476, 1512, 'ORGANIZATION', 'hooge regeering van nederlands india'),
#   (1541, 1548, 'GPE', 'Batavia'),
#   (1640,
#    1717,
#    'ORGANIZATION',
#    'raad ord„s van Nederlands india en president in ’t Eerw„s Collegie van heeren'),
#   (2285, 2291, 'WOMEN', 'dogter'),
#   (2150, 2154, 'MEN', 'Heer'),
#   (1752, 1761, 'MEN', 'de Heeren'),
#   (1655, 1671, 'GPE', 'Nederlands india')],
#  'NL-HaNA_1.04.02_6847_0262.txt': [(227, 235, 'GPE', 'Geoninge')],
#  'NL-HaNA_1.04.02_6847_0289.txt': [(1172, 1181, 'ORGANIZATION', 'wee kamer'),
#   (1219, 1239, 'ORGANIZATION', 'Heeren Weesmeesteren'),
#   (1267, 1274, 'GPE', 'Batavia'),
#   (425, 459, 'ORGANIZATION', 'Edele Hooge Regeering deser Landen'),
#   (1586, 1592, 'GPE', 'pisang')],
#  'NL-HaNA_1.04.02_6847_0074.txt': [(342, 348, 'MEN', 'sijnen'),
#   (349, 355, 'INDIGENOUS', 'slaaff'),
#   (779, 783, 'MEN', 'mons'),
#   (2557, 2564, 'GPE', 'batavia')],
#  'NL-HaNA_1.04.02_6847_0060.txt': [],
#  'NL-HaNA_1.04.02_6847_0048.txt': [(252, 263, 'WOMEN', 'haar moeder'),
#   (264, 270, 'WOMEN', 'Just=m'),
#   (295, 300, 'WOMEN', 'wed=e'),
#   (408, 414, 'WOMEN', 'moeder'),
#   (780, 784, 'MEN', 'heer')],
#  'NL-HaNA_1.04.02_6847_0089.txt': [(873, 889, 'GPE', 'nederlands India'),
#   (919, 926, 'GPE', 'Batavia'),
#   (2018, 2024, 'MEN', 'mons:r'),
#   (798, 801, 'MEN', 'M:r'),
#   (977, 980, 'MEN', 'DE:'),
#   (1513, 1520, 'MEN', 'dE: M:r'),
#   (1659, 1662, 'MEN', 'dE:')],
#  'NL-HaNA_1.04.02_6847_0076.txt': [(242, 254, 'INDIGENOUS', 'lijf eigenen'),
#   (340, 346, 'INDIGENOUS', 'slaaff'),
#   (771, 776, 'MEN', 'mons:'),
#   (2546, 2553, 'GPE', 'batavia')],
#  'NL-HaNA_1.04.02_6847_0062.txt': [],
#  'NL-HaNA_1.04.02_6847_0512.txt': [(165, 174, 'GPE', 'Amsterdam'),
#   (484, 496, 'INDIGENOUS', 'LijfEijgenen'),
#   (2342, 2349, 'GPE', 'Batavia'),
#   (2295, 2301, 'MEN', 'Heeren'),
#   (340, 349, 'MEN', 'testateur')],
#  'NL-HaNA_1.04.02_6847_0274.txt': [(245,
#    351,
#    'ORGANIZATION',
#    'de welEdele Groot Agtb: Hee rend Bewindhebberen der Geoctroijeerde oost indische Comp: ter kamer Amsterdam'),
#   (849, 863, 'INDIGENOUS', 'Leijf Eijgenen')],
#  'NL-HaNA_1.04.02_6847_0260.txt': [],
#  'NL-HaNA_1.04.02_6847_0506.txt': [(54, 63, 'WOMEN', 'me jusf=r'),
#   (1076, 1085, 'MEN', 'de heeren'),
#   (1232, 1238, 'WOMEN', 'dogter'),
#   (1365, 1381, 'GPE', 'nederlands india'),
#   (1417, 1427, 'MEN', 'van heeren'),
#   (1466, 1473, 'MEN', 'de heer'),
#   (2334, 2339, 'WOMEN', 'frouw'),
#   (2127, 2136, 'GPE', 'amsterdam'),
#   (1770, 1775, 'WOMEN', 'wed„e'),
#   (1746, 1752, 'WOMEN', 'Mejuff'),
#   (633, 638, 'MEN', 'den E'),
#   (672, 677, 'MEN', 'zomen'),
#   (898, 905, 'MEN', 'de heer'),
#   (828, 832, 'MEN', 'heer')],
#  'NL-HaNA_1.04.02_6847_0261.txt': [(686, 693, 'GPE', 'Amboina')],
#  'NL-HaNA_1.04.02_6847_0507.txt': [(573, 580, 'GPE', 'Batavia'),
#   (1154, 1156, 'MEN', 'DE'),
#   (1382, 1386, 'MEN', 'heer'),
#   (1608, 1615, 'GPE', 'Batavia'),
#   (2208,
#    2254,
#    'ORGANIZATION',
#    'de Edele hooge Regeeringe van Nederlands India'),
#   (2283, 2290, 'GPE', 'Batavia'),
#   (2339, 2341, 'MEN', 'DE'),
#   (2168, 2171, 'MEN', 'M:r')],
#  'NL-HaNA_1.04.02_6847_0513.txt': [(103,
#    148,
#    'ORGANIZATION',
#    'debaele hoge regeeringe van nederslands India'),
#   (162, 184, 'GPE', 'binnen de stad Batavia'),
#   (230, 247, 'MEN', 'De wel Edele Heer'),
#   (874, 886, 'INDIGENOUS', 'lijfeijgenen'),
#   (1491, 1497, 'WOMEN', 'Juff„r'),
#   (1528, 1531, 'WOMEN', 'wed'),
#   (1554, 1558, 'MEN', 'zoon'),
#   (1720, 1737, 'INDIGENOUS', 'de vrije Christen'),
#   (1738, 1743, 'WOMEN', 'Vrouw'),
#   (2139, 2151, 'INDIGENOUS', 'lijfeijgenen'),
#   (1559, 1565, 'MEN', 'DE M„r')],
#  'NL-HaNA_1.04.02_6847_0275.txt': [(151, 158, 'GPE', 'Batavia'),
#   (332,
#    379,
#    'ORGANIZATION',
#    'de Edele Hooge Regeering dan Neder„ lands India'),
#   (401, 418, 'GPE', 'de stad Bata„ via'),
#   (525, 531, 'WOMEN', 'Iuff=r'),
#   (1017, 1061, 'ORGANIZATION', 'Gereformeerde'),
#   (1052, 1061, 'GPE', 'Amsterdam')],
#  'NL-HaNA_1.04.02_6847_0063.txt': [(1166, 1182, 'GPE', 'nederlands india'),
#   (1210, 1219, 'GPE', 'ba„ favra'),
#   (1349, 1356, 'GPE', 'malacca'),
#   (1836, 1848, 'INDIGENOUS', 'sla„ vernije'),
#   (1889, 1901, 'INDIGENOUS', 'lijf eidenen'),
#   (1939, 1942, 'WOMEN', 'wij'),
#   (2028, 2033, 'WOMEN', 'wijff')],
#  'NL-HaNA_1.04.02_6847_0077.txt': [(158, 161, 'MEN', 'M:r'),
#   (227, 243, 'GPE', 'nederlands India'),
#   (273, 280, 'GPE', 'Batavia'),
#   (1123, 1137, 'ORGANIZATION', 'Lutersche kork'),
#   (1240, 1260, 'INDIGENOUS', 'vrije Christen vrouw'),
#   (1240, 1260, 'WOMEN', 'vrije Christen vrouw'),
#   (1611, 1615, 'MEN', 'heer'),
#   (1644, 1650, 'GPE', 'Alkmaa'),
#   (2039, 2046, 'MEN', 'zoontje')],
#  'NL-HaNA_1.04.02_6847_0088.txt': [(148, 152, 'MEN', 'Heer'),
#   (1474, 1480, 'WOMEN', 'dogter'),
#   (1490, 1500, 'WOMEN', 'Erfgenaame'),
#   (1560, 1580, 'WOMEN', 'vaije Christen vrouw'),
#   (1725, 1734, 'WOMEN', 'doctertje'),
#   (1864, 1869, 'INDIGENOUS', 'slaaf'),
#   (1883, 1891, 'INDIGENOUS', 'Slavinne'),
#   (1883, 1891, 'WOMEN', 'Slavinne'),
#   (2318, 2331, 'INDIGENOUS', 'LijffEijgenen'),
#   (228, 231, 'MEN', 'DE:')],
#  'NL-HaNA_1.04.02_6847_0098.txt': [(32, 38, 'MEN', 'zoonen'),
#   (91, 102, 'MEN', 'schoon zoon'),
#   (125, 135, 'GPE', 'Nagapatnam'),
#   (435, 441, 'WOMEN', 'dogter'),
#   (590, 596, 'WOMEN', 'dogter'),
#   (1757, 1763, 'INDIGENOUS', 'slaven')],
#  'NL-HaNA_1.04.02_6847_0073.txt': [(225, 241, 'GPE', 'nederlands India'),
#   (271, 278, 'GPE', 'Batavia'),
#   (1120, 1134, 'ORGANIZATION', 'Lutersche kork'),
#   (1238, 1258, 'WOMEN', 'vrije Christen vrouw'),
#   (1238, 1258, 'INDIGENOUS', 'vrije Christen vrouw'),
#   (1608, 1612, 'MEN', 'heer'),
#   (1641, 1648, 'GPE', 'Alkmaar'),
#   (2036, 2043, 'MEN', 'zoontje'),
#   (156, 159, 'MEN', 'M:r')],
#  'NL-HaNA_1.04.02_6847_0067.txt': [],
#  'NL-HaNA_1.04.02_6847_0271.txt': [(258, 264, 'WOMEN', 'Suster'),
#   (310, 321, 'GPE', 'Amster„ dam'),
#   (365, 371, 'WOMEN', 'zuster'),
#   (422, 429, 'GPE', 'Teerdam'),
#   (504, 511, 'WOMEN', 'suester'),
#   (601, 612, 'GPE', 'S=t Maarten'),
#   (645, 651, 'WOMEN', 'Suster'),
#   (705, 712, 'MEN', 'Broeder'),
#   (546, 564, 'MEN', 'den wel Eerw: Heer')],
#  'NL-HaNA_1.04.02_6847_0517.txt': [(143, 152, 'GPE', 'rotterdam'),
#   (200, 206, 'MEN', 'deheer'),
#   (228, 234, 'WOMEN', 'vrouwe')],
#  'NL-HaNA_1.04.02_6847_0503.txt': [(71, 77, 'GPE', 'Europa'),
#   (159, 166, 'MEN', 'voogden'),
#   (1103, 1111, 'WOMEN', 'Mejuff=r'),
#   (1379, 1388, 'GPE', 'nederland'),
#   (458, 467, 'GPE', 'nederland'),
#   (616, 624, 'INDIGENOUS', 'slavinne'),
#   (677, 686, 'INDIGENOUS', 'slaevinne'),
#   (486, 493, 'WOMEN', 'dogters'),
#   (2164, 2183, 'ORGANIZATION', 'oost in dische Comp'),
#   (2195, 2204, 'GPE', 'Amsterdam'),
#   (2038, 2042, 'MEN', 'Ed„e'),
#   (1985, 1992, 'ORGANIZATION', 'dE Comp')],
#  'NL-HaNA_1.04.02_6847_0265.txt': [(253,
#    335,
#    'INDIGENOUS',
#    'de LeijtEijgenen, die belijdenis van den Christelijken Gods„ dienst gedaan hebben;'),
#   (138, 170, 'ORGANIZATION', 'de Edele hooge Indiase Regeering'),
#   (1294, 1299, 'WOMEN', 'vrouw'),
#   (1245, 1254, 'WOMEN', 'dogtertje'),
#   (1245, 1254, 'INDIGENOUS', 'dogtertje'),
#   (1577, 1585, 'MEN', 'manslaaf'),
#   (1743, 1748, 'WOMEN', 'vrouw'),
#   (1779, 1800, 'WOMEN', 'vrije ontristen vrouw'),
#   (1779, 1800, 'INDIGENOUS', 'vrije ontristen vrouw'),
#   (1726, 1748, 'INDIGENOUS', 'vrije onchristen vrouw'),
#   (1577, 1585, 'INDIGENOUS', 'manslaaf'),
#   (1283, 1299, 'INDIGENOUS', 'onchristen vrouw')],
#  'NL-HaNA_1.04.02_6847_0259.txt': [],
#  'NL-HaNA_1.04.02_6847_0258.txt': [(452, 460, 'MEN', 'den heer'),
#   (1216, 1223, 'GPE', 'Batavia'),
#   (120, 143, 'ORGANIZATION', 'heeren Commissarissen')],
#  'NL-HaNA_1.04.02_6847_0502.txt': [(772,
#    798,
#    'GPE',
#    'Frankena Gutenand Collonee'),
#   (1172, 1205, 'ORGANIZATION', 'latijnsche schoolen tot amsterdam'),
#   (1265, 1274, 'GPE', 'Amsterdam'),
#   (989, 993, 'MEN', 'zoon'),
#   (1127, 1136, 'MEN', 'de heeren'),
#   (1299, 1308, 'MEN', 'de heeren'),
#   (1435, 1444, 'MEN', 'de heeren'),
#   (1496, 1506, 'GPE', 'amsterdann'),
#   (1590, 1599, 'GPE', 'nederland'),
#   (2302, 2309, 'WOMEN', 'dogters'),
#   (1059, 1065, 'WOMEN', 'weduwe'),
#   (813, 818, 'ORGANIZATION', 'sComp'),
#   (114, 118, 'MEN', 'heer'),
#   (683, 689, 'MEN', 'de hee'),
#   (837, 843, 'MEN', 'de hee'),
#   (881, 884, 'MEN', 'dE:'),
#   (953, 962, 'MEN', 'de heeren'),
#   (1073, 1080, 'MEN', 'de heer')],
#  'NL-HaNA_1.04.02_6847_0264.txt': [(5, 9, 'MEN', 'Heer'),
#   (573, 577, 'MEN', 'Heer'),
#   (1210,
#    1282,
#    'ORGANIZATION',
#    'Bewindhebberen der Geoctroieerde oost jndische Comp: ter kamer Amsterdam'),
#   (1178, 1209, 'MEN', 'De Wel Edele groot Agtb: Heeren'),
#   (1752, 1766, 'INDIGENOUS', 'Leijt bijgenen')],
#  'NL-HaNA_1.04.02_6847_0270.txt': [(93,
#    200,
#    'ORGANIZATION',
#    'De welEdele Groot Agtbaren Heeren Bewindhebberen der Geoptroijeerde Oost Jndische Comp: ter kamer Amsterdam'),
#   (191, 200, 'GPE', 'Amsterdam'),
#   (824, 869, 'ORGANIZATION', 'de Edele Hooge Regeering van Nederlands India'),
#   (892, 904, 'GPE', 'stad Batavia'),
#   (1448, 1453, 'WOMEN', 'vrouw'),
#   (1642, 1649, 'WOMEN', 'meijden'),
#   (1432, 1453, 'INDIGENOUS', 'vrije Chris ten vrouw'),
#   (1738, 1756, 'INDIGENOUS', 'den vrije papanger'),
#   (1748, 1756, 'GPE', 'papanger')],
#  'NL-HaNA_1.04.02_6847_0516.txt': [(17, 24, 'GPE', 'Luijden'),
#   (243, 250, 'GPE', 'batavia'),
#   (276, 279, 'MEN', 'M„r'),
#   (460, 463, 'MEN', 'S„r'),
#   (583, 590, 'GPE', 'batavia'),
#   (760, 767, 'GPE', 'batavia'),
#   (788, 797, 'MEN', 'de heeren'),
#   (895, 902, 'GPE', 'Batavia'),
#   (1149, 1155, 'MEN', 'heeren'),
#   (2713, 2720, 'GPE', 'Batavia')],
#  'NL-HaNA_1.04.02_6847_0066.txt': [(119, 127, 'WOMEN', 'Slavinne'),
#   (119, 127, 'INDIGENOUS', 'Slavinne'),
#   (158, 164, 'WOMEN', 'dogter'),
#   (458, 469, 'INDIGENOUS', 'slaven, nen'),
#   (500, 506, 'WOMEN', 'dogter'),
#   (1150, 1168, 'WOMEN', 'vrije Cristen vion'),
#   (1150, 1168, 'INDIGENOUS', 'vrije Cristen vion'),
#   (1497, 1516, 'WOMEN', 'vrije fristen vrouw'),
#   (1497, 1516, 'INDIGENOUS', 'vrije fristen vrouw')],
#  'NL-HaNA_1.04.02_6847_0072.txt': [(247, 259, 'INDIGENOUS', 'lijf eigenen'),
#   (347, 353, 'INDIGENOUS', 'slaaff'),
#   (787, 792, 'MEN', 'mons:'),
#   (2310, 2319, 'GPE', 'Jagerspad')],
#  'NL-HaNA_1.04.02_6847_0099.txt': [(882, 889, 'GPE', 'Batavia'),
#   (1156, 1163, 'GPE', 'Batavia'),
#   (1321, 1338, 'GPE', 'Nederlands India,'),
#   (1877, 1884, 'WOMEN', 'Susters'),
#   (1923, 1932, 'WOMEN', 'huisvrouw'),
#   (1991, 1998, 'GPE', 'Jocarta'),
#   (2192, 2198, 'MEN', 'zwager'),
#   (1213, 1216, 'MEN', 'dE:'),
#   (443, 447, 'MEN', 'heer')],
#  'NL-HaNA_1.04.02_6847_0064.txt': [],
#  'NL-HaNA_1.04.02_6847_0070.txt': [(62, 67, 'WOMEN', 'JnW=m'),
#   (614, 627, 'INDIGENOUS', 'lijf eijgenen'),
#   (728, 736, 'INDIGENOUS', 'Slavinne'),
#   (728, 736, 'WOMEN', 'Slavinne'),
#   (885, 890, 'MEN', 'Ionge'),
#   (1848, 1852, 'MEN', 'heer'),
#   (1838, 1843, 'MEN', 'vader'),
#   (2151, 2156, 'MEN', 'vader'),
#   (3011, 3015, 'MEN', 'heer'),
#   (3097, 3107, 'INDIGENOUS', 'inlanderen'),
#   (876, 890, 'INDIGENOUS', 'de vrije Ionge')],
#  'NL-HaNA_1.04.02_6847_0058.txt': [],
#  'NL-HaNA_1.04.02_6847_0266.txt': [(584, 591, 'GPE', 'Batavia'),
#   (781, 823, 'ORGANIZATION', 'Edele Hooge Regeering van Nederlands India'),
#   (850, 862, 'GPE', 'Stad Batavia'),
#   (924, 926, 'MEN', 'DE'),
#   (1029, 1047, 'GPE', 'Rotterdammer poort'),
#   (1638, 1643, 'WOMEN', 'vrouw'),
#   (1628, 1637, 'GPE', 'maleijtse'),
#   (1622, 1643, 'INDIGENOUS', 'vrije maleijtse vrouw'),
#   (114, 121, 'MEN', 'de Heer')],
#  'NL-HaNA_1.04.02_6847_0514.txt': [(162, 172, 'INDIGENOUS', 'boorlingen'),
#   (243, 252, 'MEN', 'testateur'),
#   (264, 274, 'WOMEN', 'huijsvrouw'),
#   (362, 375, 'INDIGENOUS', 'lijffeijgenen'),
#   (385, 394, 'MEN', 'testateur'),
#   (626, 633, 'WOMEN', 'Juff=re'),
#   (928, 938, 'WOMEN', 'huijsvrouw'),
#   (1020, 1024, 'MEN', 'zoon'),
#   (1315, 1319, 'MEN', 'zoon'),
#   (1564, 1573, 'MEN', 'testateur'),
#   (1496, 1505, 'GPE', 'uijtrecht'),
#   (1871, 1877, 'WOMEN', 'Moeder'),
#   (77, 94, 'GPE', 'batavia bij nases'),
#   (109, 116, 'GPE', 'batavia'),
#   (4, 9, 'GPE', 'balij'),
#   (61, 68, 'GPE', 'batavia'),
#   (1384, 1393, 'GPE', 'uijtrecht'),
#   (154, 172, 'INDIGENOUS', 'hujs in boorlingen'),
#   (22, 27, 'GPE', 'Bwool'),
#   (40, 46, 'GPE', 'boegis')],
#  'NL-HaNA_1.04.02_6847_0272.txt': [(422,
#    532,
#    'ORGANIZATION',
#    'DE wel Edele Groot tg „baaren Heeren Bewind hebberan der geoctaateerde oog Jndesche Comp: ter kamier Amsterdam'),
#   (523, 532, 'GPE', 'Amsterdam'),
#   (1814, 1821, 'GPE', 'Batavia')],
#  'NL-HaNA_1.04.02_6847_0528.txt': [],
#  'NL-HaNA_1.04.02_6847_0529.txt': [],
#  'NL-HaNA_1.04.02_6847_0515.txt': [(994, 1007, 'INDIGENOUS', 'lijfseijgenen'),
#   (1781, 1825, 'GPE', 'oost zijde van de tijgersgragt binnen destad'),
#   (2170, 2177, 'GPE', 'Batavia')],
#  'NL-HaNA_1.04.02_6847_0273.txt': [(147,
#    192,
#    'ORGANIZATION',
#    'de Edele Hooge Regeering van Nederlandt India'),
#   (216, 228, 'GPE', 'stad Batavia'),
#   (1026, 1041, 'INDIGENOUS', 'Leifthij„ genen'),
#   (1164, 1171, 'WOMEN', 'lavenne'),
#   (1164, 1171, 'INDIGENOUS', 'lavenne')],
#  'NL-HaNA_1.04.02_6847_0267.txt': [(604,
#    715,
#    'ORGANIZATION',
#    'De wel Edele Groot Agtbaeren Heeren Bewindhebberen der Geactroijeerde oost Indische Comp: ter kamer Am„ sterdam'),
#   (704, 715, 'GPE', 'Am„ sterdam')],
#  'NL-HaNA_1.04.02_6847_0501.txt': [(143, 149, 'GPE', 'Campen'),
#   (347, 353, 'GPE', 'Zwolle'),
#   (101, 108, 'MEN', 'broeder'),
#   (777, 782, 'MEN', 'Neeff'),
#   (855, 861, 'ORGANIZATION', 'E Comp'),
#   (1010, 1014, 'MEN', 'zoon'),
#   (1308, 1312, 'MEN', 'zoon'),
#   (988, 997, 'GPE', 'nederland'),
#   (305, 311, 'MEN', 'de hee'),
#   (427, 433, 'MEN', 'heeren'),
#   (807, 809, 'MEN', 'dE')],
#  'NL-HaNA_1.04.02_6847_0059.txt': [(1159, 1175, 'GPE', 'nederlands india'),
#   (1203, 1212, 'GPE', 'ba„ favra'),
#   (1343, 1350, 'GPE', 'malacca'),
#   (1827, 1839, 'INDIGENOUS', 'sla„ verrige'),
#   (1879, 1891, 'INDIGENOUS', 'lijf eidenen'),
#   (1929, 1932, 'WOMEN', 'wij'),
#   (2018, 2023, 'WOMEN', 'wijff'),
#   (1095, 1098, 'MEN', 'm:r')],
#  'NL-HaNA_1.04.02_6847_0071.txt': [(1863, 1867, 'MEN', 'heer'),
#   (1906, 1913, 'GPE', 'Batavia'),
#   (2134, 2152, 'GPE', 'nederlands india g'),
#   (2179, 2186, 'GPE', 'batavia'),
#   (18, 20, 'MEN', 'dE')],
#  'NL-HaNA_1.04.02_6847_0065.txt': [(1160, 1176, 'GPE', 'nederlands india'),
#   (1204, 1213, 'GPE', 'ba„ favra'),
#   (1343, 1350, 'GPE', 'malarca'),
#   (1827, 1839, 'INDIGENOUS', 'sla„ vernije'),
#   (1880, 1893, 'INDIGENOUS', 'lijf eijdenen'),
#   (1931, 1934, 'WOMEN', 'wij'),
#   (2020, 2025, 'WOMEN', 'wijff'),
#   (1095, 1098, 'MEN', 'm:r')],
#  'NL-HaNA_1.04.02_6847_0083.txt': [(145, 148, 'MEN', 'man'),
#   (283, 290, 'GPE', 'Steltin'),
#   (326, 332, 'WOMEN', 'dogter'),
#   (347, 356, 'GPE', 'Amsterdam')],
#  'NL-HaNA_1.04.02_6847_0097.txt': [(83, 89, 'INDIGENOUS', 'slaven'),
#   (93, 102, 'WOMEN', 'slavinnen'),
#   (93, 102, 'INDIGENOUS', 'slavinnen'),
#   (404, 417, 'WOMEN', 'huijs „vrouw,'),
#   (476, 486, 'GPE', 'nagapatnam'),
#   (1200, 1204, 'MEN', 'zoon'),
#   (1388, 1398, 'GPE', 'nagapatnam'),
#   (1930, 1934, 'MEN', 'zoon'),
#   (2377, 2380, 'MEN', 'dE:')],
#  'NL-HaNA_1.04.02_6847_0068.txt': [(461, 464, 'MEN', 'M:r'),
#   (606, 613, 'GPE', 'batavia'),
#   (888, 895, 'GPE', 'Batavia'),
#   (1023, 1029, 'WOMEN', 'Dist=m'),
#   (951, 954, 'MEN', 'M:r')],
#  'NL-HaNA_1.04.02_6847_0040.txt': [(79, 84, 'MEN', 'mons:'),
#   (346, 352, 'ORGANIZATION', 'Comp:e'),
#   (498, 534, 'ORGANIZATION', 'geoctrooijeerde oost indesche Comp:s'),
#   (545, 549, 'GPE', 'amst'),
#   (786, 811, 'ORGANIZATION', 'Collegie van heeren weesm')],
#  'NL-HaNA_1.04.02_6847_0054.txt': [(2621, 2626, 'MEN', 'heere')],
#  'NL-HaNA_1.04.02_6847_0281.txt': [(137, 144, 'GPE', 'Batavia'),
#   (87, 111, 'ORGANIZATION', 'det Ed: Hoogen degeering'),
#   (178, 181, 'MEN', 'M„s'),
#   (190, 193, 'MEN', '1„e'),
#   (1395, 1404, 'GPE', 'Mallabaar'),
#   (1341, 1348, 'MEN', 'Iongens'),
#   (2525, 2564, 'ORGANIZATION', 'Eerw: Collegie van Heeren Weesmeesteren'),
#   (1334, 1348, 'INDIGENOUS', 'slaave Iongens')],
#  'NL-HaNA_1.04.02_6847_0295.txt': [(1196, 1211, 'GPE', 'de stad Batavia'),
#   (1266, 1275, 'MEN', 'Den Manh:'),
#   (1361, 1378, 'GPE', 'Reug chiros-Gragt'),
#   (1833, 1841, 'WOMEN', 'slavinud'),
#   (1833, 1841, 'INDIGENOUS', 'slavinud')],
#  'NL-HaNA_1.04.02_6847_0518.txt': [(1999, 2008, 'GPE', 'rotterdam'),
#   (2146, 2152, 'WOMEN', 'vrouwe'),
#   (2135, 2142, 'MEN', 'de heer'),
#   (2315, 2318, 'MEN', 'M„r'),
#   (2384, 2399, 'ORGANIZATION', 'Nederlands Indi'),
#   (2429, 2433, 'GPE', 'Batg'),
#   (694, 703, 'WOMEN', 'voogdesje')],
#  'NL-HaNA_1.04.02_6847_0524.txt': [(126, 144, 'GPE', 'Eijland Groot Iava'),
#   (454, 456, 'MEN', 'Mr'),
#   (902, 905, 'MEN', 'man'),
#   (2331, 2338, 'MEN', 'de heer'),
#   (2297, 2300, 'MEN', 'M„r'),
#   (2098, 2101, 'MEN', 'M„r'),
#   (2124, 2127, 'MEN', 'M„r')],
#  'NL-HaNA_1.04.02_6847_0256.txt': [(155, 158, 'MEN', 'M„r'),
#   (80,
#    154,
#    'ORGANIZATION',
#    'eeren Commissarissen uijt den agtb: raad van Justitie des Casteels Batavia'),
#   (147, 154, 'GPE', 'Batavia'),
#   (1383, 1388, 'MEN', 'Jonge'),
#   (1483, 1490, 'GPE', 'batavia'),
#   (1445, 1450, 'GPE', 'balij'),
#   (1395, 1404, 'GPE', 'Maccasser'),
#   (1229, 1238, 'MEN', 'agtb: h=r'),
#   (1558, 1579, 'ORGANIZATION', 'heeren Commissarissen'),
#   (324, 335, 'MEN', 'der E: Comp'),
#   (542, 551, 'MEN', 'Agtb: h=r'),
#   (184, 187, 'MEN', 'M=r')],
#  'NL-HaNA_1.04.02_6847_0530.txt': [],
#  'NL-HaNA_1.04.02_6847_0257.txt': [(212, 219, 'GPE', 'Batavia')],
#  'NL-HaNA_1.04.02_6847_0531.txt': [(147, 163, 'GPE', 'nederlands india'),
#   (193, 200, 'GPE', 'batavia'),
#   (742, 753, 'GPE', 'Amster„ dam'),
#   (757, 764, 'MEN', 'de Heer'),
#   (1090, 1100, 'WOMEN', 'Nejuffrouw'),
#   (1063, 1070, 'MEN', 'de heer'),
#   (1138, 1147, 'GPE', 'dordrecht'),
#   (1189, 1196, 'MEN', 'broeder'),
#   (1200, 1207, 'WOMEN', 'Susters'),
#   (247, 253, 'MEN', 'dE M:r'),
#   (1877, 1879, 'MEN', 'dE'),
#   (120, 163, 'ORGANIZATION', 'Edele Hooge Reegeringe van nederlands india')],
#  'NL-HaNA_1.04.02_6847_0525.txt': [(122, 138, 'GPE', 'nederlands India'),
#   (166, 173, 'GPE', 'Batavia'),
#   (362, 365, 'MEN', 'M„r'),
#   (739, 746, 'GPE', 'batavia'),
#   (831, 838, 'WOMEN', 'huijsv:'),
#   (1259, 1269, 'WOMEN', 'huijsvrouw'),
#   (2052, 2056, 'MEN', 'zoon'),
#   (2297, 2307, 'WOMEN', 'huijsvrouw'),
#   (93, 138, 'ORGANIZATION', "d' Edele hooge regeering van nederlands India")],
#  'NL-HaNA_1.04.02_6847_0519.txt': [(1, 8, 'GPE', 'Batavia'),
#   (64, 80, 'MEN', 'Edele Geste Heer'),
#   (122, 140, 'ORGANIZATION', 'nederlandsch india'),
#   (565, 569, 'MEN', 'heer'),
#   (690, 695, 'WOMEN', 'dogte'),
#   (808, 811, 'MEN', 'M„r'),
#   (1646, 1653, 'WOMEN', 'huijsv:'),
#   (1654, 1662, 'WOMEN', 'mejuff=r'),
#   (1799, 1806, 'GPE', 'batavia')],
#  'NL-HaNA_1.04.02_6847_0294.txt': [(1669, 1679, 'WOMEN', 'huijsvrouw'),
#   (1680, 1686, 'WOMEN', 'Juff=r'),
#   (1714, 1723, 'GPE', 'amsterdam'),
#   (2244, 2263, 'ORGANIZATION', 'Heere Weesmeesteren')],
#  'NL-HaNA_1.04.02_6847_0280.txt': [(609,
#    654,
#    'ORGANIZATION',
#    'd’ Edele Hooge regeering van Nederlands India'),
#   (638, 654, 'GPE', 'Nederlands India'),
#   (681, 693, 'GPE', 'stad Batavia'),
#   (808,
#    860,
#    'ORGANIZATION',
#    'Eerw: Collegie, van Heeren Heemra „den der Bataviase'),
#   (876, 882, 'WOMEN', 'Memss=')],
#  'NL-HaNA_1.04.02_6847_0055.txt': [(1496, 1512, 'GPE', 'nederlands indra'),
#   (1540, 1547, 'GPE', 'babavia'),
#   (1597, 1602, 'MEN', 'mons:'),
#   (1683, 1689, 'GPE', 'Jappan'),
#   (1893, 1898, 'GPE', 'Japan'),
#   (1985, 1990, 'GPE', 'Jopan'),
#   (1840, 1842, 'MEN', 'dE')],
#  'NL-HaNA_1.04.02_6847_0041.txt': [(434, 441, 'GPE', 'Batavia'),
#   (650, 666, 'GPE', 'nederlands India'),
#   (695, 702, 'GPE', 'Batavia'),
#   (861, 870, 'WOMEN', 'me jnst=m'),
#   (760, 762, 'MEN', 'dE')],
#  'NL-HaNA_1.04.02_6847_0069.txt': [(61, 67, 'MEN', 'heeren'),
#   (134, 140, 'WOMEN', 'vrouwe'),
#   (305, 311, 'WOMEN', 'vrouwe'),
#   (2682, 2698, 'GPE', 'nederlands india'),
#   (2727, 2735, 'GPE', 'bo„ tara'),
#   (218, 222, 'MEN', 'heer')],
#  'NL-HaNA_1.04.02_6847_0096.txt': [(174, 179, 'WOMEN', 'huisv'),
#   (229, 238, 'GPE', 'Conningen'),
#   (448, 458, 'GPE', 'Nagapatnam'),
#   (759, 765, 'WOMEN', 'dogter'),
#   (834, 845, 'WOMEN', 'moederlijke'),
#   (1865, 1869, 'MEN', 'zoon'),
#   (1976, 1982, 'MEN', 'zoonen'),
#   (2023, 2034, 'MEN', 'Schoon zoon'),
#   (1736, 1739, 'MEN', 'dE:')],
#  'NL-HaNA_1.04.02_6847_0082.txt': [(877, 893, 'GPE', 'nederlands India'),
#   (921, 928, 'GPE', 'Batavia'),
#   (1092, 1098, 'MEN', 'Mons:r'),
#   (1597, 1616, 'ORGANIZATION', 'Lutersche weeshuijs'),
#   (1621, 1630, 'GPE', 'Amsterdam'),
#   (1841, 1846, 'MEN', 'vader'),
#   (1850, 1854, 'MEN', 'heer'),
#   (2217, 2224, 'MEN', 'broeder'),
#   (2228, 2235, 'WOMEN', 'susters')],
#  'NL-HaNA_1.04.02_6847_0094.txt': [(800, 806, 'INDIGENOUS', 'slaven'),
#   (1544, 1551, 'GPE', 'Batavia'),
#   (1887, 1891, 'MEN', 'Heer'),
#   (1701, 1704, 'MEN', 'M:r')],
#  'NL-HaNA_1.04.02_6847_0080.txt': [(79, 86, 'MEN', 'zoontje'),
#   (380, 387, 'WOMEN', 'Susters'),
#   (388, 395, 'WOMEN', 'juff=en'),
#   (424, 434, 'WOMEN', 'huijsvrouw'),
#   (443, 447, 'MEN', 'Heer'),
#   (487, 494, 'GPE', 'Einbeck'),
#   (539, 543, 'MEN', 'heer'),
#   (589, 599, 'GPE', 'Aolsminden'),
#   (789, 799, 'WOMEN', 'doopdogter'),
#   (1494, 1498, 'MEN', 'zoon'),
#   (1534, 1540, 'MEN', 'Heeren'),
#   (2125, 2129, 'MEN', 'zoon'),
#   (2362, 2366, 'MEN', 'zoon')],
#  'NL-HaNA_1.04.02_6847_0057.txt': [(714, 723, 'GPE', 'amsterdam'),
#   (1470, 1475, 'GPE', 'bohor'),
#   (2250, 2254, 'MEN', 'zoon'),
#   (2258, 2264, 'WOMEN', 'dogter')],
#  'NL-HaNA_1.04.02_6847_0043.txt': [(514, 521, 'GPE', 'batavia'),
#   (726, 742, 'GPE', 'nederlands indra'),
#   (769, 776, 'GPE', 'Bohavia'),
#   (1567, 1577, 'WOMEN', 'Swagerinne'),
#   (1578, 1583, 'WOMEN', 'Jop=m'),
#   (1616, 1621, 'WOMEN', 'wed:e'),
#   (1629, 1632, 'MEN', 'dE:'),
#   (662, 665, 'MEN', 'M:r')],
#  'NL-HaNA_1.04.02_6847_0282.txt': [(327,
#    426,
#    'ORGANIZATION',
#    'd’Edele Agtb: Heeren Bewindhebberen der Nederlandse oost Jndische (maatschappij ter Kamer Amsterdam'),
#   (417, 426, 'GPE', 'Amsterdam'),
#   (2067, 2088, 'ORGANIZATION', 'Heeren Wegmnreesteren')],
#  'NL-HaNA_1.04.02_6847_0269.txt': [(1576, 1590, 'GPE', 'Grafschap Teck')],
#  'NL-HaNA_1.04.02_6847_0533.txt': [(175, 191, 'GPE', 'nederlands Jndia'),
#   (221, 228, 'GPE', 'Batavia'),
#   (1217, 1239, 'MEN', 'geadop„ teerde Soontje'),
#   (1455, 1468, 'INDIGENOUS', 'lijffeijgenen'),
#   (1591, 1599, 'INDIGENOUS', 'slavinne'),
#   (1591, 1599, 'WOMEN', 'slavinne'),
#   (1710, 1716, 'INDIGENOUS', 'slaaff'),
#   (1759, 1765, 'WOMEN', 'aogter'),
#   (1759, 1765, 'INDIGENOUS', 'aogter'),
#   (1000, 1002, 'MEN', 'dE'),
#   (146, 191, 'ORGANIZATION', 'de Edele horge regeringe van nederlands Jndia')],
#  'NL-HaNA_1.04.02_6847_0255.txt': [(496, 503, 'GPE', 'Batavia'),
#   (791, 798, 'GPE', 'Batavia')],
#  'NL-HaNA_1.04.02_6847_0527.txt': [(519, 526, 'GPE', 'Batavia'),
#   (583, 595, 'MEN', 'mijne heeren'),
#   (640, 642, 'MEN', 'Mr'),
#   (858, 865, 'GPE', 'Batavia'),
#   (1133, 1140, 'GPE', 'Batavia'),
#   (596, 599, 'MEN', 'M„r'),
#   (620, 623, 'MEN', 'M„r'),
#   (671, 674, 'MEN', 'M„r')],
#  'NL-HaNA_1.04.02_6847_0526.txt': [(132, 139, 'GPE', 'Batavia'),
#   (195, 211, 'GPE', 'Nederlands india'),
#   (360, 370, 'WOMEN', 'huijsvrouw'),
#   (1169, 1210, 'ORGANIZATION', 'nederlandsche oost indische maatschappije'),
#   (149, 152, 'MEN', 'M„r')],
#  'NL-HaNA_1.04.02_6847_0532.txt': [(575,
#    593,
#    'ORGANIZATION',
#    'oost Indische Comp'),
#   (604, 613, 'GPE', 'Amsterdam')],
#  'NL-HaNA_1.04.02_6847_0254.txt': [(323, 327, 'MEN', 'heer'),
#   (666, 677, 'MEN', 'Jonge gen=t'),
#   (718, 727, 'GPE', 'Maccasser'),
#   (701, 706, 'GPE', 'balie'),
#   (689, 696, 'GPE', 'batavia'),
#   (515, 520, 'MEN', 'd’ E:')],
#  'NL-HaNA_1.04.02_6847_0268.txt': [(615, 622, 'GPE', 'Batavia'),
#   (589, 598, 'INDIGENOUS', 'boor ling'),
#   (720, 727, 'GPE', 'Balavia'),
#   (943, 958, 'GPE', 'de stad Batavia'),
#   (1161, 1178, 'MEN', 'Den Welherw: Heer'),
#   (1006, 1011, 'MEN', 'Mons:')],
#  'NL-HaNA_1.04.02_6847_0283.txt': [(275, 281, 'WOMEN', 'suster'),
#   (444, 454, 'GPE', 'Suijlesten'),
#   (463, 470, 'GPE', 'utrecht'),
#   (344, 350, 'GPE', 'Leeren'),
#   (309, 316, 'MEN', 'de Heer'),
#   (1008, 1015, 'WOMEN', 'dogters'),
#   (1090, 1128, 'ORGANIZATION', 'Raad Estra ord„e van Nederlands India,'),
#   (1111, 1127, 'GPE', 'Nederlands India'),
#   (1149, 1159, 'WOMEN', 'huijsvrouw'),
#   (1167, 1181, 'MEN', 'WelEdelen Heer'),
#   (1050, 1070, 'MEN', 'welEdele Gestr: Heer'),
#   (1250, 1264, 'GPE', 'Iaras oostcust'),
#   (1598, 1604, 'WOMEN', 'bagter'),
#   (1841, 1845, 'WOMEN', 'Nigt'),
#   (2074, 2082, 'WOMEN', 'mejusf=r'),
#   (2202, 2259, 'ORGANIZATION', 'de wel'),
#   (2243, 2259, 'GPE', 'der stad utrecht')],
#  'NL-HaNA_1.04.02_6847_0042.txt': [(366, 372, 'WOMEN', 'moeder'),
#   (373, 380, 'WOMEN', 'mepnst='),
#   (406, 411, 'WOMEN', 'wed:e'),
#   (415, 419, 'MEN', 'heer')],
#  'NL-HaNA_1.04.02_6847_0056.txt': [(1999, 2005, 'WOMEN', 'moeder'),
#   (2065, 2081, 'GPE', 'nassan deelenbur'),
#   (2118, 2125, 'MEN', 'broeder'),
#   (2129, 2134, 'WOMEN', 'suste')],
#  'NL-HaNA_1.04.02_6847_0081.txt': [(363, 368, 'MEN', 'zoons'),
#   (382, 389, 'WOMEN', 'Mepff:r'),
#   (406, 414, 'WOMEN', 'huijsv:r'),
#   (1225, 1234, 'GPE', 'Amsterdam'),
#   (1785, 1798, 'INDIGENOUS', 'Lijfflijgenen')],
#  'NL-HaNA_1.04.02_6847_0095.txt': [(366, 374, 'WOMEN', 'Slavinne'),
#   (366, 374, 'INDIGENOUS', 'Slavinne'),
#   (401, 407, 'WOMEN', 'dogter'),
#   (489, 501, 'INDIGENOUS', 'sla„ vernije'),
#   (989, 996, 'GPE', 'Batavia'),
#   (1187, 1196, 'WOMEN', 'dogtertje'),
#   (1213, 1217, 'MEN', 'zoon'),
#   (1250, 1256, 'WOMEN', 'huisv:'),
#   (1336, 1345, 'MEN', 'doopvader'),
#   (1407, 1426, 'INDIGENOUS', 'vrij huisinboorling'),
#   (1506, 1510, 'WOMEN', 'meid'),
#   (1579, 1589, 'GPE', 'Nagapatnam'),
#   (1017, 1029, 'ORGANIZATION', 'Luterse kerk'),
#   (1084, 1095, 'GPE', 'Tranquebaar'),
#   (1054, 1080, 'ORGANIZATION', 'koninglijke deense Mission'),
#   (1636, 1644, 'INDIGENOUS', 'slavinne'),
#   (1636, 1644, 'WOMEN', 'slavinne'),
#   (1913, 1917, 'MEN', 'zoon'),
#   (2095, 2108, 'INDIGENOUS', 'lijffEijgenen'),
#   (2122, 2128, 'INDIGENOUS', 'Slavin'),
#   (2156, 2164, 'WOMEN', 'slavinne'),
#   (2156, 2164, 'INDIGENOUS', 'slavinne')],
#  'NL-HaNA_1.04.02_6847_0091.txt': [(524, 531, 'MEN', 'broeder'),
#   (894, 901, 'MEN', 'broeder'),
#   (2441, 2444, 'MEN', 'DE:')],
#  'NL-HaNA_1.04.02_6847_0085.txt': [(1398, 1404, 'INDIGENOUS', 'slaven'),
#   (2330, 2346, 'GPE', 'Nederlands Jndia'),
#   (2259, 2262, 'MEN', 'M:r')],
#  'NL-HaNA_1.04.02_6847_0052.txt': [(128, 135, 'GPE', 'Batavia'),
#   (181, 187, 'MEN', 'mons:r'),
#   (252, 258, 'WOMEN', 'Jntt=e')],
#  'NL-HaNA_1.04.02_6847_0293.txt': [(509, 519, 'WOMEN', 'huijsvrouw'),
#   (600, 607, 'GPE', 'Batavia'),
#   (753, 798, 'ORGANIZATION', 'de Edele Hooge Regeering van Nederlands India'),
#   (822, 834, 'GPE', 'stad Batavia'),
#   (1119, 1163, 'ORGANIZATION', 'Agtb: Raad van Justitie des Casteels Batavia'),
#   (1147, 1163, 'GPE', 'Casteels Batavia')],
#  'NL-HaNA_1.04.02_6847_0287.txt': [(231, 240, 'WOMEN', 'Moe„ „der'),
#   (241, 247, 'WOMEN', 'vrauwe'),
#   (267, 272, 'WOMEN', 'wed„e'),
#   (281, 297, 'MEN', 'den wel Ed: Heer'),
#   (343, 353, 'GPE', 'Rijs„'),
#   (1536, 1543, 'GPE', 'Naarden'),
#   (1471, 1489, 'MEN', 'De WelEdele Heeren'),
#   (1765, 1772, 'GPE', 'Muijden'),
#   (1699, 1717, 'MEN', 'den wel Edele Heer'),
#   (1618, 1642, 'MEN', 'Den welEdel Agtb: Heeren'),
#   (1913, 1949, 'MEN', 'Den Hoog Edelen Groot Agtbaaren Heer'),
#   (2003, 2019, 'GPE', 'Nederlands India'),
#   (2091, 2115, 'MEN', 'Den WelEdele Gestr: Heer'),
#   (301, 304, 'MEN', 'M„r'),
#   (2290, 2293, 'MEN', 'M„r')],
#  'NL-HaNA_1.04.02_6847_0250.txt': [(728, 734, 'WOMEN', 'suster'),
#   (789, 792, 'MEN', 'oom')],
#  'NL-HaNA_1.04.02_6847_0536.txt': [(58, 67, 'MEN', 'testateur'),
#   (500, 516, 'GPE', 'nederlands India'),
#   (546, 553, 'GPE', 'Batavia'),
#   (603, 609, 'MEN', 'Mons=r'),
#   (1385, 1407, 'INDIGENOUS', 'de vrij Christen vrouw'),
#   (1385, 1407, 'WOMEN', 'de vrij Christen vrouw'),
#   (1449, 1463, 'WOMEN', 'doop dogtertje'),
#   (429, 432, 'MEN', 'M:r'),
#   (479, 516, 'ORGANIZATION', 'hooge regieringh van nederlands India')],
#  'NL-HaNA_1.04.02_6847_0522.txt': [(191,
#    234,
#    'ORGANIZATION',
#    'staaten Generaal der vereenigde nederlanden'),
#   (287, 297, 'WOMEN', 'gedagdesse'),
#   (770, 771, 'MEN', 'M'),
#   (212, 234, 'GPE', 'vereenigde nederlanden')],
#  'NL-HaNA_1.04.02_6847_0278.txt': [(1364, 1372, 'WOMEN', 'Mejuff=r'),
#   (1323, 1331, 'MEN', 'Den Heer'),
#   (1405, 1414, 'GPE', 'S„t Aubin'),
#   (1844, 1876, 'MEN', 'Den wel Edele vestrenge Heer M„r'),
#   (1919, 1944, 'ORGANIZATION', 'Raad van Nederlands India'),
#   (1928, 1944, 'GPE', 'Nederlands India'),
#   (1949, 1963, 'MEN', 'den E: E:')],
#  'NL-HaNA_1.04.02_6847_0872.txt': [(358,
#    375,
#    'INDIGENOUS',
#    'huysen boorlingen')],
#  'NL-HaNA_1.04.02_6847_0279.txt': [(210,
#    238,
#    'ORGANIZATION',
#    'de Eerw: Heeren Weesmeeteren'),
#   (805,
#    918,
#    'ORGANIZATION',
#    'E: seer Eerbiedig De welEdele Groot Agtbaaren bewind hebbren der Geartroijeerde oost Jndische ter kamer Amsterdam'),
#   (909, 918, 'GPE', 'Amsterdam'),
#   (1374, 1387, 'INDIGENOUS', 'Legt Eijgenen')],
#  'NL-HaNA_1.04.02_6847_0523.txt': [(236, 243, 'GPE', 'Batavia'),
#   (444, 447, 'MEN', 'M„r'),
#   (470, 473, 'MEN', 'M„r'),
#   (894, 896, 'MEN', 'Mr'),
#   (964, 973, 'WOMEN', 'huijvrouw'),
#   (2003, 2006, 'MEN', 'man'),
#   (508, 515, 'GPE', 'Batavia'),
#   (643, 682, 'ORGANIZATION', 'agtb: raad van Justitie deses Casteelen'),
#   (695, 702, 'GPE', 'Batavia'),
#   (783, 821, 'ORGANIZATION', 'raede van Iustitie des Casteel batavia'),
#   (806, 821, 'GPE', 'Casteel batavia'),
#   (1260, 1278, 'ORGANIZATION', 'de hooge regeering'),
#   (868, 871, 'MEN', 'M„r'),
#   (1881, 1884, 'MEN', 'M:r')],
#  'NL-HaNA_1.04.02_6847_0251.txt': [(222,
#    262,
#    'ORGANIZATION',
#    'oost indiesche Comp: ter kamer Amsterdam'),
#   (253, 262, 'GPE', 'Amsterdam'),
#   (457, 483, 'ORGANIZATION', 'hooge indiasche regeering,')],
#  'NL-HaNA_1.04.02_6847_0286.txt': [(530, 538, 'WOMEN', 'Mejuff=r'),
#   (519, 529, 'WOMEN', 'Huijsvrouw')],
#  'NL-HaNA_1.04.02_6847_0292.txt': [(1156, 1165, 'INDIGENOUS', 'Mantlaass')],
#  'NL-HaNA_1.04.02_6847_0047.txt': [(141, 147, 'WOMEN', 'Just=m'),
#   (198, 212, 'GPE', 'Chineese grogt'),
#   (1474, 1482, 'WOMEN', 'prysvrou'),
#   (1483, 1491, 'WOMEN', 'mejn p=m'),
#   (1524, 1531, 'GPE', 'holland'),
#   (2162, 2165, 'MEN', 'man'),
#   (2203, 2211, 'GPE', 'Samarang')],
#  'NL-HaNA_1.04.02_6847_0053.txt': [(2142, 2158, 'GPE', 'nederlands indra'),
#   (2186, 2193, 'GPE', 'Batavia'),
#   (2415, 2417, 'MEN', 'dE')],
#  'NL-HaNA_1.04.02_6847_0084.txt': [(382, 398, 'GPE', 'nederlands India'),
#   (437, 444, 'GPE', 'Batavia'),
#   (556, 562, 'WOMEN', 'Juff=r')],
#  'NL-HaNA_1.04.02_6847_0090.txt': [(1940, 1956, 'GPE', 'nederlands Jndia'),
#   (1985, 1992, 'GPE', 'Batavia'),
#   (2124, 2130, 'WOMEN', 'Juff:r'),
#   (2050, 2053, 'MEN', 'DE:')],
#  'NL-HaNA_1.04.02_6847_0086.txt': [(80, 87, 'GPE', 'Batavia'),
#   (1110, 1116, 'INDIGENOUS', 'slaaff'),
#   (1267, 1274, 'INDIGENOUS', 'slaafse'),
#   (1303, 1311, 'INDIGENOUS', 'Slavinne'),
#   (1303, 1311, 'WOMEN', 'Slavinne'),
#   (1777, 1797, 'WOMEN', 'vrije Christen vrouw'),
#   (1777, 1797, 'INDIGENOUS', 'vrije Christen vrouw'),
#   (148, 151, 'MEN', 'dE:')],
#  'NL-HaNA_1.04.02_6847_0092.txt': [(1990, 2006, 'GPE', 'nederlands India'),
#   (2034, 2041, 'GPE', 'Batavia'),
#   (2108, 2112, 'MEN', 'Heer'),
#   (1923, 1926, 'MEN', 'M:r')],
#  'NL-HaNA_1.04.02_6847_0045.txt': [(416, 432, 'GPE', 'nederlands endra'),
#   (460, 467, 'GPE', 'Caliara'),
#   (606, 615, 'GPE', 'palembang'),
#   (713, 717, 'MEN', 'Heer'),
#   (762, 781, 'GPE', 'portigeese gemeente'),
#   (357, 360, 'MEN', 'S:r'),
#   (792, 795, 'MEN', 'dE:')],
#  'NL-HaNA_1.04.02_6847_0051.txt': [(706, 712, 'INDIGENOUS', 'slaven'),
#   (1708, 1712, 'MEN', 'Zoon'),
#   (2015, 2022, 'GPE', 'Batavia')],
#  'NL-HaNA_1.04.02_6847_0079.txt': [(225, 241, 'GPE', 'nederlands India'),
#   (271, 278, 'GPE', 'Batavia'),
#   (1119, 1133, 'ORGANIZATION', 'Lutersche kork'),
#   (1238, 1258, 'WOMEN', 'vrije Christen vrouw'),
#   (1238, 1258, 'INDIGENOUS', 'vrije Christen vrouw'),
#   (1604, 1608, 'MEN', 'heer'),
#   (1637, 1644, 'GPE', 'Alkmaar'),
#   (1755, 1761, 'WOMEN', 'zuster'),
#   (2032, 2039, 'MEN', 'zoontje'),
#   (157, 160, 'MEN', 'M:r'),
#   (326, 328, 'MEN', 'DE')],
#  'NL-HaNA_1.04.02_6847_0284.txt': [(834, 840, 'WOMEN', 'Iuff=r'),
#   (968, 974, 'WOMEN', 'Jusf=t'),
#   (1197, 1216, 'WOMEN', 'Ed: Moeije Mejrff=r'),
#   (1289, 1296, 'GPE', 'Eendrom'),
#   (1300, 1313, 'GPE', 'Groningerland'),
#   (1413, 1426, 'WOMEN', 'Moeije Iuff=r'),
#   (1479, 1488, 'GPE', 'Amsterdam'),
#   (1778, 1793, 'INDIGENOUS', 'Leijt„ Eijgenen'),
#   (1918, 1923, 'MEN', 'Ionga'),
#   (1959, 1964, 'WOMEN', 'wijft'),
#   (1900, 1905, 'WOMEN', 'vrouw'),
#   (1912, 1923, 'INDIGENOUS', 'vrije Ionga')],
#  'NL-HaNA_1.04.02_6847_0290.txt': [(388, 394, 'INDIGENOUS', 'slanen'),
#   (398, 401, 'INDIGENOUS', '„je'),
#   (1405, 1411, 'WOMEN', 'suster'),
#   (1427, 1437, 'WOMEN', 'huijsvrouw'),
#   (456, 462, 'GPE', 'pisang')],
#  'NL-HaNA_1.04.02_6847_0521.txt': [(79, 86, 'MEN', 'de heer'),
#   (242, 248, 'INDIGENOUS', 'slaaff'),
#   (484, 491, 'GPE', 'Batavia'),
#   (1330, 1337, 'MEN', 'De heer'),
#   (1486, 1496, 'WOMEN', 'huijsvrouw'),
#   (1527, 1538, 'WOMEN', 'gedaagdesse'),
#   (266, 270, 'WOMEN', 'wij/')],
#  'NL-HaNA_1.04.02_6847_0535.txt': [(676,
#    696,
#    'ORGANIZATION',
#    'oost Jndissche Comp:'),
#   (707, 716, 'GPE', 'Amsterdam'),
#   (997, 1009, 'INDIGENOUS', 'lijfEijgenen'),
#   (1303, 1315, 'INDIGENOUS', 'lijfEijgenen')],
#  'NL-HaNA_1.04.02_6847_0253.txt': [(306,
#    333,
#    'ORGANIZATION',
#    'den agtb: Raad van Justitie'),
#   (347, 363, 'GPE', 'Casteels batavia')],
#  'NL-HaNA_1.04.02_6847_0509.txt': [(523, 529, 'MEN', 'zoonen'),
#   (494, 500, 'GPE', 'Europa'),
#   (672, 679, 'MEN', 'broeder'),
#   (719, 726, 'MEN', 'Broeder'),
#   (768, 772, 'MEN', 'zoon'),
#   (1188, 1227, 'ORGANIZATION', 'oostindische Comp„e ter kamer Amsterdam'),
#   (2360, 2364, 'MEN', 'heer'),
#   (2492, 2500, 'WOMEN', 'mejuff=r'),
#   (2501, 2508, 'WOMEN', 'demed„e'),
#   (404, 414, 'WOMEN', 'huijsvrouw'),
#   (418, 428, 'WOMEN', 'testatrice'),
#   (1398, 1408, 'WOMEN', 'testatrice'),
#   (1881, 1891, 'WOMEN', 'testatrice'),
#   (260, 266, 'MEN', 'heeren'),
#   (1022, 1031, 'ORGANIZATION', 'DE Comp„s'),
#   (2017, 2023, 'MEN', 'heeren'),
#   (2197, 2207, 'WOMEN', 'testatrice'),
#   (1724, 1733, 'MEN', 'testateur')],
#  'NL-HaNA_1.04.02_6847_0508.txt': [(141, 147, 'WOMEN', 'Juff=r'),
#   (784, 790, 'INDIGENOUS', 'slaaff'),
#   (1051, 1058, 'WOMEN', 'Iufrouw'),
#   (1044, 1050, 'WOMEN', 'Moeder'),
#   (1084, 1088, 'WOMEN', 'wed:'),
#   (1127, 1148, 'GPE', 'frankfort aan de main'),
#   (1212, 1219, 'WOMEN', 'zusters'),
#   (1339, 1346, 'WOMEN', 'Zusters'),
#   (1476, 1483, 'MEN', 'Broeder'),
#   (1556, 1559, 'MEN', 'loo'),
#   (1788, 1794, 'GPE', 'Europa'),
#   (1902, 1915, 'WOMEN', 'schoon moeder'),
#   (1916, 1922, 'WOMEN', 'Juff=r'),
#   (1946, 1950, 'WOMEN', 'wede'),
#   (872, 880, 'WOMEN', 'statrice')],
#  'NL-HaNA_1.04.02_6847_0534.txt': [(168, 175, 'MEN', 'zoontje'),
#   (646, 653, 'MEN', 'broeder'),
#   (654, 661, 'MEN', 'de heer'),
#   (730, 750, 'MEN', 'geadopteerde zoontje'),
#   (1294, 1301, 'MEN', 'zoontje')],
#  'NL-HaNA_1.04.02_6847_0252.txt': [(525, 532, 'GPE', 'Batavia')],
#  'NL-HaNA_1.04.02_6847_1158.txt': [(495,
#    513,
#    'INDIGENOUS',
#    'huijsin boorlingen')],
#  'NL-HaNA_1.04.02_6847_0520.txt': [(133,
#    151,
#    'ORGANIZATION',
#    'nedre„ lanas india'),
#   (179, 186, 'GPE', 'Batavia'),
#   (234, 263, 'MEN', 'den'),
#   (298, 315, 'GPE', 'nederlands indies'),
#   (792, 796, 'MEN', 'heer'),
#   (926, 932, 'WOMEN', 'dogter'),
#   (1053, 1056, 'MEN', 'M„r'),
#   (1197, 1201, 'MEN', 'hier'),
#   (2048, 2055, 'MEN', 'de Heer'),
#   (234, 263, 'MEN', 'den Wel Edele Gestrengen hier')],
#  'NL-HaNA_1.04.02_6847_0291.txt': [(398,
#    463,
#    'ORGANIZATION',
#    'Hoog Edele Groot Agtb: Heeren Bewind hebberen ter kamer Amsterdam'),
#   (454, 463, 'GPE', 'Amsterdam'),
#   (1555, 1569, 'GPE', 'Casteel Orange')],
#  'NL-HaNA_1.04.02_6847_0285.txt': [(230, 239, 'MEN', 'de Heeren'),
#   (357, 364, 'MEN', 'de Heer'),
#   (307, 315, 'WOMEN', 'Mejasp=m'),
#   (607, 616, 'MEN', 'de Heeren'),
#   (976, 983, 'GPE', 'Batavia'),
#   (1032, 1035, 'WOMEN', 'M„r'),
#   (1020, 1023, 'MEN', 'M=l'),
#   (1155, 1175, 'ORGANIZATION', 'Heeren weesmeesteren'),
#   (1351, 1354, 'MEN', 'A„r'),
#   (1391,
#    1436,
#    'ORGANIZATION',
#    'de Edele Hooge Regeering van Nederlands India'),
#   (1420, 1436, 'GPE', 'Nederlands India'),
#   (1457, 1472, 'GPE', 'de stad Batavia'),
#   (1523, 1536, 'MEN', 'DeHeer en M=r'),
#   (1671, 1677, 'WOMEN', 'Mems=n')],
#  'NL-HaNA_1.04.02_6847_0078.txt': [(239, 251, 'INDIGENOUS', 'lijf eigenen'),
#   (338, 344, 'INDIGENOUS', 'slaaff'),
#   (2534, 2541, 'GPE', 'batavia'),
#   (762, 767, 'MEN', 'mons:')],
#  'NL-HaNA_1.04.02_6847_0050.txt': [(166, 171, 'WOMEN', 'moede'),
#   (181, 186, 'WOMEN', 'Just='),
#   (216, 221, 'WOMEN', 'wed:e'),
#   (638, 644, 'MEN', 'mons:r'),
#   (726, 730, 'MEN', 'heer'),
#   (1265, 1276, 'GPE', 'neder Jndia'),
#   (1206, 1210, 'MEN', 'heer'),
#   (226, 228, 'MEN', 'dE')],
#  'NL-HaNA_1.04.02_6847_0044.txt': [(122, 126, 'MEN', 'Heer'),
#   (156, 178, 'GPE', 'bataviasche ommelanden')],
#  'NL-HaNA_1.04.02_6847_0093.txt': [(600, 610, 'WOMEN', 'huijsvrouw'),
#   (611, 619, 'WOMEN', 'Mejuff:r'),
#   (831, 834, 'MEN', 'm:e'),
#   (1022, 1032, 'WOMEN', 'Huijsvrouw'),
#   (520, 523, 'MEN', 'DE:')],
#  'NL-HaNA_1.04.02_6847_0087.txt': [(526, 534, 'INDIGENOUS', 'slavinne'),
#   (526, 534, 'WOMEN', 'slavinne'),
#   (752, 794, 'ORGANIZATION', 'armen van de gereformeerde gemeente alhier'),
#   (862, 875, 'ORGANIZATION', 'Lutherse kerk'),
#   (984, 994, 'WOMEN', 'doopdogter'),
#   (1040, 1046, 'INDIGENOUS', 'slaaff'),
#   (1071, 1079, 'INDIGENOUS', 'Slavinne'),
#   (1071, 1079, 'WOMEN', 'Slavinne'),
#   (1271, 1277, 'WOMEN', 'moeder'),
#   (1300, 1304, 'WOMEN', 'wed:'),
#   (1374, 1384, 'GPE', 'Frauenkerk'),
#   (1429, 1442, 'MEN', 'halve broeder'),
#   (1485, 1491, 'WOMEN', 'Suster'),
#   (1533, 1543, 'GPE', 'frauenkerk'),
#   (1611, 1621, 'WOMEN', 'doopdogter'),
#   (1877, 1888, 'WOMEN', 'doop dogter'),
#   (2456, 2462, 'WOMEN', 'dogter')],
#  'NL-HaNA_1.04.02_6847_0745.txt': [(2851,
#    2890,
#    'ORGANIZATION',
#    'hoofge regeeringe van Nederlandst Jndia')],
#  'NL-HaNA_1.04.02_6847_0023.txt': [(1074, 1081, 'INDIGENOUS', 'De moor'),
#   (1082, 1090, 'MEN', 'd’ Jonge'),
#   (1620, 1627, 'GPE', 'Holland'),
#   (1659, 1672, 'GPE', 'nederl: india'),
#   (1701, 1708, 'GPE', 'Bahavra'),
#   (1765, 1769, 'MEN', 'heer'),
#   (2089, 2095, 'INDIGENOUS', 'slaven')],
#  'NL-HaNA_1.04.02_6847_0037.txt': [(420, 426, 'INDIGENOUS', 'slaven'),
#   (430, 438, 'WOMEN', 'Pavinnen'),
#   (430, 438, 'INDIGENOUS', 'Pavinnen'),
#   (900, 916, 'GPE', 'nederlands india')],
#  'NL-HaNA_1.04.02_6847_0751.txt': [(15, 22, 'GPE', 'Batavia'),
#   (2536, 2577, 'ORGANIZATION', 'gectroijeerde Comp oortjndische Compagnie'),
#   (2801, 2811, 'WOMEN', 'testatrice'),
#   (3012, 3028, 'ORGANIZATION', 'Hooge regeeringe'),
#   (2107, 2113, 'MEN', 'Heeren'),
#   (2114, 2127, 'ORGANIZATION', 'Weesmeesteren'),
#   (2588, 2597, 'GPE', 'Amsterdam')],
#  'NL-HaNA_1.04.02_6847_0427.txt': [(364,
#    380,
#    'INDIGENOUS',
#    'hueys inboorling'),
#   (344, 363, 'INDIGENOUS', 'in vrijdom gestelde'),
#   (344, 380, 'INDIGENOUS', 'in vrijdom gestelde hueys inboorling')],
#  'NL-HaNA_1.04.02_6847_0426.txt': [(531,
#    547,
#    'INDIGENOUS',
#    'huijs inboorling')],
#  'NL-HaNA_1.04.02_6847_0036.txt': [(419, 429, 'WOMEN', 'huijsvrouw'),
#   (852, 858, 'WOMEN', 'dogter'),
#   (915, 919, 'MEN', 'zoon'),
#   (977, 981, 'MEN', 'soon'),
#   (1109, 1116, 'WOMEN', 'dogters'),
#   (1571, 1575, 'MEN', 'soon'),
#   (1766, 1770, 'MEN', 'zoon'),
#   (500, 510, 'WOMEN', 'testatrice')],
#  'NL-HaNA_1.04.02_6847_0750.txt': [(2179,
#    2192,
#    'ORGANIZATION',
#    'weesmeesteren'),
#   (2172, 2178, 'MEN', 'Heeren'),
#   (1579, 1583, 'MEN', 'Heer'),
#   (739, 743, 'MEN', 'Heer'),
#   (1110, 1122, 'INDIGENOUS', 'lijf Eigenen'),
#   (80, 97, 'ORGANIZATION', 'oortjndische Comp'),
#   (145, 149, 'MEN', 'Heer'),
#   (2429, 2465, 'ORGANIZATION', 'Hooge regeering van Nederlands India')],
#  'NL-HaNA_1.04.02_6847_0022.txt': [(88, 92, 'MEN', 'heer'),
#   (819, 824, 'MEN', 'heere'),
#   (989, 996, 'MEN', 'meester'),
#   (1724, 1731, 'GPE', 'amster:')],
#  'NL-HaNA_1.04.02_6847_0752.txt': [(2407, 2423, 'GPE', 'Casteels Batavia'),
#   (99, 105, 'INDIGENOUS', 'slaven'),
#   (601, 612, 'INDIGENOUS', 'lijfeigenen'),
#   (1877, 1896, 'ORGANIZATION', 'Jndinsche regeering'),
#   (2362, 2366, 'MEN', 'Heer')],
#  'NL-HaNA_1.04.02_6847_0034.txt': [(576, 590, 'WOMEN', 'Jongste dogter'),
#   (653, 657, 'MEN', 'zoon'),
#   (721, 725, 'MEN', 'Zoon'),
#   (781, 788, 'WOMEN', 'dogters'),
#   (1303, 1307, 'MEN', 'zoon'),
#   (1472, 1476, 'MEN', 'soon'),
#   (1516, 1522, 'MEN', 'zoonen'),
#   (1818, 1830, 'WOMEN', 'huijs„ vrouw'),
#   (1984, 1994, 'WOMEN', 'huijsbrouw')],
#  'NL-HaNA_1.04.02_6847_0020.txt': [(269, 276, 'GPE', 'Batavia'),
#   (527, 535, 'GPE', 'Batavia,'),
#   (1294, 1297, 'MEN', 'hem'),
#   (1298, 1305, 'MEN', 'De Heer'),
#   (1417, 1420, 'MEN', 'hem'),
#   (584, 586, 'MEN', 'dE'),
#   (1364, 1367, 'MEN', 'dE:')],
#  'NL-HaNA_1.04.02_6847_0746.txt': [(23, 30, 'GPE', 'Batavia'),
#   (124, 132, 'WOMEN', 'Juffrouw'),
#   (156, 163, 'GPE', 'Balavia'),
#   (806, 816, 'WOMEN', 'huis vrouw'),
#   (820, 827, 'WOMEN', 'Iufrouw'),
#   (1021, 1031, 'WOMEN', 'huijsvrouw'),
#   (1381, 1389, 'WOMEN', 'Juffrouw'),
#   (2341, 2347, 'WOMEN', 'moeder')],
#  'NL-HaNA_1.04.02_6847_0237.txt': [(266, 272, 'MEN', 'slaaff'),
#   (266, 272, 'INDIGENOUS', 'slaaff'),
#   (292, 300, 'WOMEN', 'slavinne'),
#   (292, 300, 'INDIGENOUS', 'slavinne'),
#   (315, 320, 'GPE', 'balij'),
#   (284, 288, 'GPE', 'Nias'),
#   (1668, 1677, 'GPE', 'Amsterdam')],
#  'NL-HaNA_1.04.02_6847_0021.txt': [(228, 235, 'GPE', 'Holland'),
#   (266, 284, 'GPE', 'ne„ derlands india'),
#   (313, 320, 'GPE', 'Batavia'),
#   (392, 397, 'MEN', 'Heere'),
#   (1947, 1951, 'MEN', 'heer'),
#   (2014, 2023, 'GPE', 'Amsterdam'),
#   (2027, 2033, 'WOMEN', 'vrouwe'),
#   (2198, 2206, 'MEN', 'broeders'),
#   (2210, 2217, 'WOMEN', 'zuiders')],
#  'NL-HaNA_1.04.02_6847_0747.txt': [(118, 122, 'MEN', 'Heer'),
#   (140, 175, 'ORGANIZATION', 'raad croinaire van Wederlands Jndia'),
#   (206, 228, 'ORGANIZATION', 'Collegie van heem raad'),
#   (299, 311, 'WOMEN', 'Meju„ „frouw'),
#   (315, 321, 'WOMEN', 'weduwe'),
#   (372, 389, 'ORGANIZATION', 'provisie magazijn'),
#   (1270, 1304, 'ORGANIZATION', 'Collegie van Heer en weermeesteren'),
#   (1691, 1700, 'GPE', 'Amsterdam'),
#   (2008, 2020, 'INDIGENOUS', 'lijf Eigenen')],
#  'NL-HaNA_1.04.02_6847_0753.txt': [(1343, 1348, 'GPE', 'Japan'),
#   (1362, 1373, 'GPE', 'Nanga Casti'),
#   (362, 371, 'WOMEN', 'Mejufrouw'),
#   (733, 747, 'ORGANIZATION', "w'eesmeesteren"),
#   (434, 443, 'GPE', 'Eldenzeel'),
#   (556, 560, 'MEN', 'Heer'),
#   (1108, 1123, 'ORGANIZATION', 'Kamer Amsterdam'),
#   (1114, 1123, 'GPE', 'Amsterdam'),
#   (2019, 2056, 'ORGANIZATION', 'hooge regeeringe van Nederlands Jndra'),
#   (2090, 2097, 'GPE', 'Batavia'),
#   (2208, 2229, 'ORGANIZATION', 'Comp:s Equipagie werf')],
#  'NL-HaNA_1.04.02_6847_0035.txt': [(374, 383, 'WOMEN', 'puysvrouw'),
#   (529, 535, 'INDIGENOUS', 'slaven'),
#   (539, 548, 'INDIGENOUS', 'slavinnen'),
#   (539, 548, 'WOMEN', 'slavinnen'),
#   (867, 876, 'WOMEN', 'hijsvrouw'),
#   (1012, 1027, 'GPE', 'ederlands india'),
#   (1725, 1735, 'WOMEN', 'huijsvrouw')],
#  'NL-HaNA_1.04.02_6847_0031.txt': [(362, 373, 'MEN', 'schoon Zoon'),
#   (404, 406, 'MEN', 'm:'),
#   (1498, 1507, 'GPE', 'Amsterdam'),
#   (521, 527, 'MEN', 'mons:r')],
#  'NL-HaNA_1.04.02_6847_0757.txt': [(1198, 1203, 'WOMEN', 'Juff„'),
#   (1223, 1229, 'WOMEN', 'weduwe'),
#   (1423, 1429, 'WOMEN', 'moeder'),
#   (2054, 2067, 'ORGANIZATION', 'Weesmeesteren'),
#   (3029, 3036, 'INDIGENOUS', 'slaaven')],
#  'NL-HaNA_1.04.02_6847_0025.txt': [(1312, 1318, 'WOMEN', 'Sister'),
#   (1301, 1308, 'MEN', 'broeder'),
#   (1405, 1412, 'GPE', 'malacca'),
#   (1452, 1455, 'MEN', 'oom'),
#   (1528, 1535, 'GPE', 'Zulphen'),
#   (2082, 2086, 'MEN', 'heer')],
#  'NL-HaNA_1.04.02_6847_0019.txt': [(96, 102, 'WOMEN', 'moeder'),
#   (103, 109, 'WOMEN', 'Jn p=m'),
#   (136, 141, 'WOMEN', 'wed:e'),
#   (242, 249, 'MEN', 'broeder'),
#   (253, 259, 'WOMEN', 'suster'),
#   (351, 364, 'GPE', 'oostvriesland'),
#   (1005, 1017, 'MEN', 'Eerw: heeren'),
#   (697, 700, 'MEN', 'm:r')],
#  'NL-HaNA_1.04.02_6847_0018.txt': [(648, 655, 'GPE', 'Batavia'),
#   (936, 943, 'GPE', 'batavia'),
#   (1612, 1619, 'MEN', 'booeder'),
#   (1001, 1005, 'MEN', 'mons')],
#  'NL-HaNA_1.04.02_6847_0024.txt': [(158, 162, 'MEN', 'Heer'),
#   (199, 207, 'GPE', 'Ternaten'),
#   (213, 217, 'MEN', 'heer'),
#   (855, 863, 'GPE', 'Iaccatra'),
#   (1229, 1236, 'GPE', 'batavia'),
#   (1487, 1503, 'GPE', 'nederlands india'),
#   (1539, 1546, 'GPE', 'batavia'),
#   (1606, 1610, 'MEN', 'haer'),
#   (1699, 1707, 'WOMEN', 'me juw=m')],
#  'NL-HaNA_1.04.02_6847_0030.txt': [(117, 120, 'MEN', 'm:r'),
#   (482, 498, 'GPE', 'nederlands indra'),
#   (527, 534, 'GPE', 'Batavia'),
#   (1213, 1220, 'WOMEN', 'dogters'),
#   (1555, 1560, 'WOMEN', 'Jep=m'),
#   (1596, 1604, 'MEN', 'broeders'),
#   (1605, 1612, 'WOMEN', 'dogters'),
#   (1659, 1663, 'MEN', 'Heer'),
#   (1834, 1838, 'MEN', 'heer'),
#   (1883, 1889, 'WOMEN', 'Pijs=m'),
#   (2238, 2244, 'WOMEN', 'dogter'),
#   (2245, 2251, 'WOMEN', 'Just=m'),
#   (2269, 2278, 'WOMEN', 'Jnisvrouw'),
#   (2358, 2364, 'WOMEN', 'dogter'),
#   (2392, 2399, 'GPE', 'batavia'),
#   (454, 498, 'ORGANIZATION', 'de Edele hooge regering van nederlands indra'),
#   (273, 280, 'GPE', 'Batavia'),
#   (420, 423, 'MEN', 'M:r'),
#   (579, 581, 'MEN', 'dE')],
#  'NL-HaNA_1.04.02_6847_0756.txt': [(747, 755, 'WOMEN', 'Juffrouw'),
#   (827, 836, 'INDIGENOUS', 'Stariynen'),
#   (827, 836, 'WOMEN', 'Stariynen'),
#   (858, 863, 'GPE', 'Balij'),
#   (879, 888, 'GPE', 'Maccasser'),
#   (1952, 1959, 'GPE', 'Batavia'),
#   (2065, 2080, 'INDIGENOUS', 'maleijdse vrouw'),
#   (2075, 2080, 'WOMEN', 'vrouw'),
#   (2285, 2292, 'GPE', 'Batavia'),
#   (2081, 2084, 'INDIGENOUS', 'Vai'),
#   (2096, 2103, 'GPE', 'Boegies'),
#   (2548, 2555, 'GPE', 'Batavia'),
#   (2653, 2661, 'WOMEN', 'Iuffrouw')],
#  'NL-HaNA_1.04.02_6847_0026.txt': [(307, 313, 'GPE', 'amstv:'),
#   (1916, 1920, 'MEN', 'heer'),
#   (2281, 2297, 'GPE', 'nederlands india'),
#   (2326, 2333, 'GPE', 'batavia'),
#   (2217, 2220, 'MEN', 'm:r')],
#  'NL-HaNA_1.04.02_6847_0754.txt': [(2483,
#    2502,
#    'INDIGENOUS',
#    'vrije Chrisle vrouw'),
#   (485, 490, 'INDIGENOUS', 'slaaf'),
#   (625, 630, 'INDIGENOUS', 'slaaf'),
#   (760, 771, 'INDIGENOUS', 'sla „kinnen'),
#   (1219, 1231, 'INDIGENOUS', 'lijf eigenen'),
#   (1652, 1660, 'WOMEN', 'Juffrouw'),
#   (2497, 2502, 'WOMEN', 'vrouw'),
#   (784, 791, 'GPE', 'Batavia'),
#   (805, 810, 'GPE', 'Balij'),
#   (641, 647, 'GPE', 'Boegja'),
#   (560, 565, 'GPE', 'Balij'),
#   (539, 546, 'GPE', 'Batavia'),
#   (510, 517, 'GPE', 'Coegies'),
#   (1253, 1260, 'GPE', 'Boegies'),
#   (1273, 1280, 'GPE', 'Batavia'),
#   (1294, 1299, 'GPE', 'Balij'),
#   (1705, 1711, 'WOMEN', 'dogter'),
#   (463, 476, 'INDIGENOUS', 'lijff Eigenen'),
#   (760, 771, 'WOMEN', 'sla „kinnen'),
#   (1491, 1498, 'WOMEN', 'machome'),
#   (1507, 1512, 'WOMEN', 'vrouw'),
#   (1500, 1506, 'WOMEN', 'zuanje'),
#   (1482, 1512, 'INDIGENOUS', 'de vrije machome, zuanje vrouw')],
#  'NL-HaNA_1.04.02_6847_0032.txt': [(1261, 1277, 'GPE', 'nederlands India'),
#   (1306, 1313, 'GPE', 'Batavia'),
#   (1406, 1415, 'GPE', 'Jac Catra'),
#   (1499, 1503, 'MEN', 'Heer'),
#   (1533, 1549, 'GPE', 'nederlands india'),
#   (1661, 1669, 'WOMEN', 'mevrouwe'),
#   (1991, 1998, 'GPE', 'batavia'),
#   (1192, 1195, 'MEN', 'm:r')],
#  'NL-HaNA_1.04.02_6847_0768.txt': [(1318,
#    1338,
#    'ORGANIZATION',
#    'Heeren weesmeesteren'),
#   (1673,
#    1726,
#    'ORGANIZATION',
#    'bewinchebberen der goetroijeerde oostjn „dische Comp:'),
#   (1731, 1746, 'ORGANIZATION', 'kamer Amsterdam'),
#   (1737, 1746, 'GPE', 'Amsterdam'),
#   (2378, 2385, 'GPE', 'Balavia'),
#   (2490, 2497, 'WOMEN', 'Jufrouw'),
#   (2537, 2541, 'MEN', 'zoon'),
#   (2668, 2675, 'MEN', 'Loantje'),
#   (2683, 2687, 'MEN', 'Heer')],
#  'NL-HaNA_1.04.02_6847_0542.txt': [(1287,
#    1303,
#    'INDIGENOUS',
#    'huijs inboorling')],
#  'NL-HaNA_1.04.02_6847_0813.txt': [(1026, 1030, 'WOMEN', 'nigt'),
#   (1031, 1039, 'WOMEN', 'mesisp=m')],
#  'NL-HaNA_1.04.02_6847_0769.txt': [(78, 85, 'GPE', 'Batavia'),
#   (229, 249, 'ORGANIZATION', 'Heeren weesmestelren'),
#   (416, 435, 'ORGANIZATION', 'Heeren weermerteren'),
#   (903, 939, 'ORGANIZATION', 'Hooge Regeering van Neverlands India'),
#   (968, 975, 'GPE', 'Batavia'),
#   (1033, 1037, 'MEN', 'Mons'),
#   (2478, 2500, 'ORGANIZATION', 'Heeren weesmer, „teren')],
#  'NL-HaNA_1.04.02_6847_0755.txt': [(700, 713, 'ORGANIZATION', 'weesmeesteren'),
#   (1515, 1527, 'INDIGENOUS', 'lijf Eigenen'),
#   (1089, 1126, 'ORGANIZATION', "g'egtroijeerde aastjndische Compagnie"),
#   (1130, 1145, 'ORGANIZATION', 'kamer Amsterdam'),
#   (1136, 1145, 'GPE', 'Amsterdam'),
#   (2431, 2456, 'ORGANIZATION', 'hooge Indiaeche Regeering')],
#  'NL-HaNA_1.04.02_6847_0033.txt': [(158, 174, 'GPE', 'nederlands Indio'),
#   (204, 211, 'GPE', 'Batavia'),
#   (283, 287, 'MEN', 'Heer'),
#   (321, 337, 'GPE', 'nederlands india'),
#   (391, 399, 'WOMEN', 'mevrouwe'),
#   (450, 457, 'GPE', 'Jaccaha'),
#   (1768, 1784, 'GPE', 'nederlands india'),
#   (87, 90, 'MEN', 'M:r')],
#  'NL-HaNA_1.04.02_6847_0027.txt': [(942, 949, 'GPE', 'Batavia'),
#   (1270, 1274, 'MEN', 'Heer'),
#   (1213, 1220, 'GPE', 'batavia'),
#   (1316, 1322, 'WOMEN', 'Iuff=m'),
#   (2026, 2044, 'WOMEN', 'natuurlijke dogter'),
#   (2199, 2205, 'INDIGENOUS', 'slaven'),
#   (1103, 1106, 'MEN', 'M:r')]}

# %% [markdown]
# ### Terms for men, women and indigenous

# %%
def get_terms(data, group):
    for entity_list in data.values():
        for row in entity_list:
            if row[2] == group:
                yield row[3]
                
terms_men = set(get_terms(data, "MEN"))
terms_women = set(get_terms(data, "WOMEN"))
terms_indi = set(get_terms(data, "INDIGENOUS"))
terms_gpe = set(get_terms(data, "GPE"))
terms_org = set(get_terms(data, "ORGANIZATION"))

# %%
print(terms_men)
# Out:
# {'mons:r', 'DE:', 'Den welEdel Agtb: Heeren', 'Iongens', 'heer', 'Schoon zoon', 'DE M„r', 'den E: E:', 'vader', 'de heeren', 'man', 'Den E', 'Ionga', 'mons:', 'M:r', 'doopzoon', 'de Heer', 'haer', 'den wel Eerw: Heer', 'Den Welherw: Heer', 'Mons:', 'meester', 'alleu Heere', 'welEdele Gestr: Heer', 'voogden', 'm:e', 'den heer', 'geadopteerde zoontje', 'd’ E:', 'Den Hoog Edelen Groot Agtbaaren Heer', 'slaaff', 'zoon', 'sijnen', 'Jonge', 'M=r', 'Ed„e', 'Heeren', 'den wel Ed: Heer', 'Neeff', 'Den Manh:', 'Heere', 'wager', 'm:', 'broeders', 'den E', 'S„r', 'voogd', 'De WelEdele Heeren', 'Edele Geste Heer', '1„e', 'zoons', 'Den wel Edele vestrenge Heer M„r', 'De Wel Edele groot Agtb: Heeren', 'M:', 'opperm:', 'broeder', 'Ionge', 'A„r', 'm:r', 'hem', 'M„r', 'den Wel Edele Gestrengen hier', 'dE M:r', 'agt: heeren', 'slaeff', 'hier', 'Heer', 'van heeren', 'soon', 'E: mH', 'doopvader', 'DeHeer en M=r', 'de heer', 'zomen', 'De Heer', 'loo', 'de Heeren', 'VE:', 'den Eerwaarde Heer', 'Mons:r', 'Jonge gen=t', 'dE: M:r', 'De wel Edele Heer', 'Mr', 'Agtb: h=r', 'testateur', 'De heer', 'Iongman', 'Zoon', 'schoon Zoon', 'mons', 'geadop„ teerde Soontje', 'dE', 'Loantje', 'oom', 'halve broeder', 'd’ Jonge', 'zwager', 'dE:', 'Eerw: heeren', 'M„s', 'Swager', 'booeder', 'agtb: h=r', 'schoon zoon', 'zoonen', 'neeven', 'manslaaf', 'mijne heeren', 'Mons', 'slaaf', 'der E: Comp', 'M', 'testateurs', 'den wel Edele Heer', 'Mons=r', 'Den Heer', 'den Heer', 'S:r', 'Broeder', 'deheer', 'heeren', 'zoontje', 'Den WelEdele Gestr: Heer', 'Testateur', 'de hee', 'DE', 'WelEdelen Heer', 'den', 'heere', 'M=l'}

# %%
print(terms_org)
# Out:
# {'Hooge Regeeringe van Nederlakds India', 'Weeskamer', 'Heeren Weermeesteren', 'Eerw: Collegie, van Heeren Heemra „den der Bataviase', 'de Edele Hooge Regeering dan Neder„ lands India', 'de hooge regeering', 'Eerw: Collegie van Heeren Weesmeesteren', 'Politie', 'Jndinsche regeering', "Heeren Berind hebberen der g'eetregeerde d tindinhe Comp:e", 'Edele Hooge, regeeringe', 'Comp:e', 'de Edele Hooge Regeering van Nederlandt India', 'debaele hoge regeeringe van nederslands India', "g'Ectroijeerde oostjndische Comp", 'WelEdele Groot Agtb: Heeren Bewind. hebberen der Geostroijeerde oost Jndische Comp: ter kamer Amsterdam', 'Heeren Weesmeesteren', 'kamer Amsterdam', 'EHooge Regeeringe van Nederlands India', 'eeren Commissarissen uijt den agtb: raad van Justitie des Casteels Batavia', 'Heeren weermerteren', 'gectroijeerde Comp oortjndische Compagnie', 'Agtb: Raad van Justitie des Casteels Batavia', 'Heeren weesmer, „teren', 'De wel Edele Groot Agtbaeren Heeren Bewindhebberen der Geactroijeerde oost Indische Comp: ter kamer Am„ sterdam', 'sComp', 'hooge regeeringe van Nederlands Jndra', 'Collegie van Heeren weesmeesteren', 'de wel', 'Lutersche weeshuijs', 'Hlaege Regeeringe van Nederlangs India', 'Kleede Pakthuijs', 'hooge regeeringe van Nederlands India', 'nedre„ lanas india', 'bewinchebberen der goetroijeerde oostjn „dische Comp:', 'Kamer Amsterdam', 'Comp:s Equipagie werf', 'Heeren weesmestelren', 'E Comp', 'armen van de gereformeerde gemeente alhier', 'dergoetroyeerde costjueische Comp', 'De welEdele Groot Agtb: Heeren bewindhebberen der geocrraijeerde oost Jndisch Compagnie ter kamer Amsterdam', 'hooge regeering van nederlands india', 'de Edele hooge regering van nederlands indra', 'Luterse kerk', 'DE Comp„s', 'nederlandsche oost indische maatschappije', 'Chineese korpitaal', 'Heeren Weesmesteren', 'Heere Weesmeesteren', 'hooge Indiaeche Regeering', 'agtb: raad van Justitie deses Casteelen', 'geoctrooijeerde oost indesche Comp:s', 'wee kamer', 'Raad Estra ord„e van Nederlands India,', 'E: Comp', 'Lutherse kerk', 'oost in dische Comp', 'De welEdele Groot Agtbaren Heeren Bewindhebberen der Geoptroijeerde Oost Jndische Comp: ter kamer Amsterdam', 'Edele Hooge Regeering deser Landen', 'hooge regieringh van nederlands India', 'd’Edele Agtb: Heeren Bewindhebberen der Nederlandse oost Jndische (maatschappij ter Kamer Amsterdam', 'Edele Hooge Regeering van Nederlands India', 'Heeren Weesmeksteren', 'Kamer Amstersan', 'Heeren weesmeesteren', 'raede van Iustitie des Casteel batavia', 'Collegief van Heeten weermeesteren', 'hooge indiasche regeering,', 'Heeren Wegmnreesteren', 'oostjndische Comp', 'latijnsche schoolen tot amsterdam', 'provisie magazijn', 'E: Comp:', 'oortjndische Comp', 'oost Indische Comp', 'Edele Hooge Indiasche Regeering', 'Collegie van heeren weesm', 'heeren Commissarissen', 'den agtb: Raad van Justitie', 'Collegie van Heer en weermeesteren', "g'egtroijeerde aastjndische Compagnie", "BewinP. „hebberen der g'octroijeerde coptimischhe Comp", 'oost indiesche Comp: ter kamer Amsterdam', 'weesmeesteren', "w'eesmeesteren", 'raad croinaire van Wederlands Jndia', 'hoofge regeeringe van Nederlandst Jndia', 'dE Comp', 'de Edele horge regeringe van nederlands Jndia', 'det Ed: Hoogen degeering', "d' Edele hooge regeering van nederlands India", 'de Edele hooge Regeeringe van Nederlands India', 'Edele Comp', 'Hooge Regeering van Neverlands India', 'wegsmeesteren', 'nedertuijsche gemeente', 'oostindische Comp„e ter kamer Amsterdam', 'water geregt', 'de Edele hooge Indiase Regeering', 'raad ord„s van Nederlands india en president in ’t Eerw„s Collegie van heeren', 'Comploir generaal', 'nederlandsch india', 'Bewindhebberen der Geoctroieerde oost jndische Comp: ter kamer Amsterdam', 'gereformeerde diaconie', 'Hooge regeering van Nederlands India', 'Regeering van Nederlands Jndia', 'Hooge Indjasche Regeering', 'Lutersche kork', 'almoesniers wdeshuijs tot Amsteriam', 'Weesmeesteren', 'Hooge regeeringe', 'Raad van Nederlands India', 'Heere we ...

# %%
print(terms_women)
# Out:
# {'Mejasp=m', 'nigt', 'suester', 'vaije Christen vrouw', 'Mejuff=r', 'Iup=m', 'erfgenaame', 'Jep=m', 'Testatrice', 'de vrij Christen vrouw', 'mejusf=r', 'Jop=m', 'doop dogter', 'Mejufrouw', 'huijsv:', 'Iufrouw', 'schoon moeder', 'mesust=r', 'puysvrouw', 'hijsvrouw', 'moeden', 'haar moeder', 'moede', 'wijff', 'zuster', 'ngt', 'doctertje', 'Sister', 'Pavinnen', 'dogters', 'huijs „vrouw,', 'Hluste', 'do ter', 'me jnst=m', 'gedaagdesse', 'Mems=n', 'Meju„ „frouw', 'lavenne', 'Huijevrouw', 'Enlandsche Crietene persoone', 'voogdesje', 'mesisp=m', 'slavinud', 'haker', 'Juff=re', 'zusters', 'huijsvrouw', 'susters', 'moeder', 'voogdesse', 'Jntt=e', 'meijden', 'vrauwe', 'Dist=m', 'slavinne', 'Mepff:r', 'slavinnen', 'mejuf', 'wed:', 'me jusf=r', 'wed:e', 'weduwe', 'meid', 'wijf', 'Suster', 'Juff=r', 'huijs„ vrouw', 'Juffrouw', 'Jn p=m', 'machome', 'frouw', 'suste', 'Stariynen', 'Mejuffrouw', 'Nejuffrouw', 'vrije ontristen vrouw', 'Mejuff:r', 'wed', 'M„r', 'Juff„r', 'huijs vrouw', 'sla „kinnen', 'mevrouwe', 'Jufrouw', 'hogter', 'doop dogtertje', 'Juff:r', 'aogter', 'gedagdesse', 'suster', 'Memss=', 'wed„e', 'vrije fristen vrouw', 'huijvrouw', 'mepst=m', 'Swagerinne', 'wij/', 'Zusters', 'vrije Cristen vion', 'zuiders', 'Erfgenaame', 'Moeder', 'dogter', 'Jns=m', 'huijsv:r', 'demed„e', 'Just=m', 'Juff„', 'testatrice', 'Meuffrouw', 'mejn p=m', 'natuurlijke dogter', 'Jnst=m', 'Ins=m', 'mepnst=', 'Mejuff', 'Jongste dogter', 'Pijs=m', 'Excutrice', 'Juff=mo', 'Iuffrouw', 'groot moeder', 'Huijsvrouw', 'wede', 'degterlje', 'vrouw', 'moederlijke', 'huis vrouw', 'huisv', 'huisvrouw', 'doopdogter', 'dogtertje', 'Iuff=m', 'statrice', 'Moe„ „der', 'mejnst=m', 'wij', 'dogte', 'Just=', 'Erfgename', 'Jnsf=m', 'wijft', 'Zuster', 'Moeije Iuff=r', 'mejuff=r', 'JnW=m', 'Jusf=t', 'Susters', 'Memttw', 'Vrouw', 'vrouwe', 'bagter', 'wed=e', 'vrije Cristene vrouw', 'zuanje', 'Slavinne', 'huifsvrouw', 'mesust=m', 'Jnisvrouw', 'juff=en', 'vrije Christen vrouw', 'huisv:', 'Jnst=r', 'prysvrou', 'Ed: Moeije Mejrff=r', 'Iuff=r', 'huijsbrouw', 'Nigt', 'me juw=m'}

# %%
print(terms_indi)
# Out:
# {'Slaaf', 'de vrije Ionge', 'vrije Chrisle vrouw', 'lijfEijgenen', 'lijfEigenen', '„je', 'bereeds vrijgegevene slavinne', 'de vrij Christen vrouw', 'vrije Onchriste vrouwe', 'lijf eijdenen', 'vrije maleijtse vrouw', 'Pavinnen', 'de LeijtEijgenen, die belijdenis van den Christelijken Gods„ dienst gedaan hebben;', 'slaaff', 'lijf eijgenen', 'lavenne', 'lijfeigenen', 'Enlandsche Crietene persoone', 'slavinud', 'vrije Chris ten vrouw', 'slaven die beleijdenisse van den Christelijken Podsdienst gedaan hebben', 'boorlingen', 'lijf eidenen', 'Chineese korpitaal', 'lijffeijgenen', 'slavinne', 'slavinnen', 'Inlander', 'vrije onchristen vrouw', 'lijff Eigenen', 'hueys inboorling', 'huijsin boorlingen', 'sla„ verrije', 'lijff eigenen', 'slafsche', 'slf', 'Lijfflijgenen', 'slaeven', 'Stariynen', 'in vrijdom gestelde hueys inboorling', 'LijfEijgenen', 'sla„ verrige', 'Leijt bijgenen', 'haere kinderen', 'Legt Eijgenen', 'vrije ontristen vrouw', 'lyfeigenen', 'onchristen vrouw', 'slaave Iongens', 'sla „kinnen', 'vrij huisinboorling', 'huijs inboorling', 'slaven, nen', 'aogter', 'slaeff', 'lijf eigenen', 'huysen boorlingen', 'vrije fristen vrouw', 'vrije onchristene vrouw', 'vrije Cristen vion', 'hujs in boorlingen', 'de vrije machome, zuanje vrouw', 'in vrijdom gestelde', 'slaven', 'Slavin', 'inlanderen', 'lijf Eigenen', 'huis inboorling', 'Vai', 'maleijdse vrouw', 'slaevinne', 'slaafse', 'lijfeijgenen', 'dogtertje', 'vrije Ionga', 'De moor', 'slaaven', 'den vrije papanger', 'Mantlaass', 'sla„ vernije', 'lijffEijgenen', 'inboorling', 'Leijf Eijgenen', 'Leijt„ Eijgenen', 'manslaaf', 'boor ling', 'slaaf', 'de vrije Christen', 'vrije Cristene vrouw', 'Slavinne', 'LijffEijgenen', 'lijfseijgenen', 'slanen', 'Leifthij„ genen', 'lijf ergenen', 'vrije Christen vrouw'}

# %%
terms_indi_women = terms_women & terms_indi

# %%
print(terms_gpe)
# Out:
# {'nederlands India', 'pack poeram', 'maleijtse', 'frauenkerk', 'Geoninge', 'S„t Aubin', 'Boegja', 'Japan', 'amstveromme', 'Holland', 'Amster „dam,', 'Zwolle', 'Bestavia', 'nederdui Vshegemeen te', 'op de hoek van de Amsterdam graagt', 'binnen de stad Batavia', 'Casteel batavia', 'Ben„ „galen', 'de westzijde van de heere straet binnen destad', 'Campen', 'Balij', 'Chineese grogt', 'Jopan', 'de stad Bata„ via', 'Coegies', 'palembang', 'Eendrom', 'Einbeck', 'Iaccatra', 'bohor', 'boegis', 'Stad Batavia', 'Amster„ dam', 'batnera', 'batmera', 'Casteel Orange', 'de Theewaterstraat', 'Batavia', 'amster:', 'babavia', 'Leeren', 'holland', 'maastreiht', 'Iaras oostcust', 'Jocarta', 'de angiolse vaart buijten destad', 'Jappan', 'Maccasser', 'Bohavia', 'Goelo Chincu', 'papanger', 'Rotterdammer poort', "'tGaaven Ergedag", 'nederlands india g', 'Surmatra', 'Suijlesten', 'wystzijne van de Grootte Rivier binnen destaet', 'Amstersan', 'am„ Herdan', 'zwol', 'balie', 'Nederlands Jndia', 'Frankena Gutenand Collonee', 'Soudratta', 'Casteels batavia', 'amersfort', 'Ooslijndien', 'bataviasche ommelanden', 'amst', 'de tijgersgragt', 'vereenigde nederlanden', 'Caliara', 'Frauenkerk', 'Nagapatnam', 'nederlands indra', 'Nanga Casti', 'Eijland Groot Iava', 'de kaijmansgragt', 'utrecht', 'frankfort aan de main', 'Bwool', 'ba„ favra', 'nederlands endra', 'Batavia,', 'oost zijde van de tijgersgragt binnen destad', 'Tranquebaar', 'Alkmaar', 'Malbaar', 'schale', 'Rijs„', 'nagapatn:', 'S=t Maarten', 'amstv', 'portigeese gemeente', 'maleydse', 'Amstver:', 'batavia bij nases', 'nederland', 'nagapatnam', 'Bahavra', 'Nederlands India,', 'nederl: india', 'Mallabaar', 'oostvriesland', 'Muijden', 'nederlands Jordia', 'Nedetland India', 'bo„ tara', 'nederlands indies', 'Steltin', 'Aolsminden', 'Zulphen', 'Ternaten', 'ne„ derlands india', 'amstv:', 'Nederlands india', 'Nederlands India', 'Teerdam', 'malacca', 'Eldenzeel', 'bellingwolde', 'de stad Batavia', 'Boegies', 'amsterdam', 'Samarang', 'De Lahaije', 'Casteels Batavia', 'Conningen', 'Malacca', 'Groningerland', 'Nias', 'nassan deelenbur', 'malarca', 'nederlands in dea', 'Amboina', 'Jagerspad', 'Sumatras', 'batera', 'Europa', 'Naarden', 'der stad utrecht', 'stad Batavia', 'uijtrecht', 'nederlands Jndia', 'ederlands india', 'Batg', 'Amsterdam', 'Javra', 'Reug chiros-Gragt', 'balij', 'Am„ sterdam', 'dordrecht', 'nederlands india', 'nederlands Jonra', 'Nederland india', 'rotterdam', 'Grafschap Teck', 'batavia', 'Alkmaa', 'nederlands Indio', 'Padang', 'Luijden', 'pisang', 'amsterdann', 'Jaccaha', 'nogo patnam', 'Balavia', 'Jac Catra', 'neder Jndia'}

# %% [markdown]
# ### Creating an Index for women, indigenous

# %%
test_corpus = "./Corpus"
docs = {f: load(f, test_corpus) for f in filter(lambda f: f.endswith(".txt"), os.listdir(test_corpus))}

# %%
def build_group_regex(term_set):
    escaped = {re.escape(s) for s in term_set}
    return r"|".join(["[\s+|^]("+t+")\s+" for t in reversed(sorted(escaped, key=len))])

def get_mentions(text, group_regex):
    for m in re.finditer(group_regex, text):
        found_term = m.group()
        stripped = found_term.lstrip()
        
        if stripped == found_term:
            yield m.start(), found_term.rstrip()
        else:
            yield (m.start() + (len(found_term) - len(stripped))), stripped.rstrip()


def get_group_records(docs, group_terms):
    group_regex = build_group_regex(group_terms)

    for fname, txt in docs.items():
        for ind, found_term in get_mentions(txt, group_regex):
            yield(fname, ind, found_term)

# %%
import pandas as pd
women_records = list(get_group_records(docs, terms_women))
women_df = pandas.DataFrame.from_records(women_records, columns=["filename", "start_index", "identifier_term"])

men_records = list(get_group_records(docs, terms_men))
men_df = pandas.DataFrame.from_records(men_records, columns=["filename", "start_index", "identifier_term"])

indi_records = list(get_group_records(docs, terms_indi))
indi_df = pandas.DataFrame.from_records(indi_records, columns=["filename", "start_index", "identifier_term"])

indi_women_records = list(get_group_records(docs, terms_indi_women))
indi_women_df = pandas.DataFrame.from_records(indi_women_records, columns=["filename", "start_index", "identifier_term"])

# %%
women_df
# Out:
#                            filename  start_index       identifier_term
# 0     NL-HaNA_1.04.02_6847_0788.txt          845                 vrouw
# 1     NL-HaNA_1.04.02_6847_0978.txt         1605            Erfgenaame
# 2     NL-HaNA_1.04.02_6847_0039.txt          449                 Ins=m
# 3     NL-HaNA_1.04.02_6847_0039.txt          892                 Iup=m
# 4     NL-HaNA_1.04.02_6847_0039.txt         1147  vrije Cristene vrouw
# ...                             ...          ...                   ...
# 2137  NL-HaNA_1.04.02_6847_0785.txt          530                 vrouw
# 2138  NL-HaNA_1.04.02_6847_0791.txt          334                   wij
# 2139  NL-HaNA_1.04.02_6847_0791.txt         1347              Iuffrouw
# 2140  NL-HaNA_1.04.02_6847_0791.txt         1413                   wij
# 2141  NL-HaNA_1.04.02_6847_0791.txt         2149            erfgenaame
#
# [2142 rows x 3 columns]

# %%
indi_df
# Out:
#                           filename  start_index               identifier_term
# 0    NL-HaNA_1.04.02_6847_0039.txt         1147          vrije Cristene vrouw
# 1    NL-HaNA_1.04.02_6847_0039.txt         1289                      slavinne
# 2    NL-HaNA_1.04.02_6847_0039.txt         1330  Enlandsche Crietene persoone
# 3    NL-HaNA_1.04.02_6847_1131.txt         1028                  lijfEijgenen
# 4    NL-HaNA_1.04.02_6847_0213.txt          317                      slavinne
# ..                             ...          ...                           ...
# 544  NL-HaNA_1.04.02_6847_0550.txt          665                  lijfeijgenen
# 545  NL-HaNA_1.04.02_6847_0593.txt         1653                       slaaven
# 546  NL-HaNA_1.04.02_6847_0752.txt          601                   lijfeigenen
# 547  NL-HaNA_1.04.02_6847_0975.txt         1027                        slaven
# 548  NL-HaNA_1.04.02_6847_0785.txt         2065                   lijfeigenen
#
# [549 rows x 3 columns]

# %%
indi_women_df
# Out:
#                           filename  start_index               identifier_term
# 0    NL-HaNA_1.04.02_6847_0039.txt         1147          vrije Cristene vrouw
# 1    NL-HaNA_1.04.02_6847_0039.txt         1289                      slavinne
# 2    NL-HaNA_1.04.02_6847_0039.txt         1330  Enlandsche Crietene persoone
# 3    NL-HaNA_1.04.02_6847_0213.txt          317                      slavinne
# 4    NL-HaNA_1.04.02_6847_1092.txt         1793                     slavinnen
# ..                             ...          ...                           ...
# 152  NL-HaNA_1.04.02_6847_0237.txt          292                      slavinne
# 153  NL-HaNA_1.04.02_6847_0814.txt         2098                      slavinne
# 154  NL-HaNA_1.04.02_6847_0168.txt         1594                      slavinne
# 155  NL-HaNA_1.04.02_6847_0829.txt         1826                      Slavinne
# 156  NL-HaNA_1.04.02_6847_0578.txt           53                     dogtertje
#
# [157 rows x 3 columns]

# %%
with pd.ExcelWriter('qualifierbasedindex.xlsx') as writer:
    indi_df.to_excel(writer, sheet_name = "indigenous")
    women_df.to_excel(writer, sheet_name = "women")
    indi_women_df.to_excel(writer, sheet_name= "indigenous women")

# %% [markdown]
# ## Statistics of (Test) Corpus

# %% [markdown]
# ### Statistics Women

# %%
print("Percentage of docs with at least one mention of a women: ", women_df.filename.unique().shape[0]/len(docs))
women_per_doc = women_df.groupby("filename").apply(lambda df: df.shape[0])
print("Mean and std. dev. number of women metions per document: ", women_per_doc.mean(), women_per_doc.var()**.5)
# Out:
# Percentage of docs with at least one mention of a women:  0.6198003327787022
# Mean and std. dev. number of women metions per document:  2.875167785234899 2.0879166585748377

# %%
print("Percentage of docs with at least one mention of a men: ", men_df.filename.unique().shape[0]/len(docs)) #no qualifiers?
men_per_doc = men_df.groupby("filename").apply(lambda df: df.shape[0])
print("Mean and std. dev. number of men metions per document: ", men_per_doc.mean(), men_per_doc.var()**.5)
# Out:
# Percentage of docs with at least one mention of a men:  0.956738768718802
# Mean and std. dev. number of men metions per document:  11.066956521739131 4.938952326672142

# %%
import seaborn as sns

g = sns.histplot(women_df, x="identifier_term")
sns.set(rc={'figure.figsize':(10, 8)})
plt.xticks(rotation=90)
plt.title("Histogram of usage of identifier terms for women")
# Out:
# Text(0.5, 1.0, 'Histogram of usage of identifier terms for women')

# %%
#men_per_doc = men_df.groupby("filename").apply(lambda df: df.shape[0])
#women_per_doc = women_df.groupby("filename").apply(lambda df: df.shape[0])

#sns.jointplot(x=women_per_doc, y=men_per_doc, kind="hex")
#_ = plt.xlabel("Women per Doc")
#_ = plt.ylabel("Men per Doc")

# %%
#for x in women_df.iterrows():
    #print(x[1].filename)
    #print("----")

# %% [markdown]
# ### Statistics Indigenous

# %%
print("Percentage of docs with at least one mention of an indigenous person: ", indi_df.filename.unique().shape[0]/len(docs))
indi_per_doc = indi_df.groupby("filename").apply(lambda df: df.shape[0])
print("Mean and std. dev. number of indigenous peoples metions per document: ", indi_per_doc.mean(), indi_per_doc.var()**.5)
# Out:
# Percentage of docs with at least one mention of an indigenous person:  0.2945091514143095
# Mean and std. dev. number of indigenous peoples metions per document:  1.5508474576271187 1.0232215217702916

# %%
import seaborn as sns

g = sns.histplot(indi_df, x="identifier_term")
sns.set(rc={'figure.figsize':(10,8)})
plt.xticks(rotation=90)
plt.title("Histogram of usage of identifier terms for indigenous people")
# Out:
# Text(0.5, 1.0, 'Histogram of usage of identifier terms for indigenous people')
